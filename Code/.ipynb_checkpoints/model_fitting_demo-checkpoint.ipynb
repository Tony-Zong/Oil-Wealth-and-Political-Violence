# %%
import numpy as np
import pandas as pd
import scipy as sp
from sklearn.ensemble import RandomForestClassifier, RandomForestRegressor
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import KFold, StratifiedKFold, train_test_split
from sklearn.metrics import mean_squared_error, log_loss
import sklearn
import os
from matplotlib.pyplot import hist
from scipy import stats
# import more functions or modules if you need them !!

# %%
# set random seed for numpy
RANDOM_SEED=42
np.random.seed(RANDOM_SEED)

# %%
oil_df = pd.read_pickle('../Data/data/comprehensive_new_full.pkl')
oil_df = oil_df[oil_df.democracy>0.005]

# %%
# Conditional outcome models (Q models)
def make_linear_Q_model():
    ''' A function that returns a linear q model for later use in k-folding'''
    return LinearRegression()

def make_Q_model(output_type:str):
    ''' A function that returns a general ML q model for later use in k-folding'''
    if output_type == 'binary':
        return RandomForestClassifier(random_state=RANDOM_SEED, n_estimators=500, max_depth=None)
    return RandomForestRegressor(random_state=RANDOM_SEED, n_estimators=500, max_depth=None)
# One example: RandomForestRegressor(random_state=RANDOM_SEED, n_estimators=500, max_depth=None)

# %%
# Propensity score models (g models)
def make_g_model():
    ''' A function that returns a g model for computing propensity scores'''
    return RandomForestClassifier(n_estimators=100, max_depth=5)
# One example: RandomForestClassifier(n_estimators=100, max_depth=5)

# %%
# Functions for K-fold cross-fitting
def treatment_k_fold_fit_and_predict(make_model, X:pd.DataFrame, A:np.array, n_splits:int):
    '''
    Implements K fold cross-fitting for the model predicting the treatment A. 
    That is, 
    1. Split data into K folds
    2. For each fold j, the model is fit on the other K-1 folds
    3. The fitted model is used to make predictions for each data point in fold j
    Returns an array containing the predictions  

    Args:
    model: function that returns sklearn model (which implements fit and predict_prob)
    X: dataframe of variables to adjust for
    A: array of treatments
    n_splits: number of splits to use
    '''

    predictions = np.full_like(A, np.nan, dtype=float)
    kf = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=RANDOM_SEED)
    
    for train_index, test_index in kf.split(X, A):
        X_train = X.loc[train_index]
        A_train = A.loc[train_index]
        g = make_model()
        g.fit(X_train, A_train)

        # get predictions for split
        predictions[test_index] = g.predict_proba(X.loc[test_index])[:, 1]
    
    # sanity check that overlap holds
    assert np.isnan(predictions).sum() == 0
    return predictions

def outcome_k_fold_fit_and_predict(make_model, X:pd.DataFrame, y:np.array, A:np.array, n_splits:int, output_type:str):
    '''
    Implements K fold cross-fitting for the model predicting the outcome Y. 
    That is, 
    1. Split data into K folds
    2. For each fold j, the model is fit on the other K-1 folds
    3. The fitted model is used to make predictions for each data point in fold j
    Returns two arrays containing the predictions for all units untreated, all units treated  

    Args:
    model: function that returns sklearn model (that implements fit and either predict_prob or predict)
    X: dataframe of variables to adjust for
    y: array of outcomes
    A: array of treatments
    n_splits: number of splits to use
    output_type: type of outcome, "binary" or "continuous"
    '''

    predictions0 = np.full_like(A, np.nan, dtype=float)
    predictions1 = np.full_like(y, np.nan, dtype=float)
    if output_type == 'binary':
        kf = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=RANDOM_SEED)
    elif output_type == 'continuous':
        kf = KFold(n_splits=n_splits, shuffle=True, random_state=RANDOM_SEED)

    # include the treatment as input feature
    X_w_treatment = X.copy()
    X_w_treatment["A"] = A

    # for predicting effect under treatment / control status for each data point 
    X0 = X_w_treatment.copy()
    X0["A"] = 0
    X1 = X_w_treatment.copy()
    X1["A"] = 1

    
    for train_index, test_index in kf.split(X_w_treatment, y):
        X_train = X_w_treatment.loc[train_index]
        y_train = y.loc[train_index]
        q = make_model(output_type)
        q.fit(X_train, y_train)

        if output_type =='binary':
            predictions0[test_index] = q.predict_proba(X0.loc[test_index])[:, 1]
            predictions1[test_index] = q.predict_proba(X1.loc[test_index])[:, 1]
        elif output_type == 'continuous':
            predictions0[test_index] = q.predict(X0.loc[test_index])
            predictions1[test_index] = q.predict(X1.loc[test_index])

    assert np.isnan(predictions0).sum() == 0
    assert np.isnan(predictions1).sum() == 0
    return predictions0, predictions1

# %%
model_vars = ['ecgrowth',
              'pop_maddison_diff',
              'popdens_diff',
              'democracy_diff',
              'logmountain',
              'ethnic_fractionalization',
              'religion_fractionalization',
              'language_fractionalization',
              'leg_british',
              'decade']

# %% [markdown]
# outcome = 'onset2COWCS'
# treatment = 'valoilres_binarize'
# confounders = ['crude1990P_diff',
#                'wildcat_diff',
#                'out_regdisaster_diff',
#                'ecgrowth',
#                'pop_maddison_diff',
#                'popdens_diff',
#                'democracy_diff',
#                'logmountain',
#                'ethnic_fractionalization',
#                'religion_fractionalization',
#                'language_fractionalization',
#                'leg_british',
#                'decade',
#                'opec']

# %%
def fit_and_run_model(df, outcome:str, treatment:str, confounders:list, make_g_model,
                      make_Q_model, n_splits=5, output_type='binary', ate=True):
    '''
    Function that creates a g, q, and aiptw model based on the 
    given inputs
    
    Inputs: df (pandas df) - the dataframe the variables are contained in
            outcome (str) - the outcome variable
            treatment (str) - the treatment variable
            confounders (lst) - a list of the confounding variables
            make_g_model - the make_g_model function
            make_Q_model - the make_Q_model function
            n_splits (int) - number of splits for the model
            output_type (str) - the desired output type, either binary or continous
            ate (bool) - whether to use ate or alternative att
    
    Returns: tau_hat - the tau hat estimator for the average treatment effect
             std of tau_hat - the standard deviation for the tau_hat estimator
    '''
    df = df.replace({outcome: .00001}, 0)
    df = df[[outcome] + confounders + [treatment]]
    df = df.dropna().reset_index()
    print('Running models for treatment {} and outcome {} on {} samples'.format(treatment, outcome, len(df)))
    n = len(df)
    outcome = df[outcome]
    confounders = df[confounders]
    treatment = df[treatment]
    treatment = treatment.replace({0.0: 0, 1.0: 1})
    outcome = outcome.replace({0.0: 0, 1.0: 1})
    g = treatment_k_fold_fit_and_predict(make_g_model, X=confounders, A=treatment, n_splits=n_splits)
    drop=False
    if min(g) < .01:
        print('\nWARNING:\n Some propensity scores are very small,\n which could '
              'lead to an inflated AIPTW.\n Minimum score = ', min(g))
    if max(g) > .99:
        print('\nWARNING:\n Some propensity scores are very large,\n which could '
              'lead to an inflated AIPTW.\n Maximum score = ', max(g))
        drop = True
    print('G Model has been fit')

    Q0_ml, Q1_ml = outcome_k_fold_fit_and_predict(make_Q_model, X=confounders, y=outcome, A=treatment, \
                                                  n_splits=n_splits, output_type=output_type)
    
    print('Q model has been fit')
    data_and_nuisance_estimates_ml = pd.DataFrame({'g': g, 'Q0': Q0_ml, 'Q1': Q1_ml, 'A': treatment, 'Y': outcome})
    
    if drop:
        data_and_nuisance_estimates_ml = data_and_nuisance_estimates_ml[data_and_nuisance_estimates_ml['g'] > .01]
        data_and_nuisance_estimates_ml = data_and_nuisance_estimates_ml[data_and_nuisance_estimates_ml['g'] < .99]
        print('Dropped {} observations due to overlap condition'.format(len(df) - len(data_and_nuisance_estimates_ml)))
    # ate aiptw
    if ate:
        tau_hat, std_hat = ate_aiptw(**data_and_nuisance_estimates_ml)
    else: 
        tau_hat, std_hat = att_aiptw(**data_and_nuisance_estimates_ml)
    test_stat = tau_hat / std_hat
    p_value = stats.t.sf(abs(test_stat), df=(n-1))
    print('AIPTW model has been fit. Returning \u03C4 hat and its standard deviation')
    print('\u03C4 hat = {}, std = {}, test statistic = {}, p-value = {}\n'.format(round(tau_hat, 5), round(std_hat, 5), round(test_stat, 5), round(p_value, 5)))
    return tau_hat, std_hat, test_stat, p_value

# %%
treatment_lst = ['valoilres_binarize', # value of oil reserves
               'valoilres_public_binarize', # value of oil reserves from public data
               'oilpop_binarize', # oil reserves per capita in million barrels per 1000 persons
               'valoilres_impute_binarize', # value of oilpop_impute (multiply by crude oil price)
               'oilpop_impute_binarize']

outcome_lst = ['onset2COWCS',
               'onsetUCS',
               'coup',
               'periregular',
               'milexp_pergdpSIPRI_diff']

# %%
oil_df = oil_df.T.drop_duplicates().T

# %%
# !pip install xgboost
from xgboost import XGBClassifier
from xgboost import XGBRegressor
# Out:
# Requirement already satisfied: xgboost in /Users/zwanran/opt/anaconda3/lib/python3.9/site-packages (1.7.2)
# Requirement already satisfied: numpy in /Users/zwanran/opt/anaconda3/lib/python3.9/site-packages (from xgboost) (1.20.3)
# Requirement already satisfied: scipy in /Users/zwanran/opt/anaconda3/lib/python3.9/site-packages (from xgboost) (1.7.1)

# %%
def make_xgboost_g_model():
    return XGBClassifier(n_estimators=50, max_depth=3)

def make_xgboost_Q_model(output_type:str):
    if output_type == 'binary':
        return XGBClassifier(random_state=RANDOM_SEED, n_estimators=500, max_depth=None)
    return XGBRegressor(random_state=RANDOM_SEED, n_estimators=500, max_depth=None)

# %%
oil_df[confounders] = oil_df[confounders].astype(float)

# %%
df_dict = {'model': [], 'treatment': [], 'outcome': [], 'tau_hat': [], 'tau_std': [], 'test_stat': [], 'p_value': []}
for treat in treatment_lst:
    for out in outcome_lst:
        for model_type in ['rf', 'xgb']:
            if len(oil_df[out].value_counts()) == 2:
                output = 'binary'
            else:
                output = 'continuous'
            if model_type == 'rf':
                tau_hat, tau_std, test_stat, p_value = fit_and_run_model(oil_df, out, treat, confounders, make_g_model, make_Q_model, output_type=output, ate=False)
            else:
                tau_hat, tau_std, test_stat, p_value = fit_and_run_model(oil_df, out, treat, confounders, make_xgboost_g_model, make_xgboost_Q_model, output_type=output, ate=False)
            df_dict['model'].append(model_type)
            df_dict['treatment'].append(treat)
            df_dict['outcome'].append(out)
            df_dict['tau_hat'].append(tau_hat)
            df_dict['tau_std'].append(tau_std)
            df_dict['test_stat'].append(test_stat)
            df_dict['p_value'].append(p_value)

att_results_df = pd.DataFrame(data=df_dict)
# Out:
# Running models for treatment valoilres_binarize and outcome onset2COWCS on 2500 samples
#
# WARNING:
#  Some propensity scores are very small,
#  which could lead to an inflated AIPTW.
#  Minimum score =  0.00920356725893484
# G Model has been fit
# Q model has been fit
# AIPTW model has been fit. Returning τ hat and its standard deviation
# τ hat = -0.00177, std = 0.00441, test statistic = -0.40226, p-value = 0.34376
#
# Running models for treatment valoilres_binarize and outcome onset2COWCS on 2500 samples
#
# WARNING:
#  Some propensity scores are very small,
#  which could lead to an inflated AIPTW.
#  Minimum score =  0.00010281377763021737
#
# WARNING:
#  Some propensity scores are very large,
#  which could lead to an inflated AIPTW.
#  Maximum score =  0.9962659478187561
# G Model has been fit
# Q model has been fit
# Dropped 1004 observations due to overlap condition
# AIPTW model has been fit. Returning τ hat and its standard deviation
# τ hat = 0.00413, std = 0.00459, test statistic = 0.89981, p-value = 0.18415
#
# Running models for treatment valoilres_binarize and outcome onsetUCS on 2161 samples
#
# WARNING:
#  Some propensity scores are very small,
#  which could lead to an inflated AIPTW.
#  Minimum score =  0.008916233587506161
# G Model has been fit
# Q model has been fit
# AIPTW model has been fit. Returning τ hat and its standard deviation
# τ hat = 0.00661, std = 0.01164, test statistic = 0.56843, p-value = 0.2849
#
# Running models for treatment valoilres_binarize and outcome onsetUCS on 2161 samples
#
# WARNING:
#  Some propensity scores are very small,
#  which could lead to an inflated AIPTW.
#  Minimum score =  4.9739577661966905e-05
#
# WARNING:
#  Some propensity scores are very large,
#  which could lead to an inflated AIPTW.
#  Maximum score =  0.9976771473884583
# G Model has been fit
# Q model has been fit
# Dropped 973 observations due to overlap condition
# AIPTW model has been fit. Returning τ hat and its standard deviation
# τ hat = 0.02303, std = 0.01437, test statistic = 1.60301, p-value = 0.05454
#
# Running models for treatment valoilres_binarize and outcome coup on 2397 samples
#
# WARNING:
#  Some propensity scores are very small,
#  which could lead to an inflated AIPTW.
#  Minimum score =  0.008427323199612188
# G Model has been fit
# Q model has been fit
# AIPTW model has been fit. Returning τ hat and its standard deviation
# τ hat = -0.02411, std = 0.01436, test statistic = -1.67948, p-value = 0.04659
#
# Running models for treatment valoilres_binarize and outcome coup on 2397 samples
#
# WARNING:
#  Some propensity scores are very small,
#  which could lead to an inflated AIPTW.
#  Minimum score =  4.195065048406832e-05
#
# WARNING:
#  Some propensity scores are very large,
#  which could lead to an inflated AIPTW.
#  Maximum score =  0.9975312948226929
# G Model has been fit
# Q model has been fit
# Dropped 1025 observations due to overlap condition
# AIPTW model has been fit. Returning τ hat and its standard deviation
# τ hat = -0.03191, std = 0.02053, test statistic = -1.55416, p-value = 0.06014
#
# Running models for treatment valoilres_binarize and outcome periregular on 1393 samples
# G Model has been fit
# Q model has been fit
# AIPTW model has been fit. Returning τ hat and its standard deviation
# τ hat = -0.0056, std = 0.005, test statistic = -1.11965, p-value = 0.13153
#
# Running models for treatment valoilres_binarize and outcome periregular on 1393 samples
#
# WARNING:
#  Some propensity scores are very small,
#  which could lead to an inflated AIPTW.
#  Minimum score =  0.00020057761867064983
#
# WARNING:
#  Some propensity scores are very large,
#  which could lead to an inflated AIPTW.
#  Maximum score =  0.9961199760437012
# G Model has been fit
# Q model has been fit
# Dropped 505 observations due to overlap condition
# AIPTW model has been fit. Returning τ hat and its standard deviation
# τ hat = -0.0075, std = 0.00629, test statistic = -1.1921, p-value = 0.11671
#
# Running models for treatment valoilres_binarize and outcome milexp_pergdpSIPRI_diff on 809 samples
#
# WARNING:
#  Some propensity scores are very small,
#  which could lead to an inflated AIPTW.
#  Minimum score =  0.00355492795515152
# G Model has been fit
# Q model has been fit
# AIPTW model has been fit. Returning τ hat and its standard deviation
# τ hat = -0.00262, std = 0.02706, test statistic = -0.09681, p-value = 0.46145
#
# Running models for treatment valoilres_binarize and outcome milexp_pergdpSIPRI_diff on 809 samples
#
# WARNING:
#  Some propensity scores are very small,
#  which could lead to an inflated AIPTW.
#  Minimum score =  4.8033700295491144e-05
#
# WARNING:
#  Some propensity scores are very large,
#  which could lead to an inflated AIPTW.
#  Maximum score =  0.9988583326339722
# G Model has been fit
# Q model has been fit
# Dropped 542 observations due to overlap condition
# AIPTW model has been fit. Returning τ hat and its standard deviation
# τ hat = -0.01444, std = 0.03726, test statistic = -0.3876, p-value = 0.34921
#
# Running models for treatment valoilres_public_binarize and outcome onset2COWCS on 2047 samples
# G Model has been fit
# Q model has been fit
# AIPTW model has been fit. Returning τ hat and its standard deviation
# τ hat = -0.00147, std = 0.00453, test statistic = -0.32381, p-value = 0.37306
#
# Running models for treatment valoilres_public_binarize and outcome onset2COWCS on 2047 samples
#
# WARNING:
#  Some propensity scores are very small,
#  which could lead to an inflated AIPTW.
#  Minimum score =  0.00024992902763187885
#
# WARNING:
#  Some propensity scores are very large,
#  which could lead to an inflated AIPTW.
#  Maximum score =  0.9923778772354126
# G Model has been fit
# Q model has been fit
# Dropped 485 observations due to overlap condition
# AIPTW model has been fit. Returning τ hat and its standard deviation
# τ hat = 0.00618, std = 0.00468, test statistic = 1.32039, p-value = 0.09343
#
# Running models for treatment valoilres_public_binarize and outcome onsetUCS on 1941 samples
# G Model has been fit
# Q model has been fit
# AIPTW model has been fit. Returning τ hat and its standard deviation
# τ hat = 0.00617, std = 0.00972, test statistic = 0.63513, p-value = 0.26271
#
# Running models for treatment valoilres_public_binarize and outcome onsetUCS on 1941 samples
#
# WARNING:
#  Some propensity scores are very small,
#  which could lead to an inflated AIPTW.
#  Minimum score =  0.0002074136573355645
#
# WARNING:
#  Some propensity scores are very large,
#  which could lead to an inflated AIPTW.
#  Maximum score =  0.9952078461647034
# G Model has been fit
# Q model has been fit
# Dropped 491 observations due to overlap condition
# AIPTW model has been fit. Returning τ hat and its standard deviation
# τ hat = 0.00556, std = 0.02233, test statistic = 0.24904, p-value = 0.40168
#
# Running models for treatment valoilres_public_binarize and outcome coup on 2165 samples
# G Model has been fit
# Q model has been fit
# AIPTW model has been fit. Returning τ hat and its standard deviation
# τ hat = -0.01822, std = 0.0105, test statistic = -1.73604, p-value = 0.04135
#
# Running models for treatment valoilres_public_binarize and outcome coup on 2165 samples
#
# WARNING:
#  Some propensity scores are very small,
#  which could lead to an inflated AIPTW.
#  Minimum score =  0.00028605660190805793
#
# WARNING:
#  Some propensity scores are very large,
#  which could lead to an inflated AIPTW.
#  Maximum score =  0.9950893521308899
# G Model has been fit
# Q model has been fit
# Dropped 470 observations due to overlap condition
# AIPTW model has been fit. Returning τ hat and its standard deviation
# τ hat = -0.00478, std = 0.0251, test statistic = -0.19025, p-value = 0.42457
#
# Running models for treatment valoilres_public_binarize and outcome periregular on 948 samples
# G Model has been fit
# Q model has been fit
# AIPTW model has been fit. Returning τ hat and its standard deviation
# τ hat = -0.00615, std = 0.0069, test statistic = -0.89105, p-value = 0.18656
#
# Running models for treatment valoilres_public_binarize and outcome periregular on 948 samples
#
# WARNING:
#  Some propensity scores are very small,
#  which could lead to an inflated AIPTW.
#  Minimum score =  0.0006143928621895611
#
# WARNING:
#  Some propensity scores are very large,
#  which could lead to an inflated AIPTW.
#  Maximum score =  0.9946473240852356
# G Model has been fit
# Q model has been fit
# Dropped 141 observations due to overlap condition
# AIPTW model has been fit. Returning τ hat and its standard deviation
# τ hat = 0.00048, std = 0.00865, test statistic = 0.05504, p-value = 0.47806
#
# Running models for treatment valoilres_public_binarize and outcome milexp_pergdpSIPRI_diff on 800 samples
#
# WARNING:
#  Some propensity scores are very small,
#  which could lead to an inflated AIPTW.
#  Minimum score =  0.005232901503310501
# G Model has been fit
# Q model has been fit
# AIPTW model has been fit. Returning τ hat and its standard deviation
# τ hat = -0.00406, std = 0.02746, test statistic = -0.14794, p-value = 0.44121
#
# Running models for treatment valoilres_public_binarize and outcome milexp_pergdpSIPRI_diff on 800 samples
#
# WARNING:
#  Some propensity scores are very small,
#  which could lead to an inflated AIPTW.
#  Minimum score =  5.154095924808644e-05
#
# WARNING:
#  Some propensity scores are very large,
#  which could lead to an inflated AIPTW.
#  Maximum score =  0.9934331178665161
# G Model has been fit
# Q model has been fit
# Dropped 385 observations due to overlap condition
# AIPTW model has been fit. Returning τ hat and its standard deviation
# τ hat = 0.036, std = 0.08565, test statistic = 0.4203, p-value = 0.33719
#
# Running models for treatment oilpop_binarize and outcome onset2COWCS on 2500 samples
#
# WARNING:
#  Some propensity scores are very small,
#  which could lead to an inflated AIPTW.
#  Minimum score =  0.0032957646069298185
# G Model has been fit
# Q model has been fit
# AIPTW model has been fit. Returning τ hat and its standard deviation
# τ hat = -0.00886, std = 0.00356, test statistic = -2.4908, p-value = 0.00641
#
# Running models for treatment oilpop_binarize and outcome onset2COWCS on 2500 samples
#
# WARNING:
#  Some propensity scores are very small,
#  which could lead to an inflated AIPTW.
#  Minimum score =  0.0001168881353805773
# G Model has been fit
# Q model has been fit
# AIPTW model has been fit. Returning τ hat and its standard deviation
# τ hat = -0.00924, std = 0.00445, test statistic = -2.07587, p-value = 0.019
#
# Running models for treatment oilpop_binarize and outcome onsetUCS on 2161 samples
#
# WARNING:
#  Some propensity scores are very small,
#  which could lead to an inflated AIPTW.
#  Minimum score =  0.00305701010274954
# G Model has been fit
# Q model has been fit
# AIPTW model has been fit. Returning τ hat and its standard deviation
# τ hat = 0.0183, std = 0.01737, test statistic = 1.05393, p-value = 0.14602
#
# Running models for treatment oilpop_binarize and outcome onsetUCS on 2161 samples
#
# WARNING:
#  Some propensity scores are very small,
#  which could lead to an inflated AIPTW.
#  Minimum score =  0.0001068098281393759
# G Model has been fit
# Q model has been fit
# AIPTW model has been fit. Returning τ hat and its standard deviation
# τ hat = 0.03035, std = 0.01884, test statistic = 1.61075, p-value = 0.05369
#
# Running models for treatment oilpop_binarize and outcome coup on 2397 samples
#
# WARNING:
#  Some propensity scores are very small,
#  which could lead to an inflated AIPTW.
#  Minimum score =  0.004063683490097784
# G Model has been fit
# Q model has been fit
# AIPTW model has been fit. Returning τ hat and its standard deviation
# τ hat = -0.00897, std = 0.0263, test statistic = -0.34096, p-value = 0.36658
#
# Running models for treatment oilpop_binarize and outcome coup on 2397 samples
#
# WARNING:
#  Some propensity scores are very small,
#  which could lead to an inflated AIPTW.
#  Minimum score =  0.00021702876256313175
# G Model has been fit
# Q model has been fit
# AIPTW model has been fit. Returning τ hat and its standard deviation
# τ hat = -0.01897, std = 0.03357, test statistic = -0.56512, p-value = 0.28602
#
# Running models for treatment oilpop_binarize and outcome periregular on 1393 samples
#
# WARNING:
#  Some propensity scores are very small,
#  which could lead to an inflated AIPTW.
#  Minimum score =  0.004879737611092174
# G Model has been fit
# Q model has been fit
# AIPTW model has been fit. Returning τ hat and its standard deviation
# τ hat = 0.00248, std = 0.00678, test statistic = 0.36559, p-value = 0.35736
#
# Running models for treatment oilpop_binarize and outcome periregular on 1393 samples
#
# WARNING:
#  Some propensity scores are very small,
#  which could lead to an inflated AIPTW.
#  Minimum score =  0.00025406578788533807
# G Model has been fit
# Q model has been fit
# AIPTW model has been fit. Returning τ hat and its standard deviation
# τ hat = 0.01659, std = 0.00873, test statistic = 1.90164, p-value = 0.02871
#
# Running models for treatment oilpop_binarize and outcome milexp_pergdpSIPRI_diff on 809 samples
#
# WARNING:
#  Some propensity scores are very small,
#  which could lead to an inflated AIPTW.
#  Minimum score =  0.0
# G Model has been fit
# Q model has been fit
# AIPTW model has been fit. Returning τ hat and its standard deviation
# τ hat = 0.09921, std = 0.08729, test statistic = 1.13659, p-value = 0.12802
#
# Running models for treatment oilpop_binarize and outcome milexp_pergdpSIPRI_diff on 809 samples
#
# WARNING:
#  Some propensity scores are very small,
#  which could lead to an inflated AIPTW.
#  Minimum score =  7.458971958840266e-05
# G Model has been fit
# Q model has been fit
# AIPTW model has been fit. Returning τ hat and its standard deviation
# τ hat = 0.10492, std = 0.08698, test statistic = 1.20636, p-value = 0.11402
#
# Running models for treatment valoilres_impute_binarize and outcome onset2COWCS on 2500 samples
#
# WARNING:
#  Some propensity scores are very small,
#  which could lead to an inflated AIPTW.
#  Minimum score =  0.007527698168778344
# G Model has been fit
# Q model has been fit
# AIPTW model has been fit. Returning τ hat and its standard deviation
# τ hat = -0.00178, std = 0.00386, test statistic = -0.46105, p-value = 0.3224
#
# Running models for treatment valoilres_impute_binarize and outcome onset2COWCS on 2500 samples
#
# WARNING:
#  Some propensity scores are very small,
#  which could lead to an inflated AIPTW.
#  Minimum score =  4.638819154934026e-05
#
# WARNING:
#  Some propensity scores are very large,
#  which could lead to an inflated AIPTW.
#  Maximum score =  0.9975912570953369
# G Model has been fit
# Q model has been fit
# Dropped 940 observations due to overlap condition
# AIPTW model has been fit. Returning τ hat and its standard deviation
# τ hat = 0.00312, std = 0.00387, test statistic = 0.80492, p-value = 0.21047
#
# Running models for treatment valoilres_impute_binarize and outcome onsetUCS on 2161 samples
#
# WARNING:
#  Some propensity scores are very small,
#  which could lead to an inflated AIPTW.
#  Minimum score =  0.007663735434489807
# G Model has been fit
# Q model has been fit
# AIPTW model has been fit. Returning τ hat and its standard deviation
# τ hat = 0.01099, std = 0.0106, test statistic = 1.03671, p-value = 0.14999
#
# Running models for treatment valoilres_impute_binarize and outcome onsetUCS on 2161 samples
#
# WARNING:
#  Some propensity scores are very small,
#  which could lead to an inflated AIPTW.
#  Minimum score =  6.789651524741203e-05
#
# WARNING:
#  Some propensity scores are very large,
#  which could lead to an inflated AIPTW.
#  Maximum score =  0.9973801970481873
# G Model has been fit
# Q model has been fit
# Dropped 864 observations due to overlap condition
# AIPTW model has been fit. Returning τ hat and its standard deviation
# τ hat = 0.02616, std = 0.01207, test statistic = 2.16717, p-value = 0.01517
#
# Running models for treatment valoilres_impute_binarize and outcome coup on 2397 samples
#
# WARNING:
#  Some propensity scores are very small,
#  which could lead to an inflated AIPTW.
#  Minimum score =  0.008517169238639315
# G Model has been fit
# Q model has been fit
# AIPTW model has been fit. Returning τ hat and its standard deviation
# τ hat = -0.01984, std = 0.01281, test statistic = -1.54965, p-value = 0.06068
#
# Running models for treatment valoilres_impute_binarize and outcome coup on 2397 samples
#
# WARNING:
#  Some propensity scores are very small,
#  which could lead to an inflated AIPTW.
#  Minimum score =  4.845896182814613e-05
#
# WARNING:
#  Some propensity scores are very large,
#  which could lead to an inflated AIPTW.
#  Maximum score =  0.9977303147315979
# G Model has been fit
# Q model has been fit
# Dropped 966 observations due to overlap condition
# AIPTW model has been fit. Returning τ hat and its standard deviation
# τ hat = -0.02016, std = 0.01563, test statistic = -1.28982, p-value = 0.09862
#
# Running models for treatment valoilres_impute_binarize and outcome periregular on 1393 samples
# G Model has been fit
# Q model has been fit
# AIPTW model has been fit. Returning τ hat and its standard deviation
# τ hat = -0.00604, std = 0.00504, test statistic = -1.19707, p-value = 0.11574
#
# Running models for treatment valoilres_impute_binarize and outcome periregular on 1393 samples
#
# WARNING:
#  Some propensity scores are very small,
#  which could lead to an inflated AIPTW.
#  Minimum score =  0.00020057761867064983
#
# WARNING:
#  Some propensity scores are very large,
#  which could lead to an inflated AIPTW.
#  Maximum score =  0.9961199760437012
# G Model has been fit
# Q model has been fit
# Dropped 505 observations due to overlap condition
# AIPTW model has been fit. Returning τ hat and its standard deviation
# τ hat = -0.0075, std = 0.00629, test statistic = -1.1921, p-value = 0.11671
#
# Running models for treatment valoilres_impute_binarize and outcome milexp_pergdpSIPRI_diff on 809 samples
#
# WARNING:
#  Some propensity scores are very small,
#  which could lead to an inflated AIPTW.
#  Minimum score =  0.0053969455397173925
# G Model has been fit
# Q model has been fit
# AIPTW model has been fit. Returning τ hat and its standard deviation
# τ hat = -0.00354, std = 0.02731, test statistic = -0.12968, p-value = 0.44842
#
# Running models for treatment valoilres_impute_binarize and outcome milexp_pergdpSIPRI_diff on 809 samples
#
# WARNING:
#  Some propensity scores are very small,
#  which could lead to an inflated AIPTW.
#  Minimum score =  4.8033700295491144e-05
#
# WARNING:
#  Some propensity scores are very large,
#  which could lead to an inflated AIPTW.
#  Maximum score =  0.9988583326339722
# G Model has been fit
# Q model has been fit
# Dropped 542 observations due to overlap condition
# AIPTW model has been fit. Returning τ hat and its standard deviation
# τ hat = -0.01444, std = 0.03726, test statistic = -0.3876, p-value = 0.34921
#
# Running models for treatment oilpop_impute_binarize and outcome onset2COWCS on 2500 samples
#
# WARNING:
#  Some propensity scores are very small,
#  which could lead to an inflated AIPTW.
#  Minimum score =  0.005480978395211008
# G Model has been fit
# Q model has been fit
# AIPTW model has been fit. Returning τ hat and its standard deviation
# τ hat = -0.00912, std = 0.00369, test statistic = -2.47516, p-value = 0.00669
#
# Running models for treatment oilpop_impute_binarize and outcome onset2COWCS on 2500 samples
#
# WARNING:
#  Some propensity scores are very small,
#  which could lead to an inflated AIPTW.
#  Minimum score =  0.00013443976058624685
# G Model has been fit
# Q model has been fit
# AIPTW model has been fit. Returning τ hat and its standard deviation
# τ hat = -0.00671, std = 0.0041, test statistic = -1.63729, p-value = 0.05085
#
# Running models for treatment oilpop_impute_binarize and outcome onsetUCS on 2161 samples
#
# WARNING:
#  Some propensity scores are very small,
#  which could lead to an inflated AIPTW.
#  Minimum score =  0.004036197876556465
# G Model has been fit
# Q model has been fit
# AIPTW model has been fit. Returning τ hat and its standard deviation
# τ hat = 0.01576, std = 0.01642, test statistic = 0.95968, p-value = 0.16866
#
# Running models for treatment oilpop_impute_binarize and outcome onsetUCS on 2161 samples
#
# WARNING:
#  Some propensity scores are very small,
#  which could lead to an inflated AIPTW.
#  Minimum score =  0.00015571857511531562
# G Model has been fit
# Q model has been fit
# AIPTW model has been fit. Returning τ hat and its standard deviation
# τ hat = 0.02711, std = 0.0176, test statistic = 1.54082, p-value = 0.06175
#
# Running models for treatment oilpop_impute_binarize and outcome coup on 2397 samples
#
# WARNING:
#  Some propensity scores are very small,
#  which could lead to an inflated AIPTW.
#  Minimum score =  0.006303918380598971
# G Model has been fit
# Q model has been fit
# AIPTW model has been fit. Returning τ hat and its standard deviation
# τ hat = -0.00312, std = 0.02355, test statistic = -0.13231, p-value = 0.44738
#
# Running models for treatment oilpop_impute_binarize and outcome coup on 2397 samples
#
# WARNING:
#  Some propensity scores are very small,
#  which could lead to an inflated AIPTW.
#  Minimum score =  0.00022243840794544667
# G Model has been fit
# Q model has been fit
# AIPTW model has been fit. Returning τ hat and its standard deviation
# τ hat = -0.02391, std = 0.03364, test statistic = -0.71075, p-value = 0.23865
#
# Running models for treatment oilpop_impute_binarize and outcome periregular on 1393 samples
#
# WARNING:
#  Some propensity scores are very small,
#  which could lead to an inflated AIPTW.
#  Minimum score =  0.003389535205313512
# G Model has been fit
# Q model has been fit
# AIPTW model has been fit. Returning τ hat and its standard deviation
# τ hat = 0.00288, std = 0.00679, test statistic = 0.42374, p-value = 0.33591
#
# Running models for treatment oilpop_impute_binarize and outcome periregular on 1393 samples
#
# WARNING:
#  Some propensity scores are very small,
#  which could lead to an inflated AIPTW.
#  Minimum score =  0.00025406578788533807
# G Model has been fit
# Q model has been fit
# AIPTW model has been fit. Returning τ hat and its standard deviation
# τ hat = 0.01659, std = 0.00873, test statistic = 1.90164, p-value = 0.02871
#
# Running models for treatment oilpop_impute_binarize and outcome milexp_pergdpSIPRI_diff on 809 samples
#
# WARNING:
#  Some propensity scores are very small,
#  which could lead to an inflated AIPTW.
#  Minimum score =  0.0
# G Model has been fit
# Q model has been fit
# AIPTW model has been fit. Returning τ hat and its standard deviation
# τ hat = 0.11589, std = 0.08639, test statistic = 1.34148, p-value = 0.09007
#
# Running models for treatment oilpop_impute_binarize and outcome milexp_pergdpSIPRI_diff on 809 samples
#
# WARNING:
#  Some propensity scores are very small,
#  which could lead to an inflated AIPTW.
#  Minimum score =  7.458971958840266e-05
# G Model has been fit
# Q model has been fit
# AIPTW model has been fit. Returning τ hat and its standard deviation
# τ hat = 0.10492, std = 0.08698, test statistic = 1.20636, p-value = 0.11402

# %%
att_results_df
# Out:
#    model                  treatment                  outcome   tau_hat  \
# 0     rf         valoilres_binarize              onset2COWCS -0.001773
# 1    xgb         valoilres_binarize              onset2COWCS  0.004131
# 2     rf         valoilres_binarize                 onsetUCS  0.006615
# 3    xgb         valoilres_binarize                 onsetUCS  0.023033
# 4     rf         valoilres_binarize                     coup -0.024113
# 5    xgb         valoilres_binarize                     coup -0.031912
# 6     rf         valoilres_binarize              periregular -0.005601
# 7    xgb         valoilres_binarize              periregular -0.007497
# 8     rf         valoilres_binarize  milexp_pergdpSIPRI_diff -0.002620
# 9    xgb         valoilres_binarize  milexp_pergdpSIPRI_diff -0.014442
# 10    rf  valoilres_public_binarize              onset2COWCS -0.001465
# 11   xgb  valoilres_public_binarize              onset2COWCS  0.006176
# 12    rf  valoilres_public_binarize                 onsetUCS  0.006171
# 13   xgb  valoilres_public_binarize                 onsetUCS  0.005561
# 14    rf  valoilres_public_binarize                     coup -0.018223
# 15   xgb  valoilres_public_binarize                     coup -0.004776
# 16    rf  valoilres_public_binarize              periregular -0.006149
# 17   xgb  valoilres_public_binarize              periregular  0.000476
# 18    rf  valoilres_public_binarize  milexp_pergdpSIPRI_diff -0.004063
# 19   xgb  valoilres_public_binarize  milexp_pergdpSIPRI_diff  0.035999
# 20    rf            oilpop_binarize              onset2COWCS -0.008857
# 21   xgb            oilpop_binarize              onset2COWCS -0.009242
# 22    rf            oilpop_binarize                 onsetUCS  0.018302
# 23   xgb            oilpop_binarize                 onsetUCS  0.030346
# 24    rf            oilpop_binarize                     coup -0.008966
# 25   xgb            oilpop_binarize                     coup -0.018970
# 26    rf            oilpop_binarize              periregular  0.002480
# 27   xgb            oilpop_binarize              periregular  0.016594
# 28    rf            oilpop_binarize  milexp_pergdpSIPRI_diff  0.099212
# 29   xgb            oilpop_binarize  milexp_pergdpSIPRI_diff  0.104924
# 30    rf  valoilres_impute_binarize              onset2COWCS -0.001780
# 31   xgb  valoilres_impute_binarize              onset2COWCS  0.003119
# 32    rf  valoilres_impute_binarize                 onsetUCS  0.010991
# 33   xgb  valoilres_impute_binarize                 onsetUCS  0.026158
# 34    rf  valoilres_impute_binarize                     coup -0.019845
# 35   xgb  valoilres_impute_binarize                     coup -0.020158
# 36    rf  valoilres_impute_binarize              periregular -0.006037
# 37   xgb  valoilres_impute_binarize              periregular -0.007497
# 38    rf  valoilres_impute_binarize  milexp_pergdpSIPRI_diff -0.003541
# 39   xgb  valoilres_impute_binarize  milexp_pergdpSIPRI_diff -0.014442
# 40    rf     oilpop_impute_binarize              onset2COWCS -0.009123
# 41   xgb     oilpop_impute_binarize              onset2COWCS -0.006709
# 42    rf     oilpop_impute_binarize                 onsetUCS  0.015756
# 43   xgb     oilpop_impute_binarize                 onsetUCS  0.027115
# 44    rf     oilpop_impute_binarize                     coup -0.003116
# 45   xgb     oilpop_impute_binarize                     coup -0.023910
# 46    rf     oilpop_impute_binarize              periregular  0.002879
# 47   xgb     oilpop_impute_binarize              periregular  0.016594
# 48    rf     oilpop_impute_binarize  milexp_pergdpSIPRI_diff  0.115888
# 49   xgb     oilpop_impute_binarize  milexp_pergdpSIPRI_diff  0.104924
#
#      tau_std  test_stat   p_value
# 0   0.004407  -0.402262  0.343763
# 1   0.004591   0.899809  0.184154
# 2   0.011637   0.568430  0.284901
# 3   0.014369   1.603007  0.054540
# 4   0.014357  -1.679476  0.046595
# 5   0.020533  -1.554155  0.060140
# 6   0.005003  -1.119648  0.131528
# 7   0.006289  -1.192095  0.116714
# 8   0.027062  -0.096813  0.461449
# 9   0.037261  -0.387598  0.349208
# 10  0.004526  -0.323807  0.373059
# 11  0.004677   1.320385  0.093427
# 12  0.009717   0.635131  0.262709
# 13  0.022328   0.249043  0.401677
# 14  0.010497  -1.736039  0.041350
# 15  0.025104  -0.190246  0.424567
# 16  0.006901  -0.891049  0.186565
# 17  0.008647   0.055038  0.478060
# 18  0.027463  -0.147939  0.441214
# 19  0.085652   0.420298  0.337190
# 20  0.003556  -2.490800  0.006405
# 21  0.004452  -2.075868  0.019004
# 22  0.017365   1.053932  0.146016
# 23  0.018839   1.610750  0.053690
# 24  0.026297  -0.340955  0.366584
# 25  0.033568  -0.565115  0.286024
# 26  0.006782   0.365595  0.357362
# 27  0.008726   1.901643  0.028712
# 28  0.087289   1.136590  0.128023
# 29  0.086976   1.206360  0.114016
# 30  0.003860  -0.461053  0.322400
# 31  0.003875   0.804916  0.210472
# 32  0.010602   1.036713  0.149993
# 33  0.012070   2.167167  0.015166
# 34  0.012806  -1.549647  0.060679
# 35  0.015628  -1.289824  0.098618
# 36  0.005043  -1.197066  0.115742
# 37  0.006289  -1.192095  0.116714
# 38  0.027305  -0.129685  0.448424
# 39  0.037261  -0.387598  0.349208
# 40  0.003686  -2.475159  0.006692
# 41  0.004098  -1.637288  0.050848
# 42  0.016418   0.959683  0.168661
# 43  0.017598   1.540817  0.061754
# 44  0.023551  -0.132307  0.447376
# 45  0.033640  -0.710749  0.238654
# 46  0.006794   0.423740  0.335910
# 47  0.008726   1.901643  0.028712
# 48  0.086389   1.341478  0.090071
# 49  0.086976   1.206360  0.114016

# %%
att_results_df.loc[[0, 1, 4, 5, 6, 7, 12, 13, 26, 27, 30, 31], :].sort_values(by=['outcome', 'treatment', 'model']).reset_index(drop=True)
# Out:
#    model                  treatment      outcome   tau_hat   tau_std  \
# 0     rf         valoilres_binarize         coup -0.024113  0.014357
# 1    xgb         valoilres_binarize         coup -0.031912  0.020533
# 2     rf         valoilres_binarize  onset2COWCS -0.001773  0.004407
# 3    xgb         valoilres_binarize  onset2COWCS  0.004131  0.004591
# 4     rf  valoilres_impute_binarize  onset2COWCS -0.001780  0.003860
# 5    xgb  valoilres_impute_binarize  onset2COWCS  0.003119  0.003875
# 6     rf  valoilres_public_binarize     onsetUCS  0.006171  0.009717
# 7    xgb  valoilres_public_binarize     onsetUCS  0.005561  0.022328
# 8     rf            oilpop_binarize  periregular  0.002480  0.006782
# 9    xgb            oilpop_binarize  periregular  0.016594  0.008726
# 10    rf         valoilres_binarize  periregular -0.005601  0.005003
# 11   xgb         valoilres_binarize  periregular -0.007497  0.006289
#
#     test_stat   p_value
# 0   -1.679476  0.046595
# 1   -1.554155  0.060140
# 2   -0.402262  0.343763
# 3    0.899809  0.184154
# 4   -0.461053  0.322400
# 5    0.804916  0.210472
# 6    0.635131  0.262709
# 7    0.249043  0.401677
# 8    0.365595  0.357362
# 9    1.901643  0.028712
# 10  -1.119648  0.131528
# 11  -1.192095  0.116714

# %%
att_temp = att_results_df[(att_results_df['treatment'] == 'valoilres_binarize') | (att_results_df['treatment'] == 'oilpop_binarize')].reset_index(drop=True)

# %%
att_temp[att_temp['outcome'].isin(['onset2COWCS', 'coup', 'periregular', 'milexp_pergdpSIPRI_diff'])].sort_values(by=['outcome', 'treatment', 'model']).reset_index(drop=True)
# Out:
#    model           treatment                  outcome   tau_hat   tau_std  \
# 0     rf     oilpop_binarize                     coup -0.008966  0.026297
# 1    xgb     oilpop_binarize                     coup -0.018970  0.033568
# 2     rf  valoilres_binarize                     coup -0.024113  0.014357
# 3    xgb  valoilres_binarize                     coup -0.031912  0.020533
# 4     rf     oilpop_binarize  milexp_pergdpSIPRI_diff  0.099212  0.087289
# 5    xgb     oilpop_binarize  milexp_pergdpSIPRI_diff  0.104924  0.086976
# 6     rf  valoilres_binarize  milexp_pergdpSIPRI_diff -0.002620  0.027062
# 7    xgb  valoilres_binarize  milexp_pergdpSIPRI_diff -0.014442  0.037261
# 8     rf     oilpop_binarize              onset2COWCS -0.008857  0.003556
# 9    xgb     oilpop_binarize              onset2COWCS -0.009242  0.004452
# 10    rf  valoilres_binarize              onset2COWCS -0.001773  0.004407
# 11   xgb  valoilres_binarize              onset2COWCS  0.004131  0.004591
# 12    rf     oilpop_binarize              periregular  0.002480  0.006782
# 13   xgb     oilpop_binarize              periregular  0.016594  0.008726
# 14    rf  valoilres_binarize              periregular -0.005601  0.005003
# 15   xgb  valoilres_binarize              periregular -0.007497  0.006289
#
#     test_stat   p_value
# 0   -0.340955  0.366584
# 1   -0.565115  0.286024
# 2   -1.679476  0.046595
# 3   -1.554155  0.060140
# 4    1.136590  0.128023
# 5    1.206360  0.114016
# 6   -0.096813  0.461449
# 7   -0.387598  0.349208
# 8   -2.490800  0.006405
# 9   -2.075868  0.019004
# 10  -0.402262  0.343763
# 11   0.899809  0.184154
# 12   0.365595  0.357362
# 13   1.901643  0.028712
# 14  -1.119648  0.131528
# 15  -1.192095  0.116714

# %%
att_results_df[att_results_df['p_value'] < .05]
# Out:
#    model                  treatment      outcome   tau_hat   tau_std  \
# 4     rf         valoilres_binarize         coup -0.024113  0.014357
# 14    rf  valoilres_public_binarize         coup -0.018223  0.010497
# 20    rf            oilpop_binarize  onset2COWCS -0.008857  0.003556
# 21   xgb            oilpop_binarize  onset2COWCS -0.009242  0.004452
# 27   xgb            oilpop_binarize  periregular  0.016594  0.008726
# 33   xgb  valoilres_impute_binarize     onsetUCS  0.026158  0.012070
# 40    rf     oilpop_impute_binarize  onset2COWCS -0.009123  0.003686
# 47   xgb     oilpop_impute_binarize  periregular  0.016594  0.008726
#
#     test_stat   p_value
# 4   -1.679476  0.046595
# 14  -1.736039  0.041350
# 20  -2.490800  0.006405
# 21  -2.075868  0.019004
# 27   1.901643  0.028712
# 33   2.167167  0.015166
# 40  -2.475159  0.006692
# 47   1.901643  0.028712

# %%
treatment_lst = ['newdiscovery_aspo_binarize']
outcome_lst = ['d2incidenceU',
               'd3_6incidenceU',
               'onset2COWCS',
               'onsetUCS',
               'coup',
               'periregular',
               'milexp_pergdpSIPRI_diff']
confoundes = ['crude1990P_diff',
               'wildcat_diff',
               'out_regdisaster_diff',
               'ecgrowth',
               'pop_maddison_diff',
               'popdens_diff',
               'democracy_diff',
               'logmountain',
               'ethnic_fractionalization',
               'religion_fractionalization',
               'language_fractionalization',
               'leg_british',
               'decade',
               'opec']

# %%
df_dict = {'model': [], 'treatment': [], 'outcome': [], 'tau_hat': [], 'tau_std': [], 'test_stat': [], 'p_value': []}
for treat in treatment_lst:
    for out in outcome_lst:
        for model_type in ['rf', 'xgb']:
            if len(oil_df[out].value_counts()) == 2:
                output = 'binary'
            else:
                output = 'continuous'
            if model_type == 'rf':
                tau_hat, tau_std, test_stat, p_value = fit_and_run_model(oil_df, out, treat, confounders, make_g_model, make_Q_model, output_type=output, ate=False)
            else:
                tau_hat, tau_std, test_stat, p_value = fit_and_run_model(oil_df, out, treat, confounders, make_xgboost_g_model, make_xgboost_Q_model, output_type=output, ate=False)
            df_dict['model'].append(model_type)
            df_dict['treatment'].append(treat)
            df_dict['outcome'].append(out)
            df_dict['tau_hat'].append(tau_hat)
            df_dict['tau_std'].append(tau_std)
            df_dict['test_stat'].append(test_stat)
            df_dict['p_value'].append(p_value)

att_discovery_results_df = pd.DataFrame(data=df_dict)
# Out:
# Running models for treatment newdiscovery_aspo_binarize and outcome d2incidenceU on 1269 samples
# G Model has been fit
# Q model has been fit
# AIPTW model has been fit. Returning τ hat and its standard deviation
# τ hat = -0.00189, std = 0.01647, test statistic = -0.11477, p-value = 0.45432
#
# Running models for treatment newdiscovery_aspo_binarize and outcome d2incidenceU on 1269 samples
#
# WARNING:
#  Some propensity scores are very small,
#  which could lead to an inflated AIPTW.
#  Minimum score =  0.005891613196581602
#
# WARNING:
#  Some propensity scores are very large,
#  which could lead to an inflated AIPTW.
#  Maximum score =  0.9987645149230957
# G Model has been fit
# Q model has been fit
# Dropped 51 observations due to overlap condition
# AIPTW model has been fit. Returning τ hat and its standard deviation
# τ hat = -0.0102, std = 0.02517, test statistic = -0.40512, p-value = 0.34273
#
# Running models for treatment newdiscovery_aspo_binarize and outcome d3_6incidenceU on 1238 samples
# G Model has been fit
# Q model has been fit
# AIPTW model has been fit. Returning τ hat and its standard deviation
# τ hat = -0.05811, std = 0.02462, test statistic = -2.36078, p-value = 0.0092
#
# Running models for treatment newdiscovery_aspo_binarize and outcome d3_6incidenceU on 1238 samples
#
# WARNING:
#  Some propensity scores are very small,
#  which could lead to an inflated AIPTW.
#  Minimum score =  0.0025601547677069902
#
# WARNING:
#  Some propensity scores are very large,
#  which could lead to an inflated AIPTW.
#  Maximum score =  0.9981368780136108
# G Model has been fit
# Q model has been fit
# Dropped 54 observations due to overlap condition
# AIPTW model has been fit. Returning τ hat and its standard deviation
# τ hat = -0.11105, std = 0.0769, test statistic = -1.44416, p-value = 0.07447
#
# Running models for treatment newdiscovery_aspo_binarize and outcome onset2COWCS on 2371 samples
# G Model has been fit
# Q model has been fit
# AIPTW model has been fit. Returning τ hat and its standard deviation
# τ hat = 0.0003, std = 0.00481, test statistic = 0.06209, p-value = 0.47525
#
# Running models for treatment newdiscovery_aspo_binarize and outcome onset2COWCS on 2371 samples
#
# WARNING:
#  Some propensity scores are very small,
#  which could lead to an inflated AIPTW.
#  Minimum score =  0.001027289079502225
#
# WARNING:
#  Some propensity scores are very large,
#  which could lead to an inflated AIPTW.
#  Maximum score =  0.9927576780319214
# G Model has been fit
# Q model has been fit
# Dropped 199 observations due to overlap condition
# AIPTW model has been fit. Returning τ hat and its standard deviation
# τ hat = -0.01057, std = 0.01825, test statistic = -0.57899, p-value = 0.28132
#
# Running models for treatment newdiscovery_aspo_binarize and outcome onsetUCS on 2030 samples
# G Model has been fit
# Q model has been fit
# AIPTW model has been fit. Returning τ hat and its standard deviation
# τ hat = 0.01072, std = 0.0087, test statistic = 1.23228, p-value = 0.10899
#
# Running models for treatment newdiscovery_aspo_binarize and outcome onsetUCS on 2030 samples
#
# WARNING:
#  Some propensity scores are very small,
#  which could lead to an inflated AIPTW.
#  Minimum score =  0.001826913096010685
#
# WARNING:
#  Some propensity scores are very large,
#  which could lead to an inflated AIPTW.
#  Maximum score =  0.9956300258636475
# G Model has been fit
# Q model has been fit
# Dropped 135 observations due to overlap condition
# AIPTW model has been fit. Returning τ hat and its standard deviation
# τ hat = 0.00346, std = 0.02125, test statistic = 0.16288, p-value = 0.43531
#
# Running models for treatment newdiscovery_aspo_binarize and outcome coup on 2248 samples
# G Model has been fit
# Q model has been fit
# AIPTW model has been fit. Returning τ hat and its standard deviation
# τ hat = -0.00777, std = 0.00983, test statistic = -0.79068, p-value = 0.21461
#
# Running models for treatment newdiscovery_aspo_binarize and outcome coup on 2248 samples
#
# WARNING:
#  Some propensity scores are very small,
#  which could lead to an inflated AIPTW.
#  Minimum score =  0.0016018837923184037
#
# WARNING:
#  Some propensity scores are very large,
#  which could lead to an inflated AIPTW.
#  Maximum score =  0.9971693158149719
# G Model has been fit
# Q model has been fit
# Dropped 155 observations due to overlap condition
# AIPTW model has been fit. Returning τ hat and its standard deviation
# τ hat = -0.03719, std = 0.0506, test statistic = -0.73497, p-value = 0.23122
#
# Running models for treatment newdiscovery_aspo_binarize and outcome periregular on 1393 samples
# G Model has been fit
# Q model has been fit
# AIPTW model has been fit. Returning τ hat and its standard deviation
# τ hat = -0.00435, std = 0.00401, test statistic = -1.0868, p-value = 0.13866
#
# Running models for treatment newdiscovery_aspo_binarize and outcome periregular on 1393 samples
#
# WARNING:
#  Some propensity scores are very small,
#  which could lead to an inflated AIPTW.
#  Minimum score =  0.00047258162521757185
#
# WARNING:
#  Some propensity scores are very large,
#  which could lead to an inflated AIPTW.
#  Maximum score =  0.9975013136863708
# G Model has been fit
# Q model has been fit
# Dropped 227 observations due to overlap condition
# AIPTW model has been fit. Returning τ hat and its standard deviation
# τ hat = 0.00799, std = 0.01599, test statistic = 0.49979, p-value = 0.30865
#
# Running models for treatment newdiscovery_aspo_binarize and outcome milexp_pergdpSIPRI_diff on 809 samples
# G Model has been fit
# Q model has been fit
# AIPTW model has been fit. Returning τ hat and its standard deviation
# τ hat = -0.01867, std = 0.02168, test statistic = -0.86096, p-value = 0.19476
#
# Running models for treatment newdiscovery_aspo_binarize and outcome milexp_pergdpSIPRI_diff on 809 samples
#
# WARNING:
#  Some propensity scores are very small,
#  which could lead to an inflated AIPTW.
#  Minimum score =  0.0014432569732889533
#
# WARNING:
#  Some propensity scores are very large,
#  which could lead to an inflated AIPTW.
#  Maximum score =  0.9985608458518982
# G Model has been fit
# Q model has been fit
# Dropped 138 observations due to overlap condition
# AIPTW model has been fit. Returning τ hat and its standard deviation
# τ hat = 0.03249, std = 0.0427, test statistic = 0.76083, p-value = 0.22349

# %%
att_discovery_results_df.loc[0:3, :]
# Out:
#   model                   treatment         outcome   tau_hat   tau_std  \
# 0    rf  newdiscovery_aspo_binarize    d2incidenceU -0.001890  0.016471
# 1   xgb  newdiscovery_aspo_binarize    d2incidenceU -0.010198  0.025173
# 2    rf  newdiscovery_aspo_binarize  d3_6incidenceU -0.058115  0.024617
# 3   xgb  newdiscovery_aspo_binarize  d3_6incidenceU -0.111054  0.076899
#
#    test_stat   p_value
# 0  -0.114766  0.454324
# 1  -0.405119  0.342729
# 2  -2.360782  0.009195
# 3  -1.444157  0.074474

# %%
g_df = oil_df[confounders + [treatment]].dropna().reset_index()
g_df[treatment] = g_df[treatment].replace({0.0: 0, 1.0: 1})
rf_propensity = treatment_k_fold_fit_and_predict(make_g_model, g_df[confounders], g_df[treatment], n_splits=5)
xgb_propensity = treatment_k_fold_fit_and_predict(make_xgboost_g_model, g_df[confounders], g_df[treatment], n_splits=5)

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(7, 5))
hist(rf_propensity)
plt.title('Propensity Scores for Random Forest Model', fontsize=16)
plt.xlabel('Propensity Scores', fontsize=15)
plt.ylabel('Frequency', fontsize=15)
# Out:
# Text(0, 0.5, 'Frequency')

# %%
plt.figure(figsize=(7, 5))
hist(xgb_propensity)
plt.title('Propensity Scores for XGBoost Model', fontsize=16)
plt.xlabel('Propensity Scores', fontsize=15)
plt.ylabel('Frequency', fontsize=15)
# Out:
# Text(0, 0.5, 'Frequency')
