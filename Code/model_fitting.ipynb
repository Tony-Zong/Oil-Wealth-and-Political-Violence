# %%
import numpy as np
import pandas as pd
import scipy as sp
from sklearn.ensemble import RandomForestClassifier, RandomForestRegressor
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import KFold, StratifiedKFold, train_test_split
from sklearn.metrics import mean_squared_error, log_loss
import sklearn
import os
from matplotlib.pyplot import hist
from scipy import stats
# import more functions or modules if you need them !!

# %%
# set random seed for numpy
RANDOM_SEED=42
np.random.seed(RANDOM_SEED)

# %%
# read in the dataframe
oil_df = pd.read_pickle('../Data/data/comprehensive_new_full.pkl')

# %%
oil_df
# Out:
#          year  numcode  oilreserves_full  oilreserves  oilreserves_public  \
# 0      1929.0        4               NaN          NaN                 NaN
# 1      1930.0        4               NaN          NaN                 NaN
# 2      1931.0        4               NaN          NaN                 NaN
# 3      1932.0        4               NaN          NaN                 NaN
# 4      1933.0        4               NaN          NaN                 NaN
# ...       ...      ...               ...          ...                 ...
# 17915  2004.0      894           0.00001          NaN             0.00001
# 17916  2005.0      894           0.00001          NaN             0.00001
# 17917  2006.0      894           0.00001          NaN             0.00001
# 17918  2007.0      894           0.00001          NaN             0.00001
# 17919  2008.0      894           0.00001          NaN             0.00001
#
#        newdiscovery_aspo  aspo  wildcat  endowment  pop_maddison  ...  \
# 0                    NaN   NaN      NaN        NaN           NaN  ...
# 1                    NaN   NaN      NaN        NaN           NaN  ...
# 2                    NaN   NaN      NaN        NaN           NaN  ...
# 3                    NaN   NaN      NaN        NaN           NaN  ...
# 4                    NaN   NaN      NaN        NaN           NaN  ...
# ...                  ...   ...      ...        ...           ...  ...
# 17915                NaN   NaN      NaN    0.00001  10962.026367  ...
# 17916                NaN   NaN      NaN    0.00001  11115.380859  ...
# 17917                NaN   NaN      NaN    0.00001  11288.252930  ...
# 17918                NaN   NaN      NaN    0.00001  11477.447266  ...
# 17919                NaN   NaN      NaN    0.00001  11669.534180  ...
#
#        valoilres_public_binarize  oilpop_diff  oilpop_binarize  \
# 0                            NaN          NaN              NaN
# 1                            NaN          NaN              NaN
# 2                            NaN          NaN              NaN
# 3                            NaN          NaN              NaN
# 4                            NaN          NaN              NaN
# ...                          ...          ...              ...
# 17915                        0.0          0.0              0.0
# 17916                        0.0          0.0              0.0
# 17917                        0.0          0.0              0.0
# 17918                        0.0          0.0              0.0
# 17919                        0.0          0.0              0.0
#
#        valoilres_impute_diff  valoilres_impute_binarize  oilpop_impute_diff  \
# 0                        NaN                        NaN                 NaN
# 1                        NaN                        NaN                 NaN
# 2                        NaN                        NaN                 NaN
# 3                        NaN                        NaN                 NaN
# 4                        NaN                        NaN                 NaN
# ...                      ...                        ...                 ...
# 17915                    0.0                        0.0                 0.0
# 17916                    0.0                        0.0                 0.0
# 17917                    0.0                        0.0                 0.0
# 17918                    0.0                        0.0                 0.0
# 17919                    0.0                        0.0                 0.0
#
#        oilpop_impute_binarize  crude1990P_diff  milexp_pergdpSIPRI_diff  \
# 0                         NaN              NaN                      NaN
# 1                         NaN              NaN                      NaN
# 2                         NaN        -0.401178                      NaN
# 3                         NaN         0.492896                      NaN
# 4                         NaN        -0.188141                      NaN
# ...                       ...              ...                      ...
# 17915                     0.0         0.292683                      NaN
# 17916                     0.0         0.378049                      NaN
# 17917                     0.0         0.157455                      NaN
# 17918                     0.0         0.080496                      NaN
# 17919                     0.0         0.293859                      NaN
#
#        newdiscovery_aspo_binarize
# 0                             NaN
# 1                             NaN
# 2                             NaN
# 3                             NaN
# 4                             NaN
# ...                           ...
# 17915                         NaN
# 17916                         NaN
# 17917                         NaN
# 17918                         NaN
# 17919                         NaN
#
# [17920 rows x 119 columns]

# %%
oil_df.columns
# Out:
# Index(['year', 'numcode', 'oilreserves_full', 'oilreserves',
#        'oilreserves_public', 'newdiscovery_aspo', 'aspo', 'wildcat',
#        'endowment', 'pop_maddison',
#        ...
#        'valoilres_public_binarize', 'oilpop_diff', 'oilpop_binarize',
#        'valoilres_impute_diff', 'valoilres_impute_binarize',
#        'oilpop_impute_diff', 'oilpop_impute_binarize', 'crude1990P_diff',
#        'milexp_pergdpSIPRI_diff', 'newdiscovery_aspo_binarize'],
#       dtype='object', length=119)

# %%
# ATT and ATE AIPTW
def att_aiptw(Q0, Q1, g, A, Y, prob_t=None):
    """
    Double ML estimator for the ATT
    This uses the ATT specific scores, see equation 3.9 of https://www.econstor.eu/bitstream/10419/149795/1/869216953.pdf
    Return: aiptw of ATE and its standard error
    """
    
    # number of observations
    n = Y.shape[0]
    
    # estimate marginal probability of treatment
    if prob_t is None:
        prob_t = A.mean() 
    
    # att aiptw
    tau_hat = (A*(Y-Q0) - (1-A)*(g/(1-g))*(Y-Q0)).mean()/ prob_t
  
    # influence curve and standard error of aiptw
    phi = (A*(Y-Q0) - (1-A)*(g/(1-g))*(Y-Q0) - tau_hat*A) / prob_t
    std_hat = np.std(phi) / np.sqrt(n)

    return tau_hat, std_hat

def ate_aiptw(Q0, Q1, g, A, Y, prob_t=None):
    """
    Double ML estimator for the ATE
    Return: aiptw of ATE and its standard error
    """
    # number of observations
    n = Y.shape[0]
    
    # ate aiptw
    tau_hat = (Q1 - Q0 + A*(Y-Q1)/g - (1-A)*(Y-Q0)/(1-g)).mean()
  
    # influence curve and standard error of aiptw
    phi = Q1 - Q0 + A*(Y-Q1)/g - (1-A)*(Y-Q0)/(1-g) - tau_hat   
    std_hat = np.std(phi) / np.sqrt(n)

    return tau_hat, std_hat

# %%
# Conditional outcome models (Q models)
def make_linear_Q_model():
    ''' A function that returns a linear q model for later use in k-folding'''
    return LinearRegression()

def make_Q_model(output_type:str):
    ''' A function that returns a general ML q model for later use in k-folding'''
    if output_type == 'binary':
        return RandomForestClassifier(random_state=RANDOM_SEED, n_estimators=500, max_depth=None)
    return RandomForestRegressor(random_state=RANDOM_SEED, n_estimators=500, max_depth=None)
# One example: RandomForestRegressor(random_state=RANDOM_SEED, n_estimators=500, max_depth=None)

# %%
# Propensity score models (g models)
def make_g_model():
    ''' A function that returns a g model for computing propensity scores'''
    return RandomForestClassifier(n_estimators=100, max_depth=5)
# One example: RandomForestClassifier(n_estimators=100, max_depth=5)

# %%
# Functions for K-fold cross-fitting
def treatment_k_fold_fit_and_predict(make_model, X:pd.DataFrame, A:np.array, n_splits:int):
    '''
    Implements K fold cross-fitting for the model predicting the treatment A. 
    That is, 
    1. Split data into K folds
    2. For each fold j, the model is fit on the other K-1 folds
    3. The fitted model is used to make predictions for each data point in fold j
    Returns an array containing the predictions  

    Args:
    model: function that returns sklearn model (which implements fit and predict_prob)
    X: dataframe of variables to adjust for
    A: array of treatments
    n_splits: number of splits to use
    '''

    predictions = np.full_like(A, np.nan, dtype=float)
    kf = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=RANDOM_SEED)
    
    for train_index, test_index in kf.split(X, A):
        X_train = X.loc[train_index]
        A_train = A.loc[train_index]
        g = make_model()
        g.fit(X_train, A_train)

        # get predictions for split
        predictions[test_index] = g.predict_proba(X.loc[test_index])[:, 1]
    
    # sanity check that overlap holds
    assert np.isnan(predictions).sum() == 0
    return predictions

def outcome_k_fold_fit_and_predict(make_model, X:pd.DataFrame, y:np.array, A:np.array, n_splits:int, output_type:str):
    '''
    Implements K fold cross-fitting for the model predicting the outcome Y. 
    That is, 
    1. Split data into K folds
    2. For each fold j, the model is fit on the other K-1 folds
    3. The fitted model is used to make predictions for each data point in fold j
    Returns two arrays containing the predictions for all units untreated, all units treated  

    Args:
    model: function that returns sklearn model (that implements fit and either predict_prob or predict)
    X: dataframe of variables to adjust for
    y: array of outcomes
    A: array of treatments
    n_splits: number of splits to use
    output_type: type of outcome, "binary" or "continuous"
    '''

    predictions0 = np.full_like(A, np.nan, dtype=float)
    predictions1 = np.full_like(y, np.nan, dtype=float)
    if output_type == 'binary':
        kf = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=RANDOM_SEED)
    elif output_type == 'continuous':
        kf = KFold(n_splits=n_splits, shuffle=True, random_state=RANDOM_SEED)

    # include the treatment as input feature
    X_w_treatment = X.copy()
    X_w_treatment["A"] = A

    # for predicting effect under treatment / control status for each data point 
    X0 = X_w_treatment.copy()
    X0["A"] = 0
    X1 = X_w_treatment.copy()
    X1["A"] = 1

    
    for train_index, test_index in kf.split(X_w_treatment, y):
        X_train = X_w_treatment.loc[train_index]
        y_train = y.loc[train_index]
        q = make_model(output_type)
        q.fit(X_train, y_train)

        if output_type =='binary':
            predictions0[test_index] = q.predict_proba(X0.loc[test_index])[:, 1]
            predictions1[test_index] = q.predict_proba(X1.loc[test_index])[:, 1]
        elif output_type == 'continuous':
            predictions0[test_index] = q.predict(X0.loc[test_index])
            predictions1[test_index] = q.predict(X1.loc[test_index])

    assert np.isnan(predictions0).sum() == 0
    assert np.isnan(predictions1).sum() == 0
    return predictions0, predictions1

# %%
# set variables of interest
outcome = 'onset2COWCS'
treatment = 'valoilres_binarize'
confounders = ['crude1990P_diff',
               'wildcat_diff',
               'out_regdisaster_diff',
               'ecgrowth',
               'pop_maddison_diff',
               'popdens_diff',
               'democracy_diff',
               'logmountain',
               'ethnic_fractionalization',
               'religion_fractionalization',
               'language_fractionalization',
               'leg_british',
               'decade',
               'opec']

# %%
def fit_and_run_model(df, outcome:str, treatment:str, confounders:list, make_g_model,
                      make_Q_model, n_splits=5, output_type='binary', ate=True):
    '''
    Function that creates a g, q, and aiptw model based on the 
    given inputs
    
    Inputs: df (pandas df) - the dataframe the variables are contained in
            outcome (str) - the outcome variable
            treatment (str) - the treatment variable
            confounders (lst) - a list of the confounding variables
            make_g_model - the make_g_model function
            make_Q_model - the make_Q_model function
            n_splits (int) - number of splits for the model
            output_type (str) - the desired output type, either binary or continous
            ate (bool) - whether to use ate or alternative att
    
    Returns: tau_hat - the tau hat estimator for the average treatment effect
             std of tau_hat - the standard deviation for the tau_hat estimator
    '''
    df = df.replace({outcome: .00001}, 0)
    df = df[[outcome] + confounders + [treatment]]
    df = df.dropna().reset_index()
    print('Running models for treatment {} and outcome {} on {} samples'.format(treatment, outcome, len(df)))

    outcome = df[outcome]
    confounders = df[confounders]
    treatment = df[treatment]
    treatment = treatment.replace({0.0: 0, 1.0: 1})
    outcome = outcome.replace({0.0: 0, 1.0: 1})
    g = treatment_k_fold_fit_and_predict(make_g_model, X=confounders, A=treatment, n_splits=n_splits)
    drop=False
    if min(g) < .01:
        print('\nWARNING:\n Some propensity scores are very small,\n which could '
              'lead to an inflated AIPTW.\n Minimum score = ', min(g))
    if max(g) > .99:
        print('\nWARNING:\n Some propensity scores are very large,\n which could '
              'lead to an inflated AIPTW.\n Maximum score = ', max(g))
        drop = True
    print('G Model has been fit')

    Q0_ml, Q1_ml = outcome_k_fold_fit_and_predict(make_Q_model, X=confounders, y=outcome, A=treatment, \
                                                  n_splits=n_splits, output_type=output_type)
    
    print('Q model has been fit')
    data_and_nuisance_estimates_ml = pd.DataFrame({'g': g, 'Q0': Q0_ml, 'Q1': Q1_ml, 'A': treatment, 'Y': outcome})
    
    if drop:
        data_and_nuisance_estimates_ml = data_and_nuisance_estimates_ml[data_and_nuisance_estimates_ml['g'] > .01]
        data_and_nuisance_estimates_ml = data_and_nuisance_estimates_ml[data_and_nuisance_estimates_ml['g'] < .99]
        print('Dropped {} observations due to overlap condition'.format(len(df) - len(data_and_nuisance_estimates_ml)))
    n = len(data_and_nuisance_estimates_ml)
    # ate aiptw
    if ate:
        tau_hat, std_hat = ate_aiptw(**data_and_nuisance_estimates_ml)
    else: 
        tau_hat, std_hat = att_aiptw(**data_and_nuisance_estimates_ml)
    test_stat = tau_hat / std_hat
    p_value = stats.t.sf(abs(test_stat), df=(n-1))
    print('AIPTW model has been fit. Returning \u03C4 hat and its standard deviation')
    print('\u03C4 hat = {}, std = {}, test statistic = {}, p-value = {}\n'.format(round(tau_hat, 5), round(std_hat, 5), round(test_stat, 5), round(p_value, 5)))
    return tau_hat, std_hat, test_stat, p_value

# %%
def fit_and_run_model_democracy(df, outcome:str, treatment:str, confounders:list, make_g_model,
                                make_Q_model, n_splits=5, output_type='binary', ate=True):
    '''
    Similar function to fit_and_run_model but splits on democracy for heterogenous effects
    
    Inputs: df (pandas df) - the dataframe the variables are contained in
            outcome (str) - the outcome variable
            treatment (str) - the treatment variable
            confounders (lst) - a list of the confounding variables
            make_g_model - the make_g_model function
            make_Q_model - the make_Q_model function
            n_splits (int) - number of splits for the model
            output_type (str) - the desired output type, either binary or continous
            ate (bool) - whether to use ate or alternative att
    
    Returns: tau_hat - the tau hat estimator for the average treatment effect
             std of tau_hat - the standard deviation for the tau_hat estimator
    '''
    df = df.replace({outcome: .00001}, 0)
    df = df[[outcome] + confounders + [treatment] + ['democracy']]
    df = df.dropna().reset_index()
    print('Running models for treatment {} and outcome {} on {} samples'.format(treatment, outcome, len(df)))

    outcome = df[outcome]
    confounders = df[confounders]
    treatment = df[treatment]
    democracy = df['democracy']
    treatment = treatment.replace({0.0: 0, 1.0: 1})
    outcome = outcome.replace({0.0: 0, 1.0: 1})
    g = treatment_k_fold_fit_and_predict(make_g_model, X=confounders, A=treatment, n_splits=n_splits)
    drop=False
    if min(g) < .01:
        print('\nWARNING:\n Some propensity scores are very small,\n which could '
              'lead to an inflated AIPTW.\n Minimum score = ', min(g))
    if max(g) > .99:
        print('\nWARNING:\n Some propensity scores are very large,\n which could '
              'lead to an inflated AIPTW.\n Maximum score = ', max(g))
        drop = True
    print('G Model has been fit')

    Q0_ml, Q1_ml = outcome_k_fold_fit_and_predict(make_Q_model, X=confounders, y=outcome, A=treatment, \
                                                  n_splits=n_splits, output_type=output_type)
    
    print('Q model has been fit')
    data_and_nuisance_estimates_ml = pd.DataFrame({'g': g, 'Q0': Q0_ml, 'Q1': Q1_ml, 'A': treatment, 'Y': outcome})
    
    if drop:
        data_and_nuisance_estimates_ml = data_and_nuisance_estimates_ml[data_and_nuisance_estimates_ml['g'] > .01]
        data_and_nuisance_estimates_ml = data_and_nuisance_estimates_ml[data_and_nuisance_estimates_ml['g'] < .99]
        print('Dropped {} observations due to overlap condition'.format(len(df) - len(data_and_nuisance_estimates_ml)))
        
    democracy = democracy.loc[data_and_nuisance_estimates_ml.index]
    n = len(data_and_nuisance_estimates_ml)
    data_and_nuisance_estimates_ml_demo = data_and_nuisance_estimates_ml.loc[democracy[democracy > .005].index]
    data_and_nuisance_estimates_ml_nondemo = data_and_nuisance_estimates_ml.loc[democracy[democracy <= .005].index]
    # ate aiptw
    tau_hat_demo, std_hat_demo = ate_aiptw(**data_and_nuisance_estimates_ml_demo)
    tau_hat_nondemo, std_hat_nondemo = att_aiptw(**data_and_nuisance_estimates_ml_nondemo)

    test_stat_demo = tau_hat_demo / std_hat_demo
    p_value_demo = stats.t.sf(abs(test_stat_demo), df=(len(data_and_nuisance_estimates_ml_demo)-1))

    test_stat_nondemo = tau_hat_nondemo / std_hat_nondemo
    p_value_nondemo = stats.t.sf(abs(test_stat_nondemo), df=(len(data_and_nuisance_estimates_ml_nondemo)-1))
    #print('AIPTW model has been fit. Returning \u03C4 hat and its standard deviation')
    #print('\u03C4 hat = {}, std = {}, test statistic = {}, p-value = {}\n'.format(round(tau_hat, 5), round(std_hat, 5), round(test_stat, 5), round(p_value, 5)))
    return tau_hat_demo, std_hat_demo, test_stat_demo, p_value_demo, tau_hat_nondemo, std_hat_nondemo, test_stat_nondemo, p_value_nondemo

# %%
treatment_lst = ['valoilres_binarize', # value of oil reserves
               'valoilres_public_binarize', # value of oil reserves from public data
               'oilpop_binarize', # oil reserves per capita in million barrels per 1000 persons
               'valoilres_impute_binarize', # value of oilpop_impute (multiply by crude oil price)
               'oilpop_impute_binarize']

outcome_lst = ['onset2COWCS',
               'onsetUCS',
               'coup',
               'periregular',
               'milexp_pergdpSIPRI_diff']

# %%
oil_df = oil_df.T.drop_duplicates().T

# %%
from xgboost import XGBClassifier
from xgboost import XGBRegressor

# %%
def make_xgboost_g_model():
    return XGBClassifier(n_estimators=50, max_depth=3)

def make_xgboost_Q_model(output_type:str):
    if output_type == 'binary':
        return XGBClassifier(random_state=RANDOM_SEED, n_estimators=500, max_depth=None)
    return XGBRegressor(random_state=RANDOM_SEED, n_estimators=500, max_depth=None)

# %%
oil_df[confounders] = oil_df[confounders].astype(float)

# %%
# tests are relevant combinations of variables
df_dict = {'model': [], 'treatment': [], 'outcome': [], 'tau_hat': [], 'tau_std': [], 'test_stat': [], 'p_value': []}
for treat in treatment_lst:
    for out in outcome_lst:
        for model_type in ['rf', 'xgb']:
            if len(oil_df[out].value_counts()) == 2:
                output = 'binary'
            else:
                output = 'continuous'
            if model_type == 'rf':
                tau_hat, tau_std, test_stat, p_value = fit_and_run_model(oil_df, out, treat, confounders, make_g_model, make_Q_model, output_type=output, ate=False)
            else:
                tau_hat, tau_std, test_stat, p_value = fit_and_run_model(oil_df, out, treat, confounders, make_xgboost_g_model, make_xgboost_Q_model, output_type=output, ate=False)
            df_dict['model'].append(model_type)
            df_dict['treatment'].append(treat)
            df_dict['outcome'].append(out)
            df_dict['tau_hat'].append(tau_hat)
            df_dict['tau_std'].append(tau_std)
            df_dict['test_stat'].append(test_stat)
            df_dict['p_value'].append(p_value)

att_results_df = pd.DataFrame(data=df_dict)
# Out:
# Running models for treatment valoilres_binarize and outcome onset2COWCS on 5174 samples
# G Model has been fit
# Q model has been fit
# AIPTW model has been fit. Returning τ hat and its standard deviation
# τ hat = -9e-05, std = 0.00484, test statistic = -0.01917, p-value = 0.49235
#
# Running models for treatment valoilres_binarize and outcome onset2COWCS on 5174 samples
#
# WARNING:
#  Some propensity scores are very small,
#  which could lead to an inflated AIPTW.
#  Minimum score =  0.00016930692072492093
#
# WARNING:
#  Some propensity scores are very large,
#  which could lead to an inflated AIPTW.
#  Maximum score =  0.9984782338142395
# G Model has been fit
# Q model has been fit
# Dropped 1645 observations due to overlap condition
# AIPTW model has been fit. Returning τ hat and its standard deviation
# τ hat = -0.00882, std = 0.01667, test statistic = -0.52921, p-value = 0.29834
#
# Running models for treatment valoilres_binarize and outcome onsetUCS on 4517 samples
# G Model has been fit
# Q model has been fit
# AIPTW model has been fit. Returning τ hat and its standard deviation
# τ hat = -0.00137, std = 0.00847, test statistic = -0.16213, p-value = 0.43561
#
# Running models for treatment valoilres_binarize and outcome onsetUCS on 4517 samples
#
# WARNING:
#  Some propensity scores are very small,
#  which could lead to an inflated AIPTW.
#  Minimum score =  8.085629815468565e-05
#
# WARNING:
#  Some propensity scores are very large,
#  which could lead to an inflated AIPTW.
#  Maximum score =  0.9994603991508484
# G Model has been fit
# Q model has been fit
# Dropped 1592 observations due to overlap condition
# AIPTW model has been fit. Returning τ hat and its standard deviation
# τ hat = -0.03817, std = 0.08077, test statistic = -0.47265, p-value = 0.31824
#
# Running models for treatment valoilres_binarize and outcome coup on 5091 samples
# G Model has been fit
# Q model has been fit
# AIPTW model has been fit. Returning τ hat and its standard deviation
# τ hat = -0.02478, std = 0.01285, test statistic = -1.9285, p-value = 0.02692
#
# Running models for treatment valoilres_binarize and outcome coup on 5091 samples
#
# WARNING:
#  Some propensity scores are very small,
#  which could lead to an inflated AIPTW.
#  Minimum score =  7.139790250221267e-05
#
# WARNING:
#  Some propensity scores are very large,
#  which could lead to an inflated AIPTW.
#  Maximum score =  0.9985620379447937
# G Model has been fit
# Q model has been fit
# Dropped 1709 observations due to overlap condition
# AIPTW model has been fit. Returning τ hat and its standard deviation
# τ hat = 0.13969, std = 0.1073, test statistic = 1.30188, p-value = 0.09651
#
# Running models for treatment valoilres_binarize and outcome periregular on 3312 samples
# G Model has been fit
# Q model has been fit
# AIPTW model has been fit. Returning τ hat and its standard deviation
# τ hat = -0.01331, std = 0.00583, test statistic = -2.28361, p-value = 0.01123
#
# Running models for treatment valoilres_binarize and outcome periregular on 3312 samples
#
# WARNING:
#  Some propensity scores are very small,
#  which could lead to an inflated AIPTW.
#  Minimum score =  0.0008213795954361558
#
# WARNING:
#  Some propensity scores are very large,
#  which could lead to an inflated AIPTW.
#  Maximum score =  0.9973499774932861
# G Model has been fit
# Q model has been fit
# Dropped 894 observations due to overlap condition
# AIPTW model has been fit. Returning τ hat and its standard deviation
# τ hat = -0.0058, std = 0.0125, test statistic = -0.46397, p-value = 0.32135
#
# Running models for treatment valoilres_binarize and outcome milexp_pergdpSIPRI_diff on 1302 samples
#
# WARNING:
#  Some propensity scores are very small,
#  which could lead to an inflated AIPTW.
#  Minimum score =  0.00935040190666954
# G Model has been fit
# Q model has been fit
# AIPTW model has been fit. Returning τ hat and its standard deviation
# τ hat = 0.53222, std = 0.41139, test statistic = 1.29372, p-value = 0.098
#
# Running models for treatment valoilres_binarize and outcome milexp_pergdpSIPRI_diff on 1302 samples
#
# WARNING:
#  Some propensity scores are very small,
#  which could lead to an inflated AIPTW.
#  Minimum score =  7.458581239916384e-05
#
# WARNING:
#  Some propensity scores are very large,
#  which could lead to an inflated AIPTW.
#  Maximum score =  0.9979853630065918
# G Model has been fit
# Q model has been fit
# Dropped 787 observations due to overlap condition
# AIPTW model has been fit. Returning τ hat and its standard deviation
# τ hat = 0.09476, std = 0.12696, test statistic = 0.74642, p-value = 0.22777
#
# Running models for treatment valoilres_public_binarize and outcome onset2COWCS on 4160 samples
# G Model has been fit
# Q model has been fit
# AIPTW model has been fit. Returning τ hat and its standard deviation
# τ hat = 0.00334, std = 0.00473, test statistic = 0.70487, p-value = 0.24047
#
# Running models for treatment valoilres_public_binarize and outcome onset2COWCS on 4160 samples
#
# WARNING:
#  Some propensity scores are very small,
#  which could lead to an inflated AIPTW.
#  Minimum score =  0.00021631519484799355
#
# WARNING:
#  Some propensity scores are very large,
#  which could lead to an inflated AIPTW.
#  Maximum score =  0.9958070516586304
# G Model has been fit
# Q model has been fit
# Dropped 790 observations due to overlap condition
# AIPTW model has been fit. Returning τ hat and its standard deviation
# τ hat = 0.01038, std = 0.00508, test statistic = 2.04325, p-value = 0.02055
#
# Running models for treatment valoilres_public_binarize and outcome onsetUCS on 3969 samples
# G Model has been fit
# Q model has been fit
# AIPTW model has been fit. Returning τ hat and its standard deviation
# τ hat = 0.01419, std = 0.00852, test statistic = 1.6662, p-value = 0.04788
#
# Running models for treatment valoilres_public_binarize and outcome onsetUCS on 3969 samples
#
# WARNING:
#  Some propensity scores are very small,
#  which could lead to an inflated AIPTW.
#  Minimum score =  0.00020957154629286379
#
# WARNING:
#  Some propensity scores are very large,
#  which could lead to an inflated AIPTW.
#  Maximum score =  0.9970719814300537
# G Model has been fit
# Q model has been fit
# Dropped 765 observations due to overlap condition
# AIPTW model has been fit. Returning τ hat and its standard deviation
# τ hat = 0.00904, std = 0.02265, test statistic = 0.39908, p-value = 0.34493
#
# Running models for treatment valoilres_public_binarize and outcome coup on 4491 samples
# G Model has been fit
# Q model has been fit
# AIPTW model has been fit. Returning τ hat and its standard deviation
# τ hat = -0.00793, std = 0.01293, test statistic = -0.61299, p-value = 0.26996
#
# Running models for treatment valoilres_public_binarize and outcome coup on 4491 samples
#
# WARNING:
#  Some propensity scores are very small,
#  which could lead to an inflated AIPTW.
#  Minimum score =  0.0002657104341778904
#
# WARNING:
#  Some propensity scores are very large,
#  which could lead to an inflated AIPTW.
#  Maximum score =  0.9936314225196838
# G Model has been fit
# Q model has been fit
# Dropped 905 observations due to overlap condition
# AIPTW model has been fit. Returning τ hat and its standard deviation
# τ hat = -0.0589, std = 0.05709, test statistic = -1.0318, p-value = 0.15111
#
# Running models for treatment valoilres_public_binarize and outcome periregular on 2313 samples
# G Model has been fit
# Q model has been fit
# AIPTW model has been fit. Returning τ hat and its standard deviation
# τ hat = -0.00355, std = 0.00749, test statistic = -0.47314, p-value = 0.31808
#
# Running models for treatment valoilres_public_binarize and outcome periregular on 2313 samples
#
# WARNING:
#  Some propensity scores are very small,
#  which could lead to an inflated AIPTW.
#  Minimum score =  0.0016659048851579428
#
# WARNING:
#  Some propensity scores are very large,
#  which could lead to an inflated AIPTW.
#  Maximum score =  0.9939931035041809
# G Model has been fit
# Q model has been fit
# Dropped 231 observations due to overlap condition
# AIPTW model has been fit. Returning τ hat and its standard deviation
# τ hat = 0.00863, std = 0.01452, test statistic = 0.59408, p-value = 0.27626
#
# Running models for treatment valoilres_public_binarize and outcome milexp_pergdpSIPRI_diff on 1281 samples
#
# WARNING:
#  Some propensity scores are very small,
#  which could lead to an inflated AIPTW.
#  Minimum score =  0.00872753021560976
# G Model has been fit
# Q model has been fit
# AIPTW model has been fit. Returning τ hat and its standard deviation
# τ hat = 0.49383, std = 0.3684, test statistic = 1.34048, p-value = 0.09016
#
# Running models for treatment valoilres_public_binarize and outcome milexp_pergdpSIPRI_diff on 1281 samples
# WARNING:
#  Some propensity scores are very small,
#  which could lead to an inflated AIPTW.
#  Minimum score =  0.00010648815805325285
#
# WARNING:
#  Some propensity scores are very large,
#  which could lead to an inflated AIPTW.
#  Maximum score =  0.994769275188446
# G Model has been fit
# Q model has been fit
# Dropped 565 observations due to overlap condition
# AIPTW model has been fit. Returning τ hat and its standard deviation
# τ hat = 0.5545, std = 0.36618, test statistic = 1.51427, p-value = 0.0651
#
# Running models for treatment oilpop_binarize and outcome onset2COWCS on 5174 samples
#
# WARNING:
#  Some propensity scores are very small,
#  which could lead to an inflated AIPTW.
#  Minimum score =  0.004113149545574649
# G Model has been fit
# Q model has been fit
# AIPTW model has been fit. Returning τ hat and its standard deviation
# τ hat = -0.00181, std = 0.00682, test statistic = -0.2655, p-value = 0.39532
#
# Running models for treatment oilpop_binarize and outcome onset2COWCS on 5174 samples
#
# WARNING:
#  Some propensity scores are very small,
#  which could lead to an inflated AIPTW.
#  Minimum score =  0.000325085740769282
# G Model has been fit
# Q model has been fit
# AIPTW model has been fit. Returning τ hat and its standard deviation
# τ hat = -0.00171, std = 0.00795, test statistic = -0.21561, p-value = 0.41465
#
# Running models for treatment oilpop_binarize and outcome onsetUCS on 4517 samples
#
# WARNING:
#  Some propensity scores are very small,
#  which could lead to an inflated AIPTW.
#  Minimum score =  0.0036307065416384455
# G Model has been fit
# Q model has been fit
# AIPTW model has been fit. Returning τ hat and its standard deviation
# τ hat = 0.00231, std = 0.01267, test statistic = 0.18227, p-value = 0.42769
#
# Running models for treatment oilpop_binarize and outcome onsetUCS on 4517 samples
#
# WARNING:
#  Some propensity scores are very small,
#  which could lead to an inflated AIPTW.
#  Minimum score =  0.00014414271572604775
# G Model has been fit
# Q model has been fit
# AIPTW model has been fit. Returning τ hat and its standard deviation
# τ hat = 0.00957, std = 0.01449, test statistic = 0.6601, p-value = 0.25461
#
# Running models for treatment oilpop_binarize and outcome coup on 5091 samples
#
# WARNING:
#  Some propensity scores are very small,
#  which could lead to an inflated AIPTW.
#  Minimum score =  0.0051300633313683475
# G Model has been fit
# Q model has been fit
# AIPTW model has been fit. Returning τ hat and its standard deviation
# τ hat = -0.02203, std = 0.02159, test statistic = -1.02078, p-value = 0.1537
#
# Running models for treatment oilpop_binarize and outcome coup on 5091 samples
#
# WARNING:
#  Some propensity scores are very small,
#  which could lead to an inflated AIPTW.
#  Minimum score =  0.00028943835059180856
# G Model has been fit
# Q model has been fit
# AIPTW model has been fit. Returning τ hat and its standard deviation
# τ hat = -0.04813, std = 0.0275, test statistic = -1.74992, p-value = 0.0401
#
# Running models for treatment oilpop_binarize and outcome periregular on 3312 samples
#
# WARNING:
#  Some propensity scores are very small,
#  which could lead to an inflated AIPTW.
#  Minimum score =  0.008495543249715081
# G Model has been fit
# Q model has been fit
# AIPTW model has been fit. Returning τ hat and its standard deviation
# τ hat = -0.00343, std = 0.00684, test statistic = -0.50131, p-value = 0.30809
#
# Running models for treatment oilpop_binarize and outcome periregular on 3312 samples
#
# WARNING:
#  Some propensity scores are very small,
#  which could lead to an inflated AIPTW.
#  Minimum score =  0.00047344868653453887
# G Model has been fit
# Q model has been fit
# AIPTW model has been fit. Returning τ hat and its standard deviation
# τ hat = -0.0035, std = 0.01073, test statistic = -0.32651, p-value = 0.37203
#
# Running models for treatment oilpop_binarize and outcome milexp_pergdpSIPRI_diff on 1302 samples
#
# WARNING:
#  Some propensity scores are very small,
#  which could lead to an inflated AIPTW.
#  Minimum score =  0.00047940305080367685
# G Model has been fit
# Q model has been fit
# AIPTW model has been fit. Returning τ hat and its standard deviation
# τ hat = 3.32623, std = 2.93104, test statistic = 1.13483, p-value = 0.12833
#
# Running models for treatment oilpop_binarize and outcome milexp_pergdpSIPRI_diff on 1302 samples
#
# WARNING:
#  Some propensity scores are very small,
#  which could lead to an inflated AIPTW.
#  Minimum score =  4.6850094804540277e-05
# G Model has been fit
# Q model has been fit
# AIPTW model has been fit. Returning τ hat and its standard deviation
# τ hat = 3.74021, std = 2.97671, test statistic = 1.25649, p-value = 0.10458
#
# Running models for treatment valoilres_impute_binarize and outcome onset2COWCS on 5174 samples
# G Model has been fit
# Q model has been fit
# AIPTW model has been fit. Returning τ hat and its standard deviation
# τ hat = 0.00094, std = 0.0045, test statistic = 0.20825, p-value = 0.41752
#
# Running models for treatment valoilres_impute_binarize and outcome onset2COWCS on 5174 samples
#
# WARNING:
#  Some propensity scores are very small,
#  which could lead to an inflated AIPTW.
#  Minimum score =  0.00011381743388483301
#
# WARNING:
#  Some propensity scores are very large,
#  which could lead to an inflated AIPTW.
#  Maximum score =  0.9975621700286865
# G Model has been fit
# Q model has been fit
# Dropped 1669 observations due to overlap condition
# AIPTW model has been fit. Returning τ hat and its standard deviation
# τ hat = 0.00565, std = 0.0054, test statistic = 1.04649, p-value = 0.14769
#
# Running models for treatment valoilres_impute_binarize and outcome onsetUCS on 4517 samples
# G Model has been fit
# Q model has been fit
# AIPTW model has been fit. Returning τ hat and its standard deviation
# τ hat = 0.00885, std = 0.0084, test statistic = 1.05373, p-value = 0.14603
#
# Running models for treatment valoilres_impute_binarize and outcome onsetUCS on 4517 samples
#
# WARNING:
#  Some propensity scores are very small,
#  which could lead to an inflated AIPTW.
#  Minimum score =  0.0001339942537015304
#
# WARNING:
#  Some propensity scores are very large,
#  which could lead to an inflated AIPTW.
#  Maximum score =  0.999138593673706
# G Model has been fit
# Q model has been fit
# Dropped 1555 observations due to overlap condition
# AIPTW model has been fit. Returning τ hat and its standard deviation
# τ hat = 0.01881, std = 0.02693, test statistic = 0.6986, p-value = 0.24242
#
# Running models for treatment valoilres_impute_binarize and outcome coup on 5091 samples
# G Model has been fit
# Q model has been fit
# AIPTW model has been fit. Returning τ hat and its standard deviation
# τ hat = -0.01506, std = 0.01183, test statistic = -1.27314, p-value = 0.10151
#
# Running models for treatment valoilres_impute_binarize and outcome coup on 5091 samples
#
# WARNING:
#  Some propensity scores are very small,
#  which could lead to an inflated AIPTW.
#  Minimum score =  7.026324601611122e-05
#
# WARNING:
#  Some propensity scores are very large,
#  which could lead to an inflated AIPTW.
#  Maximum score =  0.9991395473480225
# G Model has been fit
# Q model has been fit
# Dropped 1748 observations due to overlap condition
# AIPTW model has been fit. Returning τ hat and its standard deviation
# τ hat = 0.02334, std = 0.0392, test statistic = 0.59547, p-value = 0.27578
#
# Running models for treatment valoilres_impute_binarize and outcome periregular on 3312 samples
# G Model has been fit
# Q model has been fit
# AIPTW model has been fit. Returning τ hat and its standard deviation
# τ hat = -0.01293, std = 0.00582, test statistic = -2.22147, p-value = 0.01319
#
# Running models for treatment valoilres_impute_binarize and outcome periregular on 3312 samples
#
# WARNING:
#  Some propensity scores are very small,
#  which could lead to an inflated AIPTW.
#  Minimum score =  0.0008213795954361558
#
# WARNING:
#  Some propensity scores are very large,
#  which could lead to an inflated AIPTW.
#  Maximum score =  0.9973499774932861
# G Model has been fit
# Q model has been fit
# Dropped 894 observations due to overlap condition
# AIPTW model has been fit. Returning τ hat and its standard deviation
# τ hat = -0.0058, std = 0.0125, test statistic = -0.46397, p-value = 0.32135
#
# Running models for treatment valoilres_impute_binarize and outcome milexp_pergdpSIPRI_diff on 1302 samples
#
# WARNING:
#  Some propensity scores are very small,
#  which could lead to an inflated AIPTW.
#  Minimum score =  0.009143133349360929
# G Model has been fit
# Q model has been fit
# AIPTW model has been fit. Returning τ hat and its standard deviation
# τ hat = 0.53593, std = 0.41176, test statistic = 1.30157, p-value = 0.09665
#
# Running models for treatment valoilres_impute_binarize and outcome milexp_pergdpSIPRI_diff on 1302 samples
#
# WARNING:
#  Some propensity scores are very small,
#  which could lead to an inflated AIPTW.
#  Minimum score =  7.458581239916384e-05
#
# WARNING:
#  Some propensity scores are very large,
#  which could lead to an inflated AIPTW.
#  Maximum score =  0.9979853630065918
# G Model has been fit
# Q model has been fit
# Dropped 787 observations due to overlap condition
# AIPTW model has been fit. Returning τ hat and its standard deviation
# τ hat = 0.09476, std = 0.12696, test statistic = 0.74642, p-value = 0.22777
#
# Running models for treatment oilpop_impute_binarize and outcome onset2COWCS on 5174 samples
#
# WARNING:
#  Some propensity scores are very small,
#  which could lead to an inflated AIPTW.
#  Minimum score =  0.005810174146911319
# G Model has been fit
# Q model has been fit
# AIPTW model has been fit. Returning τ hat and its standard deviation
# τ hat = -0.00206, std = 0.00664, test statistic = -0.30943, p-value = 0.3785
#
# Running models for treatment oilpop_impute_binarize and outcome onset2COWCS on 5174 samples
#
# WARNING:
#  Some propensity scores are very small,
#  which could lead to an inflated AIPTW.
#  Minimum score =  0.00013588905858341604
# G Model has been fit
# Q model has been fit
# AIPTW model has been fit. Returning τ hat and its standard deviation
# τ hat = -0.00172, std = 0.00793, test statistic = -0.21729, p-value = 0.414
#
# Running models for treatment oilpop_impute_binarize and outcome onsetUCS on 4517 samples
#
# WARNING:
#  Some propensity scores are very small,
#  which could lead to an inflated AIPTW.
#  Minimum score =  0.004865444269836919
# G Model has been fit
# Q model has been fit
# AIPTW model has been fit. Returning τ hat and its standard deviation
# τ hat = -0.00485, std = 0.01247, test statistic = -0.38899, p-value = 0.34865
#
# Running models for treatment oilpop_impute_binarize and outcome onsetUCS on 4517 samples
#
# WARNING:
#  Some propensity scores are very small,
#  which could lead to an inflated AIPTW.
#  Minimum score =  0.0002639525628183037
# G Model has been fit
# Q model has been fit
# AIPTW model has been fit. Returning τ hat and its standard deviation
# τ hat = 0.00352, std = 0.01449, test statistic = 0.24316, p-value = 0.40395
#
# Running models for treatment oilpop_impute_binarize and outcome coup on 5091 samples
#
# WARNING:
#  Some propensity scores are very small,
#  which could lead to an inflated AIPTW.
#  Minimum score =  0.0051351336396322665
# G Model has been fit
# Q model has been fit
# AIPTW model has been fit. Returning τ hat and its standard deviation
# τ hat = -0.02536, std = 0.02104, test statistic = -1.20538, p-value = 0.11406
#
# Running models for treatment oilpop_impute_binarize and outcome coup on 5091 samples
#
# WARNING:
#  Some propensity scores are very small,
#  which could lead to an inflated AIPTW.
#  Minimum score =  0.00022543374507222325
# G Model has been fit
# Q model has been fit
# AIPTW model has been fit. Returning τ hat and its standard deviation
# τ hat = -0.04319, std = 0.02721, test statistic = -1.58757, p-value = 0.05622
#
# Running models for treatment oilpop_impute_binarize and outcome periregular on 3312 samples
#
# WARNING:
#  Some propensity scores are very small,
#  which could lead to an inflated AIPTW.
#  Minimum score =  0.006022820806435323
# G Model has been fit
# Q model has been fit
# AIPTW model has been fit. Returning τ hat and its standard deviation
# τ hat = -0.00344, std = 0.00685, test statistic = -0.50242, p-value = 0.3077
#
# Running models for treatment oilpop_impute_binarize and outcome periregular on 3312 samples
#
# WARNING:
#  Some propensity scores are very small,
#  which could lead to an inflated AIPTW.
#  Minimum score =  0.00047344868653453887
# G Model has been fit
# Q model has been fit
# AIPTW model has been fit. Returning τ hat and its standard deviation
# τ hat = -0.0035, std = 0.01073, test statistic = -0.32651, p-value = 0.37203
#
# Running models for treatment oilpop_impute_binarize and outcome milexp_pergdpSIPRI_diff on 1302 samples
#
# WARNING:
#  Some propensity scores are very small,
#  which could lead to an inflated AIPTW.
#  Minimum score =  0.0005118986128599404
# G Model has been fit
# Q model has been fit
# AIPTW model has been fit. Returning τ hat and its standard deviation
# τ hat = 3.28869, std = 2.93177, test statistic = 1.12174, p-value = 0.13109
#
# Running models for treatment oilpop_impute_binarize and outcome milexp_pergdpSIPRI_diff on 1302 samples
#
# WARNING:
#  Some propensity scores are very small,
#  which could lead to an inflated AIPTW.
#  Minimum score =  4.6850094804540277e-05
# G Model has been fit
# Q model has been fit
# AIPTW model has been fit. Returning τ hat and its standard deviation
# τ hat = 3.74021, std = 2.97671, test statistic = 1.25649, p-value = 0.10458

# %%
# take only value of oil reserves and oil reserves for space purposes
# full table in appendix of project
att_temp = att_results_df[(att_results_df['treatment'] == 'valoilres_binarize') | (att_results_df['treatment'] == 'oilpop_binarize')].reset_index(drop=True)

# %%
# check relevant outcomes
att_temp[att_temp['outcome'].isin(['onset2COWCS', 'coup', 'periregular', 'milexp_pergdpSIPRI_diff'])].sort_values(by=['outcome', 'treatment', 'model']).reset_index(drop=True)
# Out:
#    model           treatment                  outcome   tau_hat   tau_std  \
# 0     rf     oilpop_binarize                     coup -0.022034  0.021585
# 1    xgb     oilpop_binarize                     coup -0.048128  0.027503
# 2     rf  valoilres_binarize                     coup -0.024780  0.012849
# 3    xgb  valoilres_binarize                     coup  0.139695  0.107302
# 4     rf     oilpop_binarize  milexp_pergdpSIPRI_diff  3.326232  2.931039
# 5    xgb     oilpop_binarize  milexp_pergdpSIPRI_diff  3.740208  2.976707
# 6     rf  valoilres_binarize  milexp_pergdpSIPRI_diff  0.532218  0.411386
# 7    xgb  valoilres_binarize  milexp_pergdpSIPRI_diff  0.094764  0.126958
# 8     rf     oilpop_binarize              onset2COWCS -0.001811  0.006821
# 9    xgb     oilpop_binarize              onset2COWCS -0.001714  0.007948
# 10    rf  valoilres_binarize              onset2COWCS -0.000093  0.004841
# 11   xgb  valoilres_binarize              onset2COWCS -0.008819  0.016666
# 12    rf     oilpop_binarize              periregular -0.003430  0.006842
# 13   xgb     oilpop_binarize              periregular -0.003504  0.010732
# 14    rf  valoilres_binarize              periregular -0.013310  0.005828
# 15   xgb  valoilres_binarize              periregular -0.005801  0.012502
#
#     test_stat   p_value
# 0   -1.020779  0.153704
# 1   -1.749916  0.040097
# 2   -1.928501  0.026924
# 3    1.301880  0.096508
# 4    1.134830  0.128328
# 5    1.256492  0.104582
# 6    1.293718  0.097996
# 7    0.746423  0.227773
# 8   -0.265501  0.395317
# 9   -0.215610  0.414650
# 10  -0.019169  0.492354
# 11  -0.529206  0.298343
# 12  -0.501310  0.308093
# 13  -0.326511  0.372029
# 14  -2.283614  0.011229
# 15  -0.463972  0.321349

# %%
# reset treatments and outcomes
treatment_lst = ['newdiscovery_aspo_binarize']
outcome_lst = ['d2incidenceU',
               'd3_6incidenceU',
               'onset2COWCS',
               'onsetUCS',
               'coup',
               'periregular',
               'milexp_pergdpSIPRI_diff']

# %%
df_dict = {'model': [], 'treatment': [], 'outcome': [], 'tau_hat': [], 'tau_std': [], 'test_stat': [], 'p_value': []}
for treat in treatment_lst:
    for out in outcome_lst:
        for model_type in ['rf', 'xgb']:
            if len(oil_df[out].value_counts()) == 2:
                output = 'binary'
            else:
                output = 'continuous'
            if model_type == 'rf':
                tau_hat, tau_std, test_stat, p_value = fit_and_run_model(oil_df, out, treat, confounders, make_g_model, make_Q_model, output_type=output, ate=False)
            else:
                tau_hat, tau_std, test_stat, p_value = fit_and_run_model(oil_df, out, treat, confounders, make_xgboost_g_model, make_xgboost_Q_model, output_type=output, ate=False)
            df_dict['model'].append(model_type)
            df_dict['treatment'].append(treat)
            df_dict['outcome'].append(out)
            df_dict['tau_hat'].append(tau_hat)
            df_dict['tau_std'].append(tau_std)
            df_dict['test_stat'].append(test_stat)
            df_dict['p_value'].append(p_value)

att_discovery_results_df = pd.DataFrame(data=df_dict)
# Out:
# Running models for treatment newdiscovery_aspo_binarize and outcome d2incidenceU on 2561 samples
# G Model has been fit
# Q model has been fit
# AIPTW model has been fit. Returning τ hat and its standard deviation
# τ hat = 0.00204, std = 0.01281, test statistic = 0.15951, p-value = 0.43664
#
# Running models for treatment newdiscovery_aspo_binarize and outcome d2incidenceU on 2561 samples
#
# WARNING:
#  Some propensity scores are very small,
#  which could lead to an inflated AIPTW.
#  Minimum score =  0.004560614470392466
#
# WARNING:
#  Some propensity scores are very large,
#  which could lead to an inflated AIPTW.
#  Maximum score =  0.9953548908233643
# G Model has been fit
# Q model has been fit
# Dropped 18 observations due to overlap condition
# AIPTW model has been fit. Returning τ hat and its standard deviation
# τ hat = -0.01818, std = 0.02404, test statistic = -0.75605, p-value = 0.22484
#
# Running models for treatment newdiscovery_aspo_binarize and outcome d3_6incidenceU on 2509 samples
# G Model has been fit
# Q model has been fit
# AIPTW model has been fit. Returning τ hat and its standard deviation
# τ hat = -0.00718, std = 0.01556, test statistic = -0.46128, p-value = 0.32232
#
# Running models for treatment newdiscovery_aspo_binarize and outcome d3_6incidenceU on 2509 samples
#
# WARNING:
#  Some propensity scores are very small,
#  which could lead to an inflated AIPTW.
#  Minimum score =  0.005469282623380423
#
# WARNING:
#  Some propensity scores are very large,
#  which could lead to an inflated AIPTW.
#  Maximum score =  0.9963449835777283
# G Model has been fit
# Q model has been fit
# Dropped 23 observations due to overlap condition
# AIPTW model has been fit. Returning τ hat and its standard deviation
# τ hat = 0.00098, std = 0.03709, test statistic = 0.02629, p-value = 0.48951
#
# Running models for treatment newdiscovery_aspo_binarize and outcome onset2COWCS on 4977 samples
# G Model has been fit
# Q model has been fit
# AIPTW model has been fit. Returning τ hat and its standard deviation
# τ hat = 0.00478, std = 0.00363, test statistic = 1.31672, p-value = 0.094
#
# Running models for treatment newdiscovery_aspo_binarize and outcome onset2COWCS on 4977 samples
#
# WARNING:
#  Some propensity scores are very small,
#  which could lead to an inflated AIPTW.
#  Minimum score =  0.0018777363002300262
#
# WARNING:
#  Some propensity scores are very large,
#  which could lead to an inflated AIPTW.
#  Maximum score =  0.991011381149292
# G Model has been fit
# Q model has been fit
# Dropped 339 observations due to overlap condition
# AIPTW model has been fit. Returning τ hat and its standard deviation
# τ hat = 0.00475, std = 0.00641, test statistic = 0.74053, p-value = 0.22951
#
# Running models for treatment newdiscovery_aspo_binarize and outcome onsetUCS on 4307 samples
# G Model has been fit
# Q model has been fit
# AIPTW model has been fit. Returning τ hat and its standard deviation
# τ hat = 0.00741, std = 0.0063, test statistic = 1.17642, p-value = 0.11975
#
# Running models for treatment newdiscovery_aspo_binarize and outcome onsetUCS on 4307 samples
#
# WARNING:
#  Some propensity scores are very small,
#  which could lead to an inflated AIPTW.
#  Minimum score =  0.00203303131274879
#
# WARNING:
#  Some propensity scores are very large,
#  which could lead to an inflated AIPTW.
#  Maximum score =  0.9958327412605286
# G Model has been fit
# Q model has been fit
# Dropped 324 observations due to overlap condition
# AIPTW model has been fit. Returning τ hat and its standard deviation
# τ hat = 0.00784, std = 0.01453, test statistic = 0.53933, p-value = 0.29484
#
# Running models for treatment newdiscovery_aspo_binarize and outcome coup on 4849 samples
# G Model has been fit
# Q model has been fit
# AIPTW model has been fit. Returning τ hat and its standard deviation
# τ hat = -0.03699, std = 0.00998, test statistic = -3.70479, p-value = 0.00011
#
# Running models for treatment newdiscovery_aspo_binarize and outcome coup on 4849 samples
#
# WARNING:
#  Some propensity scores are very small,
#  which could lead to an inflated AIPTW.
#  Minimum score =  0.0021128894295543432
#
# WARNING:
#  Some propensity scores are very large,
#  which could lead to an inflated AIPTW.
#  Maximum score =  0.9949800372123718
# G Model has been fit
# Q model has been fit
# Dropped 271 observations due to overlap condition
# AIPTW model has been fit. Returning τ hat and its standard deviation
# τ hat = -0.01015, std = 0.02398, test statistic = -0.42355, p-value = 0.33596
#
# Running models for treatment newdiscovery_aspo_binarize and outcome periregular on 3312 samples
# G Model has been fit
# Q model has been fit
# AIPTW model has been fit. Returning τ hat and its standard deviation
# τ hat = -0.01594, std = 0.00498, test statistic = -3.19894, p-value = 0.0007
#
# Running models for treatment newdiscovery_aspo_binarize and outcome periregular on 3312 samples
#
# WARNING:
#  Some propensity scores are very small,
#  which could lead to an inflated AIPTW.
#  Minimum score =  0.001165153575129807
#
# WARNING:
#  Some propensity scores are very large,
#  which could lead to an inflated AIPTW.
#  Maximum score =  0.9976063966751099
# G Model has been fit
# Q model has been fit
# Dropped 270 observations due to overlap condition
# AIPTW model has been fit. Returning τ hat and its standard deviation
# τ hat = -0.01757, std = 0.01049, test statistic = -1.67425, p-value = 0.04709
#
# Running models for treatment newdiscovery_aspo_binarize and outcome milexp_pergdpSIPRI_diff on 1302 samples
# G Model has been fit
# Q model has been fit
# AIPTW model has been fit. Returning τ hat and its standard deviation
# τ hat = 0.00369, std = 0.14012, test statistic = 0.02634, p-value = 0.48949
#
# Running models for treatment newdiscovery_aspo_binarize and outcome milexp_pergdpSIPRI_diff on 1302 samples
#
# WARNING:
#  Some propensity scores are very small,
#  which could lead to an inflated AIPTW.
#  Minimum score =  0.0010452225105836987
#
# WARNING:
#  Some propensity scores are very large,
#  which could lead to an inflated AIPTW.
#  Maximum score =  0.9980888962745667
# G Model has been fit
# Q model has been fit
# Dropped 176 observations due to overlap condition
# AIPTW model has been fit. Returning τ hat and its standard deviation
# τ hat = 0.03495, std = 0.10933, test statistic = 0.3197, p-value = 0.37462

# %%
att_discovery_results_df
# Out:
#    model                   treatment                  outcome   tau_hat  \
# 0     rf  newdiscovery_aspo_binarize             d2incidenceU  0.002043
# 1    xgb  newdiscovery_aspo_binarize             d2incidenceU -0.018176
# 2     rf  newdiscovery_aspo_binarize           d3_6incidenceU -0.007179
# 3    xgb  newdiscovery_aspo_binarize           d3_6incidenceU  0.000975
# 4     rf  newdiscovery_aspo_binarize              onset2COWCS  0.004785
# 5    xgb  newdiscovery_aspo_binarize              onset2COWCS  0.004747
# 6     rf  newdiscovery_aspo_binarize                 onsetUCS  0.007407
# 7    xgb  newdiscovery_aspo_binarize                 onsetUCS  0.007837
# 8     rf  newdiscovery_aspo_binarize                     coup -0.036988
# 9    xgb  newdiscovery_aspo_binarize                     coup -0.010155
# 10    rf  newdiscovery_aspo_binarize              periregular -0.015940
# 11   xgb  newdiscovery_aspo_binarize              periregular -0.017569
# 12    rf  newdiscovery_aspo_binarize  milexp_pergdpSIPRI_diff  0.003691
# 13   xgb  newdiscovery_aspo_binarize  milexp_pergdpSIPRI_diff  0.034951
#
#      tau_std  test_stat   p_value
# 0   0.012810   0.159511  0.436639
# 1   0.024041  -0.756049  0.224845
# 2   0.015563  -0.461279  0.322319
# 3   0.037087   0.026291  0.489514
# 4   0.003634   1.316723  0.093996
# 5   0.006410   0.740534  0.229505
# 6   0.006296   1.176422  0.119746
# 7   0.014530   0.539333  0.294843
# 8   0.009984  -3.704788  0.000107
# 9   0.023975  -0.423549  0.335957
# 10  0.004983  -3.198940  0.000696
# 11  0.010494  -1.674245  0.047088
# 12  0.140124   0.026342  0.489494
# 13  0.109327   0.319696  0.374625

# %%
att_discovery_results_df.loc[0:3, :]
# Out:
#   model                   treatment         outcome   tau_hat   tau_std  \
# 0    rf  newdiscovery_aspo_binarize    d2incidenceU  0.002043  0.012810
# 1   xgb  newdiscovery_aspo_binarize    d2incidenceU -0.018176  0.024041
# 2    rf  newdiscovery_aspo_binarize  d3_6incidenceU -0.007179  0.015563
# 3   xgb  newdiscovery_aspo_binarize  d3_6incidenceU  0.000975  0.037087
#
#    test_stat   p_value
# 0   0.159511  0.436639
# 1  -0.756049  0.224845
# 2  -0.461279  0.322319
# 3   0.026291  0.489514

# %%
# find propensity score distribution
# for one of the models for visualization purposes
g_df = oil_df[confounders + [treatment]].dropna().reset_index()
g_df[treatment] = g_df[treatment].replace({0.0: 0, 1.0: 1})
rf_propensity = treatment_k_fold_fit_and_predict(make_g_model, g_df[confounders], g_df[treatment], n_splits=5)
xgb_propensity = treatment_k_fold_fit_and_predict(make_xgboost_g_model, g_df[confounders], g_df[treatment], n_splits=5)

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(7, 5))
hist(rf_propensity)
plt.title('Propensity Scores for Random Forest Model', fontsize=16)
plt.xlabel('Propensity Scores', fontsize=15)
plt.ylabel('Frequency', fontsize=15)
# Out:
# Text(0, 0.5, 'Frequency')

# %%
plt.figure(figsize=(7, 5))
hist(xgb_propensity)
plt.title('Propensity Scores for XGBoost Model', fontsize=16)
plt.xlabel('Propensity Scores', fontsize=15)
plt.ylabel('Frequency', fontsize=15)
# Out:
# Text(0, 0.5, 'Frequency')

# %%
# reset treatment and outcome list
treatment_lst = ['valoilres_binarize', # value of oil reserves
               'valoilres_public_binarize', # value of oil reserves from public data
               'oilpop_binarize', # oil reserves per capita in million barrels per 1000 persons
               'valoilres_impute_binarize', # value of oilpop_impute (multiply by crude oil price)
               'oilpop_impute_binarize']

outcome_lst = ['onset2COWCS',
               'onsetUCS',
               'coup',
               'periregular',
               'milexp_pergdpSIPRI_diff']

# %%
# similar process, but utilizing the other function for 
# heterogenous effects
df_dict = {'model': [], 'democracy': [], 'treatment': [], 'outcome': [], 'tau_hat': [], 'tau_std': [], 'test_stat': [], 'p_value': []}
for treat in treatment_lst:
    for out in outcome_lst:
        for model_type in ['rf', 'xgb']:
            if len(oil_df[out].value_counts()) == 2:
                output = 'binary'
            else:
                output = 'continuous'
            if model_type == 'rf':
                tau_hat_demo, std_hat_demo, test_stat_demo, p_value_demo, tau_hat_nondemo, std_hat_nondemo, test_stat_nondemo, p_value_nondemo = fit_and_run_model_democracy(oil_df, out, treat, confounders, make_g_model, make_Q_model, output_type=output, ate=False)
            else:
                tau_hat_demo, std_hat_demo, test_stat_demo, p_value_demo, tau_hat_nondemo, std_hat_nondemo, test_stat_nondemo, p_value_nondemo = fit_and_run_model_democracy(oil_df, out, treat, confounders, make_xgboost_g_model, make_xgboost_Q_model, output_type=output, ate=False)
            df_dict['model'].append(model_type)
            df_dict['democracy'].append('demo')
            df_dict['treatment'].append(treat)
            df_dict['outcome'].append(out)
            df_dict['tau_hat'].append(tau_hat_demo)
            df_dict['tau_std'].append(std_hat_demo)
            df_dict['test_stat'].append(test_stat_demo)
            df_dict['p_value'].append(p_value_demo)
            df_dict['model'].append(model_type)
            df_dict['democracy'].append('nondemo')
            df_dict['treatment'].append(treat)
            df_dict['outcome'].append(out)
            df_dict['tau_hat'].append(tau_hat_nondemo)
            df_dict['tau_std'].append(std_hat_nondemo)
            df_dict['test_stat'].append(test_stat_nondemo)
            df_dict['p_value'].append(p_value_nondemo)

att_democracy_results_df = pd.DataFrame(data=df_dict)
# Out:
# Running models for treatment valoilres_binarize and outcome onset2COWCS on 5124 samples
# G Model has been fit
# Q model has been fit
# Running models for treatment valoilres_binarize and outcome onset2COWCS on 5124 samples
#
# WARNING:
#  Some propensity scores are very small,
#  which could lead to an inflated AIPTW.
#  Minimum score =  0.0001718762650853023
#
# WARNING:
#  Some propensity scores are very large,
#  which could lead to an inflated AIPTW.
#  Maximum score =  0.998391330242157
# G Model has been fit
# Q model has been fit
# Dropped 1638 observations due to overlap condition
# Running models for treatment valoilres_binarize and outcome onsetUCS on 4491 samples
# G Model has been fit
# Q model has been fit
# Running models for treatment valoilres_binarize and outcome onsetUCS on 4491 samples
#
# WARNING:
#  Some propensity scores are very small,
#  which could lead to an inflated AIPTW.
#  Minimum score =  9.31727554416284e-05
#
# WARNING:
#  Some propensity scores are very large,
#  which could lead to an inflated AIPTW.
#  Maximum score =  0.9991288781166077
# G Model has been fit
# Q model has been fit
# Dropped 1542 observations due to overlap condition
# Running models for treatment valoilres_binarize and outcome coup on 5050 samples
# G Model has been fit
# Q model has been fit
# Running models for treatment valoilres_binarize and outcome coup on 5050 samples
#
# WARNING:
#  Some propensity scores are very small,
#  which could lead to an inflated AIPTW.
#  Minimum score =  0.00012927815259899944
#
# WARNING:
#  Some propensity scores are very large,
#  which could lead to an inflated AIPTW.
#  Maximum score =  0.9990501999855042
# G Model has been fit
# Q model has been fit
# Dropped 1697 observations due to overlap condition
# Running models for treatment valoilres_binarize and outcome periregular on 3277 samples
# G Model has been fit
# Q model has been fit
# Running models for treatment valoilres_binarize and outcome periregular on 3277 samples
#
# WARNING:
#  Some propensity scores are very small,
#  which could lead to an inflated AIPTW.
#  Minimum score =  0.000684520578943193
#
# WARNING:
#  Some propensity scores are very large,
#  which could lead to an inflated AIPTW.
#  Maximum score =  0.9938547015190125
# G Model has been fit
# Q model has been fit
# Dropped 887 observations due to overlap condition
# Running models for treatment valoilres_binarize and outcome milexp_pergdpSIPRI_diff on 1288 samples
#
# WARNING:
#  Some propensity scores are very small,
#  which could lead to an inflated AIPTW.
#  Minimum score =  0.007554406076929955
# G Model has been fit
# Q model has been fit
# Running models for treatment valoilres_binarize and outcome milexp_pergdpSIPRI_diff on 1288 samples
#
# WARNING:
#  Some propensity scores are very small,
#  which could lead to an inflated AIPTW.
#  Minimum score =  6.0283571656327695e-05
#
# WARNING:
#  Some propensity scores are very large,
#  which could lead to an inflated AIPTW.
#  Maximum score =  0.9992812275886536
# G Model has been fit
# Q model has been fit
# Dropped 772 observations due to overlap condition
# Running models for treatment valoilres_public_binarize and outcome onset2COWCS on 4138 samples
# G Model has been fit
# Q model has been fit
# Running models for treatment valoilres_public_binarize and outcome onset2COWCS on 4138 samples
#
# WARNING:
#  Some propensity scores are very small,
#  which could lead to an inflated AIPTW.
#  Minimum score =  0.00037911703111603856
#
# WARNING:
#  Some propensity scores are very large,
#  which could lead to an inflated AIPTW.
#  Maximum score =  0.9953054785728455
# G Model has been fit
# Q model has been fit
# Dropped 737 observations due to overlap condition
# Running models for treatment valoilres_public_binarize and outcome onsetUCS on 3948 samples
# G Model has been fit
# Q model has been fit
# Running models for treatment valoilres_public_binarize and outcome onsetUCS on 3948 samples
#
# WARNING:
#  Some propensity scores are very small,
#  which could lead to an inflated AIPTW.
#  Minimum score =  0.00032221831497736275
#
# WARNING:
#  Some propensity scores are very large,
#  which could lead to an inflated AIPTW.
#  Maximum score =  0.9967644214630127
# G Model has been fit
# Q model has been fit
# Dropped 732 observations due to overlap condition
# Running models for treatment valoilres_public_binarize and outcome coup on 4455 samples
# G Model has been fit
# Q model has been fit
# Running models for treatment valoilres_public_binarize and outcome coup on 4455 samples
#
# WARNING:
#  Some propensity scores are very small,
#  which could lead to an inflated AIPTW.
#  Minimum score =  0.0002776185283437371
#
# WARNING:
#  Some propensity scores are very large,
#  which could lead to an inflated AIPTW.
#  Maximum score =  0.9914899468421936
# G Model has been fit
# Q model has been fit
# Dropped 920 observations due to overlap condition
# Running models for treatment valoilres_public_binarize and outcome periregular on 2302 samples
# G Model has been fit
# Q model has been fit
# Running models for treatment valoilres_public_binarize and outcome periregular on 2302 samples
#
# WARNING:
#  Some propensity scores are very small,
#  which could lead to an inflated AIPTW.
#  Minimum score =  0.0013578087091445923
#
# WARNING:
#  Some propensity scores are very large,
#  which could lead to an inflated AIPTW.
#  Maximum score =  0.9937604069709778
# G Model has been fit
# Q model has been fit
# Dropped 253 observations due to overlap condition
# Running models for treatment valoilres_public_binarize and outcome milexp_pergdpSIPRI_diff on 1267 samples
#
# WARNING:
#  Some propensity scores are very small,
#  which could lead to an inflated AIPTW.
#  Minimum score =  0.007627079945326977
# G Model has been fit
# Q model has been fit
# Running models for treatment valoilres_public_binarize and outcome milexp_pergdpSIPRI_diff on 1267 samples
#
# WARNING:
#  Some propensity scores are very small,
#  which could lead to an inflated AIPTW.
#  Minimum score =  9.452235826756805e-05
#
# WARNING:
#  Some propensity scores are very large,
#  which could lead to an inflated AIPTW.
#  Maximum score =  0.9967760443687439
# G Model has been fit
# Q model has been fit
# Dropped 549 observations due to overlap condition
# Running models for treatment oilpop_binarize and outcome onset2COWCS on 5124 samples
#
# WARNING:
#  Some propensity scores are very small,
#  which could lead to an inflated AIPTW.
#  Minimum score =  0.004090716574776723
# G Model has been fit
# Q model has been fit
# Running models for treatment oilpop_binarize and outcome onset2COWCS on 5124 samples
#
# WARNING:
#  Some propensity scores are very small,
#  which could lead to an inflated AIPTW.
#  Minimum score =  0.0002257275627925992
# G Model has been fit
# Q model has been fit
# Running models for treatment oilpop_binarize and outcome onsetUCS on 4491 samples
#
# WARNING:
#  Some propensity scores are very small,
#  which could lead to an inflated AIPTW.
#  Minimum score =  0.0031122806756422776
# G Model has been fit
# Q model has been fit
# Running models for treatment oilpop_binarize and outcome onsetUCS on 4491 samples
#
# WARNING:
#  Some propensity scores are very small,
#  which could lead to an inflated AIPTW.
#  Minimum score =  0.00017353618750348687
# G Model has been fit
# Q model has been fit
# Running models for treatment oilpop_binarize and outcome coup on 5050 samples
#
# WARNING:
#  Some propensity scores are very small,
#  which could lead to an inflated AIPTW.
#  Minimum score =  0.005909508614868438
# G Model has been fit
# Q model has been fit
# Running models for treatment oilpop_binarize and outcome coup on 5050 samples
#
# WARNING:
#  Some propensity scores are very small,
#  which could lead to an inflated AIPTW.
#  Minimum score =  0.00025975960306823254
# G Model has been fit
# Q model has been fit
# Running models for treatment oilpop_binarize and outcome periregular on 3277 samples
#
# WARNING:
#  Some propensity scores are very small,
#  which could lead to an inflated AIPTW.
#  Minimum score =  0.008511785407699854
# G Model has been fit
# Q model has been fit
# Running models for treatment oilpop_binarize and outcome periregular on 3277 samples
#
# WARNING:
#  Some propensity scores are very small,
#  which could lead to an inflated AIPTW.
#  Minimum score =  0.000615473953075707
# G Model has been fit
# Q model has been fit
# Running models for treatment oilpop_binarize and outcome milexp_pergdpSIPRI_diff on 1288 samples
#
# WARNING:
#  Some propensity scores are very small,
#  which could lead to an inflated AIPTW.
#  Minimum score =  0.0003331422427610308
# G Model has been fit
# Q model has been fit
# Running models for treatment oilpop_binarize and outcome milexp_pergdpSIPRI_diff on 1288 samples
#
# WARNING:
#  Some propensity scores are very small,
#  which could lead to an inflated AIPTW.
#  Minimum score =  3.679205838125199e-05
# G Model has been fit
# Q model has been fit
# Running models for treatment valoilres_impute_binarize and outcome onset2COWCS on 5124 samples
# G Model has been fit
# Q model has been fit
# Running models for treatment valoilres_impute_binarize and outcome onset2COWCS on 5124 samples
#
# WARNING:
#  Some propensity scores are very small,
#  which could lead to an inflated AIPTW.
#  Minimum score =  0.00014290718536358327
#
# WARNING:
#  Some propensity scores are very large,
#  which could lead to an inflated AIPTW.
#  Maximum score =  0.9986017346382141
# G Model has been fit
# Q model has been fit
# Dropped 1651 observations due to overlap condition
# Running models for treatment valoilres_impute_binarize and outcome onsetUCS on 4491 samples
# G Model has been fit
# Q model has been fit
# Running models for treatment valoilres_impute_binarize and outcome onsetUCS on 4491 samples
#
# WARNING:
#  Some propensity scores are very small,
#  which could lead to an inflated AIPTW.
#  Minimum score =  0.00017624095198698342
#
# WARNING:
#  Some propensity scores are very large,
#  which could lead to an inflated AIPTW.
#  Maximum score =  0.9991393089294434
# G Model has been fit
# Q model has been fit
# Dropped 1568 observations due to overlap condition
# Running models for treatment valoilres_impute_binarize and outcome coup on 5050 samples
# G Model has been fit
# Q model has been fit
# Running models for treatment valoilres_impute_binarize and outcome coup on 5050 samples
#
# WARNING:
#  Some propensity scores are very small,
#  which could lead to an inflated AIPTW.
#  Minimum score =  0.0001308233040617779
#
# WARNING:
#  Some propensity scores are very large,
#  which could lead to an inflated AIPTW.
#  Maximum score =  0.9979496598243713
# G Model has been fit
# Q model has been fit
# Dropped 1744 observations due to overlap condition
# Running models for treatment valoilres_impute_binarize and outcome periregular on 3277 samples
# G Model has been fit
# Q model has been fit
# Running models for treatment valoilres_impute_binarize and outcome periregular on 3277 samples
#
# WARNING:
#  Some propensity scores are very small,
#  which could lead to an inflated AIPTW.
#  Minimum score =  0.000684520578943193
#
# WARNING:
#  Some propensity scores are very large,
#  which could lead to an inflated AIPTW.
#  Maximum score =  0.9938547015190125
# G Model has been fit
# Q model has been fit
# Dropped 887 observations due to overlap condition
# Running models for treatment valoilres_impute_binarize and outcome milexp_pergdpSIPRI_diff on 1288 samples
#
# WARNING:
#  Some propensity scores are very small,
#  which could lead to an inflated AIPTW.
#  Minimum score =  0.006345610328785243
# G Model has been fit
# Q model has been fit
# Running models for treatment valoilres_impute_binarize and outcome milexp_pergdpSIPRI_diff on 1288 samples
#
# WARNING:
#  Some propensity scores are very small,
#  which could lead to an inflated AIPTW.
#  Minimum score =  6.0283571656327695e-05
#
# WARNING:
#  Some propensity scores are very large,
#  which could lead to an inflated AIPTW.
#  Maximum score =  0.9992812275886536
# G Model has been fit
# Q model has been fit
# Dropped 772 observations due to overlap condition
# Running models for treatment oilpop_impute_binarize and outcome onset2COWCS on 5124 samples
#
# WARNING:
#  Some propensity scores are very small,
#  which could lead to an inflated AIPTW.
#  Minimum score =  0.005250288201907263
# G Model has been fit
# Q model has been fit
# Running models for treatment oilpop_impute_binarize and outcome onset2COWCS on 5124 samples
#
# WARNING:
#  Some propensity scores are very small,
#  which could lead to an inflated AIPTW.
#  Minimum score =  0.00019344342581462115
# G Model has been fit
# Q model has been fit
# Running models for treatment oilpop_impute_binarize and outcome onsetUCS on 4491 samples
#
# WARNING:
#  Some propensity scores are very small,
#  which could lead to an inflated AIPTW.
#  Minimum score =  0.006244889513000717
# G Model has been fit
# Q model has been fit
# Running models for treatment oilpop_impute_binarize and outcome onsetUCS on 4491 samples
#
# WARNING:
#  Some propensity scores are very small,
#  which could lead to an inflated AIPTW.
#  Minimum score =  0.0003015538677573204
# G Model has been fit
# Q model has been fit
# Running models for treatment oilpop_impute_binarize and outcome coup on 5050 samples
#
# WARNING:
#  Some propensity scores are very small,
#  which could lead to an inflated AIPTW.
#  Minimum score =  0.004473787509182055
# G Model has been fit
# Q model has been fit
# Running models for treatment oilpop_impute_binarize and outcome coup on 5050 samples
#
# WARNING:
#  Some propensity scores are very small,
#  which could lead to an inflated AIPTW.
#  Minimum score =  0.00026368116959929466
# G Model has been fit
# Q model has been fit
# Running models for treatment oilpop_impute_binarize and outcome periregular on 3277 samples
#
# WARNING:
#  Some propensity scores are very small,
#  which could lead to an inflated AIPTW.
#  Minimum score =  0.007317378894752674
# G Model has been fit
# Q model has been fit
# Running models for treatment oilpop_impute_binarize and outcome periregular on 3277 samples
#
# WARNING:
#  Some propensity scores are very small,
#  which could lead to an inflated AIPTW.
#  Minimum score =  0.000615473953075707
# G Model has been fit
# Q model has been fit
# Running models for treatment oilpop_impute_binarize and outcome milexp_pergdpSIPRI_diff on 1288 samples
#
# WARNING:
#  Some propensity scores are very small,
#  which could lead to an inflated AIPTW.
#  Minimum score =  0.0006740615210429775
# G Model has been fit
# Q model has been fit
# Running models for treatment oilpop_impute_binarize and outcome milexp_pergdpSIPRI_diff on 1288 samples
#
# WARNING:
#  Some propensity scores are very small,
#  which could lead to an inflated AIPTW.
#  Minimum score =  3.679205838125199e-05
# G Model has been fit
# Q model has been fit

# %%
# democracy and nondemocracy results
att_democracy_results_df
# Out:
#    model democracy               treatment                  outcome   tau_hat  \
# 0     rf      demo      valoilres_binarize              onset2COWCS -0.000383
# 1     rf   nondemo      valoilres_binarize              onset2COWCS  0.003078
# 2    xgb      demo      valoilres_binarize              onset2COWCS -0.005328
# 3    xgb   nondemo      valoilres_binarize              onset2COWCS -0.024841
# 4     rf      demo      valoilres_binarize                 onsetUCS  0.011293
# ..   ...       ...                     ...                      ...       ...
# 95   xgb   nondemo  oilpop_impute_binarize              periregular -0.012129
# 96    rf      demo  oilpop_impute_binarize  milexp_pergdpSIPRI_diff  0.382090
# 97    rf   nondemo  oilpop_impute_binarize  milexp_pergdpSIPRI_diff  5.759621
# 98   xgb      demo  oilpop_impute_binarize  milexp_pergdpSIPRI_diff  7.164805
# 99   xgb   nondemo  oilpop_impute_binarize  milexp_pergdpSIPRI_diff  4.715068
#
#      tau_std  test_stat   p_value
# 0   0.003071  -0.124660  0.450401
# 1   0.008852   0.347677  0.364055
# 2   0.004251  -1.253165  0.105159
# 3   0.039308  -0.631966  0.263745
# 4   0.008934   1.264042  0.103176
# ..       ...        ...       ...
# 95  0.017556  -0.690871  0.244866
# 96  0.353341   1.081363  0.139929
# 97  5.417759   1.063100  0.144137
# 98  7.195176   0.995779  0.159828
# 99  4.793272   0.983685  0.162884
#
# [100 rows x 8 columns]

# %%
# subsamples of the att_democracy_results_df
att_demo_results = att_democracy_results_df[att_democracy_results_df['democracy'] == 'demo']
att_nondemo_results = att_democracy_results_df[att_democracy_results_df['democracy'] == 'nondemo']

# %%
# only certain entries for the sake of space in the paper, but all were examined
att_demo_temp = att_demo_results[(att_demo_results['treatment'] == 'valoilres_binarize') | (att_demo_results['treatment'] == 'oilpop_binarize')].reset_index(drop=True)
att_nondemo_temp = att_nondemo_results[(att_nondemo_results['treatment'] == 'valoilres_binarize') | (att_nondemo_results['treatment'] == 'oilpop_binarize')].reset_index(drop=True)

# %%
att_demo_temp[att_demo_temp['outcome'].isin(['onset2COWCS', 'coup', 'periregular', 'milexp_pergdpSIPRI_diff'])].sort_values(by=['outcome', 'treatment', 'model']).reset_index(drop=True).drop('democracy', axis=1)
# Out:
#    model           treatment                  outcome   tau_hat   tau_std  \
# 0     rf     oilpop_binarize                     coup  0.015277  0.015947
# 1    xgb     oilpop_binarize                     coup -0.008449  0.029862
# 2     rf  valoilres_binarize                     coup  0.011720  0.010239
# 3    xgb  valoilres_binarize                     coup  0.055809  0.043246
# 4     rf     oilpop_binarize  milexp_pergdpSIPRI_diff  0.530314  0.549485
# 5    xgb     oilpop_binarize  milexp_pergdpSIPRI_diff  7.164805  7.195176
# 6     rf  valoilres_binarize  milexp_pergdpSIPRI_diff -0.009669  0.022439
# 7    xgb  valoilres_binarize  milexp_pergdpSIPRI_diff -0.174507  0.086964
# 8     rf     oilpop_binarize              onset2COWCS -0.007163  0.003660
# 9    xgb     oilpop_binarize              onset2COWCS -0.023302  0.015872
# 10    rf  valoilres_binarize              onset2COWCS -0.000383  0.003071
# 11   xgb  valoilres_binarize              onset2COWCS -0.005328  0.004251
# 12    rf     oilpop_binarize              periregular  0.005826  0.004053
# 13   xgb     oilpop_binarize              periregular -0.007567  0.009049
# 14    rf  valoilres_binarize              periregular -0.000737  0.004058
# 15   xgb  valoilres_binarize              periregular -0.008859  0.007592
#
#     test_stat   p_value
# 0    0.957995  0.169081
# 1   -0.282946  0.388621
# 2    1.144562  0.126252
# 3    1.290504  0.098531
# 4    0.965112  0.167389
# 5    0.995779  0.159828
# 6   -0.430893  0.333331
# 7   -2.006655  0.022823
# 8   -1.957094  0.025224
# 9   -1.468144  0.071095
# 10  -0.124660  0.450401
# 11  -1.253165  0.105159
# 12   1.437387  0.075416
# 13  -0.836242  0.201581
# 14  -0.181557  0.427979
# 15  -1.166831  0.121775

# %%
att_nondemo_temp[att_nondemo_temp['outcome'].isin(['onset2COWCS', 'coup', 'periregular', 'milexp_pergdpSIPRI_diff'])].sort_values(by=['outcome', 'treatment', 'model']).reset_index(drop=True).drop('democracy', axis=1)
# Out:
#    model           treatment                  outcome   tau_hat   tau_std  \
# 0     rf     oilpop_binarize                     coup -0.041599  0.042245
# 1    xgb     oilpop_binarize                     coup -0.057552  0.052347
# 2     rf  valoilres_binarize                     coup -0.024356  0.023339
# 3    xgb  valoilres_binarize                     coup  0.015975  0.031459
# 4     rf     oilpop_binarize  milexp_pergdpSIPRI_diff  5.824807  5.420014
# 5    xgb     oilpop_binarize  milexp_pergdpSIPRI_diff  4.715068  4.793272
# 6     rf  valoilres_binarize  milexp_pergdpSIPRI_diff  0.959381  0.937215
# 7    xgb  valoilres_binarize  milexp_pergdpSIPRI_diff  1.234342  1.039887
# 8     rf     oilpop_binarize              onset2COWCS  0.005086  0.014961
# 9    xgb     oilpop_binarize              onset2COWCS -0.000261  0.018183
# 10    rf  valoilres_binarize              onset2COWCS  0.003078  0.008852
# 11   xgb  valoilres_binarize              onset2COWCS -0.024841  0.039308
# 12    rf     oilpop_binarize              periregular  0.005316  0.012703
# 13   xgb     oilpop_binarize              periregular -0.012129  0.017556
# 14    rf  valoilres_binarize              periregular -0.010959  0.009975
# 15   xgb  valoilres_binarize              periregular -0.014562  0.016919
#
#     test_stat   p_value
# 0   -0.984706  0.162429
# 1   -1.099439  0.135838
# 2   -1.043578  0.148388
# 3    0.507805  0.305827
# 4    1.074685  0.141529
# 5    0.983685  0.162884
# 6    1.023651  0.153259
# 7    1.186996  0.118315
# 8    0.339972  0.366952
# 9   -0.014339  0.494280
# 10   0.347677  0.364055
# 11  -0.631966  0.263745
# 12   0.418521  0.337807
# 13  -0.690871  0.244866
# 14  -1.098670  0.136026
# 15  -0.860723  0.194771

# %%
# reset treatments and outcomes
treatment_lst = ['newdiscovery_aspo_binarize']
outcome_lst = ['d2incidenceU',
               'd3_6incidenceU',
               'onset2COWCS',
               'onsetUCS',
               'coup',
               'periregular',
               'milexp_pergdpSIPRI_diff']

# %%
# similar process, but utilizing the other function for 
# heterogenous effects
df_dict = {'model': [], 'democracy': [], 'treatment': [], 'outcome': [], 'tau_hat': [], 'tau_std': [], 'test_stat': [], 'p_value': []}
for treat in treatment_lst:
    for out in outcome_lst:
        for model_type in ['rf', 'xgb']:
            if len(oil_df[out].value_counts()) == 2:
                output = 'binary'
            else:
                output = 'continuous'
            if model_type == 'rf':
                tau_hat_demo, std_hat_demo, test_stat_demo, p_value_demo, tau_hat_nondemo, std_hat_nondemo, test_stat_nondemo, p_value_nondemo = fit_and_run_model_democracy(oil_df, out, treat, confounders, make_g_model, make_Q_model, output_type=output, ate=False)
            else:
                tau_hat_demo, std_hat_demo, test_stat_demo, p_value_demo, tau_hat_nondemo, std_hat_nondemo, test_stat_nondemo, p_value_nondemo = fit_and_run_model_democracy(oil_df, out, treat, confounders, make_xgboost_g_model, make_xgboost_Q_model, output_type=output, ate=False)
            df_dict['model'].append(model_type)
            df_dict['democracy'].append('demo')
            df_dict['treatment'].append(treat)
            df_dict['outcome'].append(out)
            df_dict['tau_hat'].append(tau_hat_demo)
            df_dict['tau_std'].append(std_hat_demo)
            df_dict['test_stat'].append(test_stat_demo)
            df_dict['p_value'].append(p_value_demo)
            df_dict['model'].append(model_type)
            df_dict['democracy'].append('nondemo')
            df_dict['treatment'].append(treat)
            df_dict['outcome'].append(out)
            df_dict['tau_hat'].append(tau_hat_nondemo)
            df_dict['tau_std'].append(std_hat_nondemo)
            df_dict['test_stat'].append(test_stat_nondemo)
            df_dict['p_value'].append(p_value_nondemo)

att_democracy_discovery_results_df = pd.DataFrame(data=df_dict)
# Out:
# Running models for treatment newdiscovery_aspo_binarize and outcome d2incidenceU on 2553 samples
# G Model has been fit
# Q model has been fit
# Running models for treatment newdiscovery_aspo_binarize and outcome d2incidenceU on 2553 samples
#
# WARNING:
#  Some propensity scores are very small,
#  which could lead to an inflated AIPTW.
#  Minimum score =  0.006092668976634741
#
# WARNING:
#  Some propensity scores are very large,
#  which could lead to an inflated AIPTW.
#  Maximum score =  0.9949499368667603
# G Model has been fit
# Q model has been fit
# Dropped 20 observations due to overlap condition
# Running models for treatment newdiscovery_aspo_binarize and outcome d3_6incidenceU on 2502 samples
# G Model has been fit
# Q model has been fit
# Running models for treatment newdiscovery_aspo_binarize and outcome d3_6incidenceU on 2502 samples
#
# WARNING:
#  Some propensity scores are very small,
#  which could lead to an inflated AIPTW.
#  Minimum score =  0.002710543805733323
#
# WARNING:
#  Some propensity scores are very large,
#  which could lead to an inflated AIPTW.
#  Maximum score =  0.9952438473701477
# G Model has been fit
# Q model has been fit
# Dropped 17 observations due to overlap condition
# Running models for treatment newdiscovery_aspo_binarize and outcome onset2COWCS on 4929 samples
# G Model has been fit
# Q model has been fit
# Running models for treatment newdiscovery_aspo_binarize and outcome onset2COWCS on 4929 samples
#
# WARNING:
#  Some propensity scores are very small,
#  which could lead to an inflated AIPTW.
#  Minimum score =  0.0011724907672032714
#
# WARNING:
#  Some propensity scores are very large,
#  which could lead to an inflated AIPTW.
#  Maximum score =  0.9949265718460083
# G Model has been fit
# Q model has been fit
# Dropped 330 observations due to overlap condition
# Running models for treatment newdiscovery_aspo_binarize and outcome onsetUCS on 4283 samples
# G Model has been fit
# Q model has been fit
# Running models for treatment newdiscovery_aspo_binarize and outcome onsetUCS on 4283 samples
#
# WARNING:
#  Some propensity scores are very small,
#  which could lead to an inflated AIPTW.
#  Minimum score =  0.0023777876049280167
#
# WARNING:
#  Some propensity scores are very large,
#  which could lead to an inflated AIPTW.
#  Maximum score =  0.9950704574584961
# G Model has been fit
# Q model has been fit
# Dropped 323 observations due to overlap condition
# Running models for treatment newdiscovery_aspo_binarize and outcome coup on 4814 samples
# G Model has been fit
# Q model has been fit
# Running models for treatment newdiscovery_aspo_binarize and outcome coup on 4814 samples
#
# WARNING:
#  Some propensity scores are very small,
#  which could lead to an inflated AIPTW.
#  Minimum score =  0.0010773306712508202
#
# WARNING:
#  Some propensity scores are very large,
#  which could lead to an inflated AIPTW.
#  Maximum score =  0.9936805963516235
# G Model has been fit
# Q model has been fit
# Dropped 328 observations due to overlap condition
# Running models for treatment newdiscovery_aspo_binarize and outcome periregular on 3277 samples
# G Model has been fit
# Q model has been fit
# Running models for treatment newdiscovery_aspo_binarize and outcome periregular on 3277 samples
#
# WARNING:
#  Some propensity scores are very small,
#  which could lead to an inflated AIPTW.
#  Minimum score =  0.0010921322973445058
#
# WARNING:
#  Some propensity scores are very large,
#  which could lead to an inflated AIPTW.
#  Maximum score =  0.9950620532035828
# G Model has been fit
# Q model has been fit
# Dropped 246 observations due to overlap condition
# Running models for treatment newdiscovery_aspo_binarize and outcome milexp_pergdpSIPRI_diff on 1288 samples
# G Model has been fit
# Q model has been fit
# Running models for treatment newdiscovery_aspo_binarize and outcome milexp_pergdpSIPRI_diff on 1288 samples
#
# WARNING:
#  Some propensity scores are very small,
#  which could lead to an inflated AIPTW.
#  Minimum score =  0.0019641369581222534
#
# WARNING:
#  Some propensity scores are very large,
#  which could lead to an inflated AIPTW.
#  Maximum score =  0.9973478317260742
# G Model has been fit
# Q model has been fit
# Dropped 162 observations due to overlap condition

# %%
att_democracy_discovery_results_df
# Out:
#    model democracy                   treatment                  outcome  \
# 0     rf      demo  newdiscovery_aspo_binarize             d2incidenceU
# 1     rf   nondemo  newdiscovery_aspo_binarize             d2incidenceU
# 2    xgb      demo  newdiscovery_aspo_binarize             d2incidenceU
# 3    xgb   nondemo  newdiscovery_aspo_binarize             d2incidenceU
# 4     rf      demo  newdiscovery_aspo_binarize           d3_6incidenceU
# 5     rf   nondemo  newdiscovery_aspo_binarize           d3_6incidenceU
# 6    xgb      demo  newdiscovery_aspo_binarize           d3_6incidenceU
# 7    xgb   nondemo  newdiscovery_aspo_binarize           d3_6incidenceU
# 8     rf      demo  newdiscovery_aspo_binarize              onset2COWCS
# 9     rf   nondemo  newdiscovery_aspo_binarize              onset2COWCS
# 10   xgb      demo  newdiscovery_aspo_binarize              onset2COWCS
# 11   xgb   nondemo  newdiscovery_aspo_binarize              onset2COWCS
# 12    rf      demo  newdiscovery_aspo_binarize                 onsetUCS
# 13    rf   nondemo  newdiscovery_aspo_binarize                 onsetUCS
# 14   xgb      demo  newdiscovery_aspo_binarize                 onsetUCS
# 15   xgb   nondemo  newdiscovery_aspo_binarize                 onsetUCS
# 16    rf      demo  newdiscovery_aspo_binarize                     coup
# 17    rf   nondemo  newdiscovery_aspo_binarize                     coup
# 18   xgb      demo  newdiscovery_aspo_binarize                     coup
# 19   xgb   nondemo  newdiscovery_aspo_binarize                     coup
# 20    rf      demo  newdiscovery_aspo_binarize              periregular
# 21    rf   nondemo  newdiscovery_aspo_binarize              periregular
# 22   xgb      demo  newdiscovery_aspo_binarize              periregular
# 23   xgb   nondemo  newdiscovery_aspo_binarize              periregular
# 24    rf      demo  newdiscovery_aspo_binarize  milexp_pergdpSIPRI_diff
# 25    rf   nondemo  newdiscovery_aspo_binarize  milexp_pergdpSIPRI_diff
# 26   xgb      demo  newdiscovery_aspo_binarize  milexp_pergdpSIPRI_diff
# 27   xgb   nondemo  newdiscovery_aspo_binarize  milexp_pergdpSIPRI_diff
#
#      tau_hat   tau_std  test_stat   p_value
# 0   0.006154  0.014911   0.412681  0.339955
# 1   0.000282  0.020412   0.013792  0.494499
# 2   0.003132  0.019798   0.158220  0.437155
# 3  -0.063703  0.044585  -1.428785  0.076656
# 4  -0.019289  0.020867  -0.924359  0.177740
# 5   0.017576  0.023436   0.749964  0.226708
# 6  -0.054286  0.048567  -1.117769  0.131942
# 7   0.027435  0.038602   0.710709  0.238698
# 8   0.004411  0.003614   1.220526  0.111194
# 9   0.010613  0.005952   1.783207  0.037336
# 10 -0.000268  0.005860  -0.045701  0.481776
# 11  0.016753  0.006349   2.638581  0.004190
# 12  0.019336  0.007452   2.594773  0.004767
# 13  0.007446  0.009269   0.803352  0.210928
# 14  0.015384  0.020539   0.749025  0.226967
# 15 -0.034585  0.048365  -0.715077  0.237322
# 16 -0.003714  0.007781  -0.477271  0.316608
# 17 -0.055799  0.018396  -3.033267  0.001222
# 18  0.014943  0.028938   0.516384  0.302820
# 19 -0.023319  0.042991  -0.542411  0.293794
# 20  0.004616  0.003814   1.210285  0.113187
# 21 -0.018897  0.008092  -2.335098  0.009821
# 22 -0.004903  0.007945  -0.617159  0.268620
# 23 -0.048081  0.021671  -2.218683  0.013318
# 24 -0.045070  0.024074  -1.872156  0.030773
# 25  0.140043  0.432571   0.323746  0.373136
# 26 -0.046630  0.034742  -1.342180  0.089977
# 27  0.392970  0.578785   0.678957  0.248782

# %%
# subsamples of the att_democracy_results_df
att_demo_disco_results = att_democracy_discovery_results_df[att_democracy_discovery_results_df['democracy'] == 'demo']
att_nondemo_disco_results = att_democracy_discovery_results_df[att_democracy_discovery_results_df['democracy'] == 'nondemo']

# %%
att_demo_disco_results
# Out:
#    model democracy                   treatment                  outcome  \
# 0     rf      demo  newdiscovery_aspo_binarize             d2incidenceU
# 2    xgb      demo  newdiscovery_aspo_binarize             d2incidenceU
# 4     rf      demo  newdiscovery_aspo_binarize           d3_6incidenceU
# 6    xgb      demo  newdiscovery_aspo_binarize           d3_6incidenceU
# 8     rf      demo  newdiscovery_aspo_binarize              onset2COWCS
# 10   xgb      demo  newdiscovery_aspo_binarize              onset2COWCS
# 12    rf      demo  newdiscovery_aspo_binarize                 onsetUCS
# 14   xgb      demo  newdiscovery_aspo_binarize                 onsetUCS
# 16    rf      demo  newdiscovery_aspo_binarize                     coup
# 18   xgb      demo  newdiscovery_aspo_binarize                     coup
# 20    rf      demo  newdiscovery_aspo_binarize              periregular
# 22   xgb      demo  newdiscovery_aspo_binarize              periregular
# 24    rf      demo  newdiscovery_aspo_binarize  milexp_pergdpSIPRI_diff
# 26   xgb      demo  newdiscovery_aspo_binarize  milexp_pergdpSIPRI_diff
#
#      tau_hat   tau_std  test_stat   p_value
# 0   0.006154  0.014911   0.412681  0.339955
# 2   0.003132  0.019798   0.158220  0.437155
# 4  -0.019289  0.020867  -0.924359  0.177740
# 6  -0.054286  0.048567  -1.117769  0.131942
# 8   0.004411  0.003614   1.220526  0.111194
# 10 -0.000268  0.005860  -0.045701  0.481776
# 12  0.019336  0.007452   2.594773  0.004767
# 14  0.015384  0.020539   0.749025  0.226967
# 16 -0.003714  0.007781  -0.477271  0.316608
# 18  0.014943  0.028938   0.516384  0.302820
# 20  0.004616  0.003814   1.210285  0.113187
# 22 -0.004903  0.007945  -0.617159  0.268620
# 24 -0.045070  0.024074  -1.872156  0.030773
# 26 -0.046630  0.034742  -1.342180  0.089977

# %%
att_demo_disco_results[att_demo_disco_results['outcome'].isin(['onset2COWCS', 'coup', 'periregular', 'milexp_pergdpSIPRI_diff'])].sort_values(by=['outcome', 'treatment', 'model']).reset_index(drop=True).drop('democracy', axis=1)
# Out:
#   model                   treatment                  outcome   tau_hat  \
# 0    rf  newdiscovery_aspo_binarize                     coup -0.003714
# 1   xgb  newdiscovery_aspo_binarize                     coup  0.014943
# 2    rf  newdiscovery_aspo_binarize  milexp_pergdpSIPRI_diff -0.045070
# 3   xgb  newdiscovery_aspo_binarize  milexp_pergdpSIPRI_diff -0.046630
# 4    rf  newdiscovery_aspo_binarize              onset2COWCS  0.004411
# 5   xgb  newdiscovery_aspo_binarize              onset2COWCS -0.000268
# 6    rf  newdiscovery_aspo_binarize              periregular  0.004616
# 7   xgb  newdiscovery_aspo_binarize              periregular -0.004903
#
#     tau_std  test_stat   p_value
# 0  0.007781  -0.477271  0.316608
# 1  0.028938   0.516384  0.302820
# 2  0.024074  -1.872156  0.030773
# 3  0.034742  -1.342180  0.089977
# 4  0.003614   1.220526  0.111194
# 5  0.005860  -0.045701  0.481776
# 6  0.003814   1.210285  0.113187
# 7  0.007945  -0.617159  0.268620

# %%
att_nondemo_disco_results[att_nondemo_disco_results['outcome'].isin(['onset2COWCS', 'coup', 'periregular', 'milexp_pergdpSIPRI_diff'])].sort_values(by=['outcome', 'treatment', 'model']).reset_index(drop=True).drop('democracy', axis=1)
# Out:
#   model                   treatment                  outcome   tau_hat  \
# 0    rf  newdiscovery_aspo_binarize                     coup -0.055799
# 1   xgb  newdiscovery_aspo_binarize                     coup -0.023319
# 2    rf  newdiscovery_aspo_binarize  milexp_pergdpSIPRI_diff  0.140043
# 3   xgb  newdiscovery_aspo_binarize  milexp_pergdpSIPRI_diff  0.392970
# 4    rf  newdiscovery_aspo_binarize              onset2COWCS  0.010613
# 5   xgb  newdiscovery_aspo_binarize              onset2COWCS  0.016753
# 6    rf  newdiscovery_aspo_binarize              periregular -0.018897
# 7   xgb  newdiscovery_aspo_binarize              periregular -0.048081
#
#     tau_std  test_stat   p_value
# 0  0.018396  -3.033267  0.001222
# 1  0.042991  -0.542411  0.293794
# 2  0.432571   0.323746  0.373136
# 3  0.578785   0.678957  0.248782
# 4  0.005952   1.783207  0.037336
# 5  0.006349   2.638581  0.004190
# 6  0.008092  -2.335098  0.009821
# 7  0.021671  -2.218683  0.013318

# %%
no_russia_usa_df = oil_df[~oil_df['code3'].isin(['USA', 'RUS'])]

# %%
treatment_lst = ['valoilres_binarize', # value of oil reserves
               'oilpop_binarize'] # oil reserves per capita in million barrels per 1000 person

outcome_lst = ['onset2COWCS',
               'onsetUCS',
               'coup',
               'periregular',
               'milexp_pergdpSIPRI_diff']

# %%
df_dict = {'model': [], 'treatment': [], 'outcome': [], 'tau_hat': [], 'tau_std': [], 'test_stat': [], 'p_value': []}
for treat in treatment_lst:
    for out in outcome_lst:
        for model_type in ['rf', 'xgb']:
            if len(oil_df[out].value_counts()) == 2:
                output = 'binary'
            else:
                output = 'continuous'
            if model_type == 'rf':
                tau_hat, tau_std, test_stat, p_value = fit_and_run_model(no_russia_usa_df, out, treat, confounders, make_g_model, make_Q_model, output_type=output, ate=False)
            else:
                tau_hat, tau_std, test_stat, p_value = fit_and_run_model(no_russia_usa_df, out, treat, confounders, make_xgboost_g_model, make_xgboost_Q_model, output_type=output, ate=False)
            df_dict['model'].append(model_type)
            df_dict['treatment'].append(treat)
            df_dict['outcome'].append(out)
            df_dict['tau_hat'].append(tau_hat)
            df_dict['tau_std'].append(tau_std)
            df_dict['test_stat'].append(test_stat)
            df_dict['p_value'].append(p_value)

att_results_no_rus_usa_df = pd.DataFrame(data=df_dict)
# Out:
# Running models for treatment valoilres_binarize and outcome onset2COWCS on 5094 samples
# G Model has been fit
# Q model has been fit
# AIPTW model has been fit. Returning τ hat and its standard deviation
# τ hat = -0.00173, std = 0.00509, test statistic = -0.34002, p-value = 0.36693
#
# Running models for treatment valoilres_binarize and outcome onset2COWCS on 5094 samples
#
# WARNING:
#  Some propensity scores are very small,
#  which could lead to an inflated AIPTW.
#  Minimum score =  0.0001487927947891876
#
# WARNING:
#  Some propensity scores are very large,
#  which could lead to an inflated AIPTW.
#  Maximum score =  0.9989847540855408
# G Model has been fit
# Q model has been fit
# Dropped 1593 observations due to overlap condition
# AIPTW model has been fit. Returning τ hat and its standard deviation
# τ hat = -0.08755, std = 0.09629, test statistic = -0.90923, p-value = 0.18164
#
# Running models for treatment valoilres_binarize and outcome onsetUCS on 4446 samples
# G Model has been fit
# Q model has been fit
# AIPTW model has been fit. Returning τ hat and its standard deviation
# τ hat = 0.00072, std = 0.00862, test statistic = 0.08406, p-value = 0.4665
#
# Running models for treatment valoilres_binarize and outcome onsetUCS on 4446 samples
#
# WARNING:
#  Some propensity scores are very small,
#  which could lead to an inflated AIPTW.
#  Minimum score =  0.00012651535507757217
#
# WARNING:
#  Some propensity scores are very large,
#  which could lead to an inflated AIPTW.
#  Maximum score =  0.9994244575500488
# G Model has been fit
# Q model has been fit
# Dropped 1614 observations due to overlap condition
# AIPTW model has been fit. Returning τ hat and its standard deviation
# τ hat = 0.07772, std = 0.08069, test statistic = 0.9632, p-value = 0.16775
#
# Running models for treatment valoilres_binarize and outcome coup on 5018 samples
# G Model has been fit
# Q model has been fit
# AIPTW model has been fit. Returning τ hat and its standard deviation
# τ hat = -0.02646, std = 0.01318, test statistic = -2.00708, p-value = 0.0224
#
# Running models for treatment valoilres_binarize and outcome coup on 5018 samples
#
# WARNING:
#  Some propensity scores are very small,
#  which could lead to an inflated AIPTW.
#  Minimum score =  0.00017111393390223384
#
# WARNING:
#  Some propensity scores are very large,
#  which could lead to an inflated AIPTW.
#  Maximum score =  0.9982497096061707
# G Model has been fit
# Q model has been fit
# Dropped 1716 observations due to overlap condition
# AIPTW model has been fit. Returning τ hat and its standard deviation
# τ hat = 0.02167, std = 0.03065, test statistic = 0.7068, p-value = 0.23986
#
# Running models for treatment valoilres_binarize and outcome periregular on 3258 samples
# G Model has been fit
# Q model has been fit
# AIPTW model has been fit. Returning τ hat and its standard deviation
# τ hat = -0.01119, std = 0.00584, test statistic = -1.91612, p-value = 0.02772
#
# Running models for treatment valoilres_binarize and outcome periregular on 3258 samples
#
# WARNING:
#  Some propensity scores are very small,
#  which could lead to an inflated AIPTW.
#  Minimum score =  0.0006323104025796056
#
# WARNING:
#  Some propensity scores are very large,
#  which could lead to an inflated AIPTW.
#  Maximum score =  0.9955282807350159
# G Model has been fit
# Q model has been fit
# Dropped 927 observations due to overlap condition
# AIPTW model has been fit. Returning τ hat and its standard deviation
# τ hat = -0.02168, std = 0.00983, test statistic = -2.20484, p-value = 0.01377
#
# Running models for treatment valoilres_binarize and outcome milexp_pergdpSIPRI_diff on 1276 samples
#
# WARNING:
#  Some propensity scores are very small,
#  which could lead to an inflated AIPTW.
#  Minimum score =  0.007724722881557511
# G Model has been fit
# Q model has been fit
# AIPTW model has been fit. Returning τ hat and its standard deviation
# τ hat = 0.56284, std = 0.4255, test statistic = 1.32278, p-value = 0.09307
#
# Running models for treatment valoilres_binarize and outcome milexp_pergdpSIPRI_diff on 1276 samples
#
# WARNING:
#  Some propensity scores are very small,
#  which could lead to an inflated AIPTW.
#  Minimum score =  8.046356379054487e-05
#
# WARNING:
#  Some propensity scores are very large,
#  which could lead to an inflated AIPTW.
#  Maximum score =  0.9995219707489014
# G Model has been fit
# Q model has been fit
# Dropped 783 observations due to overlap condition
# AIPTW model has been fit. Returning τ hat and its standard deviation
# τ hat = 0.5803, std = 0.48289, test statistic = 1.20172, p-value = 0.11485
#
# Running models for treatment oilpop_binarize and outcome onset2COWCS on 5094 samples
#
# WARNING:
#  Some propensity scores are very small,
#  which could lead to an inflated AIPTW.
#  Minimum score =  0.0038600974150046884
# G Model has been fit
# Q model has been fit
# AIPTW model has been fit. Returning τ hat and its standard deviation
# τ hat = -0.00356, std = 0.00697, test statistic = -0.51108, p-value = 0.30466
#
# Running models for treatment oilpop_binarize and outcome onset2COWCS on 5094 samples
#
# WARNING:
#  Some propensity scores are very small,
#  which could lead to an inflated AIPTW.
#  Minimum score =  0.0002565483737271279
# G Model has been fit
# Q model has been fit
# AIPTW model has been fit. Returning τ hat and its standard deviation
# τ hat = -0.00338, std = 0.00774, test statistic = -0.43664, p-value = 0.3312
#
# Running models for treatment oilpop_binarize and outcome onsetUCS on 4446 samples
#
# WARNING:
#  Some propensity scores are very small,
#  which could lead to an inflated AIPTW.
#  Minimum score =  0.0037965305184280455
# G Model has been fit
# Q model has been fit
# AIPTW model has been fit. Returning τ hat and its standard deviation
# τ hat = 0.0034, std = 0.0126, test statistic = 0.26979, p-value = 0.39367
#
# Running models for treatment oilpop_binarize and outcome onsetUCS on 4446 samples
#
# WARNING:
#  Some propensity scores are very small,
#  which could lead to an inflated AIPTW.
#  Minimum score =  0.00018990780517924577
# G Model has been fit
# Q model has been fit
# AIPTW model has been fit. Returning τ hat and its standard deviation
# τ hat = 0.01078, std = 0.01387, test statistic = 0.77778, p-value = 0.21837
#
# Running models for treatment oilpop_binarize and outcome coup on 5018 samples
#
# WARNING:
#  Some propensity scores are very small,
#  which could lead to an inflated AIPTW.
#  Minimum score =  0.004830873581168982
# G Model has been fit
# Q model has been fit
# AIPTW model has been fit. Returning τ hat and its standard deviation
# τ hat = -0.02357, std = 0.0215, test statistic = -1.09643, p-value = 0.13647
#
# Running models for treatment oilpop_binarize and outcome coup on 5018 samples
#
# WARNING:
#  Some propensity scores are very small,
#  which could lead to an inflated AIPTW.
#  Minimum score =  0.0002727764949668199
# G Model has been fit
# Q model has been fit
# AIPTW model has been fit. Returning τ hat and its standard deviation
# τ hat = -0.03376, std = 0.02839, test statistic = -1.18933, p-value = 0.11718
#
# Running models for treatment oilpop_binarize and outcome periregular on 3258 samples
#
# WARNING:
#  Some propensity scores are very small,
#  which could lead to an inflated AIPTW.
#  Minimum score =  0.008770479081882191
# G Model has been fit
# Q model has been fit
# AIPTW model has been fit. Returning τ hat and its standard deviation
# τ hat = -0.00127, std = 0.00603, test statistic = -0.21101, p-value = 0.41645
#
# Running models for treatment oilpop_binarize and outcome periregular on 3258 samples
#
# WARNING:
#  Some propensity scores are very small,
#  which could lead to an inflated AIPTW.
#  Minimum score =  0.0003490638337098062
# G Model has been fit
# Q model has been fit
# AIPTW model has been fit. Returning τ hat and its standard deviation
# τ hat = -0.00109, std = 0.00886, test statistic = -0.12296, p-value = 0.45107
#
# Running models for treatment oilpop_binarize and outcome milexp_pergdpSIPRI_diff on 1276 samples
#
# WARNING:
#  Some propensity scores are very small,
#  which could lead to an inflated AIPTW.
#  Minimum score =  0.00037208641091501034
# G Model has been fit
# Q model has been fit
# AIPTW model has been fit. Returning τ hat and its standard deviation
# τ hat = 3.22235, std = 2.94886, test statistic = 1.09274, p-value = 0.13736
#
# Running models for treatment oilpop_binarize and outcome milexp_pergdpSIPRI_diff on 1276 samples
#
# WARNING:
#  Some propensity scores are very small,
#  which could lead to an inflated AIPTW.
#  Minimum score =  2.1755164198111743e-05
# G Model has been fit
# Q model has been fit
# AIPTW model has been fit. Returning τ hat and its standard deviation
# τ hat = 3.05624, std = 2.82551, test statistic = 1.08166, p-value = 0.1398

# %%
att_results_no_rus_usa_df
# Out:
#    model           treatment                  outcome   tau_hat   tau_std  \
# 0     rf  valoilres_binarize              onset2COWCS -0.001729  0.005085
# 1    xgb  valoilres_binarize              onset2COWCS -0.087547  0.096287
# 2     rf  valoilres_binarize                 onsetUCS  0.000725  0.008619
# 3    xgb  valoilres_binarize                 onsetUCS  0.077716  0.080686
# 4     rf  valoilres_binarize                     coup -0.026460  0.013183
# 5    xgb  valoilres_binarize                     coup  0.021666  0.030654
# 6     rf  valoilres_binarize              periregular -0.011194  0.005842
# 7    xgb  valoilres_binarize              periregular -0.021680  0.009833
# 8     rf  valoilres_binarize  milexp_pergdpSIPRI_diff  0.562839  0.425496
# 9    xgb  valoilres_binarize  milexp_pergdpSIPRI_diff  0.580299  0.482890
# 10    rf     oilpop_binarize              onset2COWCS -0.003560  0.006966
# 11   xgb     oilpop_binarize              onset2COWCS -0.003381  0.007743
# 12    rf     oilpop_binarize                 onsetUCS  0.003400  0.012603
# 13   xgb     oilpop_binarize                 onsetUCS  0.010784  0.013865
# 14    rf     oilpop_binarize                     coup -0.023568  0.021495
# 15   xgb     oilpop_binarize                     coup -0.033761  0.028386
# 16    rf     oilpop_binarize              periregular -0.001272  0.006030
# 17   xgb     oilpop_binarize              periregular -0.001089  0.008855
# 18    rf     oilpop_binarize  milexp_pergdpSIPRI_diff  3.222347  2.948860
# 19   xgb     oilpop_binarize  milexp_pergdpSIPRI_diff  3.056239  2.825510
#
#     test_stat   p_value
# 0   -0.340017  0.366929
# 1   -0.909228  0.181636
# 2    0.084064  0.466504
# 3    0.963198  0.167750
# 4   -2.007083  0.022397
# 5    0.706804  0.239861
# 6   -1.916121  0.027719
# 7   -2.204835  0.013768
# 8    1.322784  0.093072
# 9    1.201721  0.114847
# 10  -0.511077  0.304660
# 11  -0.436638  0.331196
# 12   0.269791  0.393667
# 13   0.777778  0.218371
# 14  -1.096431  0.136471
# 15  -1.189328  0.117183
# 16  -0.211006  0.416448
# 17  -0.122956  0.451075
# 18   1.092744  0.137356
# 19   1.081659  0.139804

# %%
# reset treatments and outcomes
treatment_lst = ['newdiscovery_aspo_binarize']
outcome_lst = ['d2incidenceU',
               'd3_6incidenceU',
               'onset2COWCS',
               'onsetUCS',
               'coup',
               'periregular',
               'milexp_pergdpSIPRI_diff']

# %%
df_dict = {'model': [], 'treatment': [], 'outcome': [], 'tau_hat': [], 'tau_std': [], 'test_stat': [], 'p_value': []}
for treat in treatment_lst:
    for out in outcome_lst:
        for model_type in ['rf', 'xgb']:
            if len(oil_df[out].value_counts()) == 2:
                output = 'binary'
            else:
                output = 'continuous'
            if model_type == 'rf':
                tau_hat, tau_std, test_stat, p_value = fit_and_run_model(no_russia_usa_df, out, treat, confounders, make_g_model, make_Q_model, output_type=output, ate=False)
            else:
                tau_hat, tau_std, test_stat, p_value = fit_and_run_model(no_russia_usa_df, out, treat, confounders, make_xgboost_g_model, make_xgboost_Q_model, output_type=output, ate=False)
            df_dict['model'].append(model_type)
            df_dict['treatment'].append(treat)
            df_dict['outcome'].append(out)
            df_dict['tau_hat'].append(tau_hat)
            df_dict['tau_std'].append(tau_std)
            df_dict['test_stat'].append(test_stat)
            df_dict['p_value'].append(p_value)

att_discovery_no_russia_usa_results_df = pd.DataFrame(data=df_dict)
# Out:
# Running models for treatment newdiscovery_aspo_binarize and outcome d2incidenceU on 2493 samples
# G Model has been fit
# Q model has been fit
# AIPTW model has been fit. Returning τ hat and its standard deviation
# τ hat = 0.00677, std = 0.01221, test statistic = 0.55432, p-value = 0.2897
#
# Running models for treatment newdiscovery_aspo_binarize and outcome d2incidenceU on 2493 samples
#
# WARNING:
#  Some propensity scores are very small,
#  which could lead to an inflated AIPTW.
#  Minimum score =  0.00807002279907465
#
# WARNING:
#  Some propensity scores are very large,
#  which could lead to an inflated AIPTW.
#  Maximum score =  0.996623158454895
# G Model has been fit
# Q model has been fit
# Dropped 18 observations due to overlap condition
# AIPTW model has been fit. Returning τ hat and its standard deviation
# τ hat = -0.01764, std = 0.0259, test statistic = -0.68108, p-value = 0.24794
#
# Running models for treatment newdiscovery_aspo_binarize and outcome d3_6incidenceU on 2443 samples
# G Model has been fit
# Q model has been fit
# AIPTW model has been fit. Returning τ hat and its standard deviation
# τ hat = 0.01319, std = 0.0153, test statistic = 0.86216, p-value = 0.19434
#
# Running models for treatment newdiscovery_aspo_binarize and outcome d3_6incidenceU on 2443 samples
#
# WARNING:
#  Some propensity scores are very small,
#  which could lead to an inflated AIPTW.
#  Minimum score =  0.008146575652062893
#
# WARNING:
#  Some propensity scores are very large,
#  which could lead to an inflated AIPTW.
#  Maximum score =  0.9957905411720276
# G Model has been fit
# Q model has been fit
# Dropped 26 observations due to overlap condition
# AIPTW model has been fit. Returning τ hat and its standard deviation
# τ hat = -0.01291, std = 0.04681, test statistic = -0.27571, p-value = 0.3914
#
# Running models for treatment newdiscovery_aspo_binarize and outcome onset2COWCS on 4900 samples
# G Model has been fit
# Q model has been fit
# AIPTW model has been fit. Returning τ hat and its standard deviation
# τ hat = 0.00594, std = 0.00353, test statistic = 1.68293, p-value = 0.04623
#
# Running models for treatment newdiscovery_aspo_binarize and outcome onset2COWCS on 4900 samples
#
# WARNING:
#  Some propensity scores are very small,
#  which could lead to an inflated AIPTW.
#  Minimum score =  0.0007837960729375482
#
# WARNING:
#  Some propensity scores are very large,
#  which could lead to an inflated AIPTW.
#  Maximum score =  0.9961177110671997
# G Model has been fit
# Q model has been fit
# Dropped 325 observations due to overlap condition
# AIPTW model has been fit. Returning τ hat and its standard deviation
# τ hat = 0.01111, std = 0.00383, test statistic = 2.90001, p-value = 0.00187
#
# Running models for treatment newdiscovery_aspo_binarize and outcome onsetUCS on 4239 samples
# G Model has been fit
# Q model has been fit
# AIPTW model has been fit. Returning τ hat and its standard deviation
# τ hat = 0.01216, std = 0.00641, test statistic = 1.89663, p-value = 0.02897
#
# Running models for treatment newdiscovery_aspo_binarize and outcome onsetUCS on 4239 samples
#
# WARNING:
#  Some propensity scores are very small,
#  which could lead to an inflated AIPTW.
#  Minimum score =  0.0022055336739867926
#
# WARNING:
#  Some propensity scores are very large,
#  which could lead to an inflated AIPTW.
#  Maximum score =  0.9936683773994446
# G Model has been fit
# Q model has been fit
# Dropped 344 observations due to overlap condition
# AIPTW model has been fit. Returning τ hat and its standard deviation
# τ hat = 0.00527, std = 0.0159, test statistic = 0.33129, p-value = 0.37022
#
# Running models for treatment newdiscovery_aspo_binarize and outcome coup on 4780 samples
# G Model has been fit
# Q model has been fit
# AIPTW model has been fit. Returning τ hat and its standard deviation
# τ hat = -0.036, std = 0.01035, test statistic = -3.4781, p-value = 0.00025
#
# Running models for treatment newdiscovery_aspo_binarize and outcome coup on 4780 samples
#
# WARNING:
#  Some propensity scores are very small,
#  which could lead to an inflated AIPTW.
#  Minimum score =  0.002002099994570017
#
# WARNING:
#  Some propensity scores are very large,
#  which could lead to an inflated AIPTW.
#  Maximum score =  0.9949048757553101
# G Model has been fit
# Q model has been fit
# Dropped 263 observations due to overlap condition
# AIPTW model has been fit. Returning τ hat and its standard deviation
# τ hat = -0.01699, std = 0.02235, test statistic = -0.76041, p-value = 0.22352
#
# Running models for treatment newdiscovery_aspo_binarize and outcome periregular on 3258 samples
# G Model has been fit
# Q model has been fit
# AIPTW model has been fit. Returning τ hat and its standard deviation
# τ hat = -0.01574, std = 0.00496, test statistic = -3.17254, p-value = 0.00076
#
# Running models for treatment newdiscovery_aspo_binarize and outcome periregular on 3258 samples
#
# WARNING:
#  Some propensity scores are very small,
#  which could lead to an inflated AIPTW.
#  Minimum score =  0.0007930818828754127
#
# WARNING:
#  Some propensity scores are very large,
#  which could lead to an inflated AIPTW.
#  Maximum score =  0.9972376823425293
# G Model has been fit
# Q model has been fit
# Dropped 244 observations due to overlap condition
# AIPTW model has been fit. Returning τ hat and its standard deviation
# τ hat = -0.01397, std = 0.01127, test statistic = -1.24017, p-value = 0.1075
#
# Running models for treatment newdiscovery_aspo_binarize and outcome milexp_pergdpSIPRI_diff on 1276 samples
# G Model has been fit
# Q model has been fit
# AIPTW model has been fit. Returning τ hat and its standard deviation
# τ hat = 0.00537, std = 0.1898, test statistic = 0.02828, p-value = 0.48872
#
# Running models for treatment newdiscovery_aspo_binarize and outcome milexp_pergdpSIPRI_diff on 1276 samples
#
# WARNING:
#  Some propensity scores are very small,
#  which could lead to an inflated AIPTW.
#  Minimum score =  0.001198984682559967
#
# WARNING:
#  Some propensity scores are very large,
#  which could lead to an inflated AIPTW.
#  Maximum score =  0.9984782338142395
# G Model has been fit
# Q model has been fit
# Dropped 182 observations due to overlap condition
# AIPTW model has been fit. Returning τ hat and its standard deviation
# τ hat = 0.14756, std = 0.12883, test statistic = 1.14539, p-value = 0.12613

# %%
att_discovery_no_russia_usa_results_df[0:4]
# Out:
#   model                   treatment         outcome   tau_hat   tau_std  \
# 0    rf  newdiscovery_aspo_binarize    d2incidenceU  0.006766  0.012205
# 1   xgb  newdiscovery_aspo_binarize    d2incidenceU -0.017643  0.025904
# 2    rf  newdiscovery_aspo_binarize  d3_6incidenceU  0.013188  0.015297
# 3   xgb  newdiscovery_aspo_binarize  d3_6incidenceU -0.012906  0.046810
#
#    test_stat   p_value
# 0   0.554320  0.289705
# 1  -0.681078  0.247943
# 2   0.862160  0.194342
# 3  -0.275709  0.391397
