# %%
import numpy as np
import pandas as pd
import scipy as sp
from sklearn.ensemble import RandomForestClassifier, RandomForestRegressor
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import KFold, StratifiedKFold, train_test_split
from sklearn.metrics import mean_squared_error, log_loss
import sklearn
import os
from matplotlib.pyplot import hist
from scipy import stats
# import more functions or modules if you need them !!

# %%
# set random seed for numpy
RANDOM_SEED=42
np.random.seed(RANDOM_SEED)

# %%
oil_df = pd.read_pickle('../Data/data/comprehensive_new_full.pkl')
oil_df = oil_df[oil_df.democracy<=0.005]

# %%
# ATT and ATE AIPTW
def att_aiptw(Q0, Q1, g, A, Y, prob_t=None):
    """
    Double ML estimator for the ATT
    This uses the ATT specific scores, see equation 3.9 of https://www.econstor.eu/bitstream/10419/149795/1/869216953.pdf
    Return: aiptw of ATE and its standard error
    """
    
    # number of observations
    n = Y.shape[0]
    
    # estimate marginal probability of treatment
    if prob_t is None:
        prob_t = A.mean() 
    
    # att aiptw
    tau_hat = (A*(Y-Q0) - (1-A)*(g/(1-g))*(Y-Q0)).mean()/ prob_t
  
    # influence curve and standard error of aiptw
    phi = (A*(Y-Q0) - (1-A)*(g/(1-g))*(Y-Q0) - tau_hat*A) / prob_t
    std_hat = np.std(phi) / np.sqrt(n)

    return tau_hat, std_hat

def ate_aiptw(Q0, Q1, g, A, Y, prob_t=None):
    """
    Double ML estimator for the ATE
    Return: aiptw of ATE and its standard error
    """
    # number of observations
    n = Y.shape[0]
    
    # ate aiptw
    tau_hat = (Q1 - Q0 + A*(Y-Q1)/g - (1-A)*(Y-Q0)/(1-g)).mean()
  
    # influence curve and standard error of aiptw
    phi = Q1 - Q0 + A*(Y-Q1)/g - (1-A)*(Y-Q0)/(1-g) - tau_hat   
    std_hat = np.std(phi) / np.sqrt(n)

    return tau_hat, std_hat

# %%
# Conditional outcome models (Q models)
def make_linear_Q_model():
    ''' A function that returns a linear q model for later use in k-folding'''
    return LinearRegression()

def make_Q_model(output_type:str):
    ''' A function that returns a general ML q model for later use in k-folding'''
    if output_type == 'binary':
        return RandomForestClassifier(random_state=RANDOM_SEED, n_estimators=500, max_depth=None)
    return RandomForestRegressor(random_state=RANDOM_SEED, n_estimators=500, max_depth=None)
# One example: RandomForestRegressor(random_state=RANDOM_SEED, n_estimators=500, max_depth=None)

# %%
# Propensity score models (g models)
def make_g_model():
    ''' A function that returns a g model for computing propensity scores'''
    return RandomForestClassifier(n_estimators=100, max_depth=5)
# One example: RandomForestClassifier(n_estimators=100, max_depth=5)

# %%
# Functions for K-fold cross-fitting
def treatment_k_fold_fit_and_predict(make_model, X:pd.DataFrame, A:np.array, n_splits:int):
    '''
    Implements K fold cross-fitting for the model predicting the treatment A. 
    That is, 
    1. Split data into K folds
    2. For each fold j, the model is fit on the other K-1 folds
    3. The fitted model is used to make predictions for each data point in fold j
    Returns an array containing the predictions  

    Args:
    model: function that returns sklearn model (which implements fit and predict_prob)
    X: dataframe of variables to adjust for
    A: array of treatments
    n_splits: number of splits to use
    '''

    predictions = np.full_like(A, np.nan, dtype=float)
    kf = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=RANDOM_SEED)
    
    for train_index, test_index in kf.split(X, A):
        X_train = X.loc[train_index]
        A_train = A.loc[train_index]
        g = make_model()
        g.fit(X_train, A_train)

        # get predictions for split
        predictions[test_index] = g.predict_proba(X.loc[test_index])[:, 1]
    
    # sanity check that overlap holds
    assert np.isnan(predictions).sum() == 0
    return predictions

def outcome_k_fold_fit_and_predict(make_model, X:pd.DataFrame, y:np.array, A:np.array, n_splits:int, output_type:str):
    '''
    Implements K fold cross-fitting for the model predicting the outcome Y. 
    That is, 
    1. Split data into K folds
    2. For each fold j, the model is fit on the other K-1 folds
    3. The fitted model is used to make predictions for each data point in fold j
    Returns two arrays containing the predictions for all units untreated, all units treated  

    Args:
    model: function that returns sklearn model (that implements fit and either predict_prob or predict)
    X: dataframe of variables to adjust for
    y: array of outcomes
    A: array of treatments
    n_splits: number of splits to use
    output_type: type of outcome, "binary" or "continuous"
    '''

    predictions0 = np.full_like(A, np.nan, dtype=float)
    predictions1 = np.full_like(y, np.nan, dtype=float)
    if output_type == 'binary':
        kf = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=RANDOM_SEED)
    elif output_type == 'continuous':
        kf = KFold(n_splits=n_splits, shuffle=True, random_state=RANDOM_SEED)

    # include the treatment as input feature
    X_w_treatment = X.copy()
    X_w_treatment["A"] = A

    # for predicting effect under treatment / control status for each data point 
    X0 = X_w_treatment.copy()
    X0["A"] = 0
    X1 = X_w_treatment.copy()
    X1["A"] = 1

    
    for train_index, test_index in kf.split(X_w_treatment, y):
        X_train = X_w_treatment.loc[train_index]
        y_train = y.loc[train_index]
        q = make_model(output_type)
        q.fit(X_train, y_train)

        if output_type =='binary':
            predictions0[test_index] = q.predict_proba(X0.loc[test_index])[:, 1]
            predictions1[test_index] = q.predict_proba(X1.loc[test_index])[:, 1]
        elif output_type == 'continuous':
            predictions0[test_index] = q.predict(X0.loc[test_index])
            predictions1[test_index] = q.predict(X1.loc[test_index])

    assert np.isnan(predictions0).sum() == 0
    assert np.isnan(predictions1).sum() == 0
    return predictions0, predictions1

# %%
model_vars = ['ecgrowth',
              'pop_maddison_diff',
              'popdens_diff',
              'democracy_diff',
              'logmountain',
              'ethnic_fractionalization',
              'religion_fractionalization',
              'language_fractionalization',
              'leg_british',
              'decade']

# %%
outcome = 'onset2COWCS'
treatment = 'valoilres_binarize'
confounders = ['crude1990P_diff',
               'wildcat_diff',
               'out_regdisaster_diff',
               'ecgrowth',
               'pop_maddison_diff',
               'popdens_diff',
               'democracy_diff',
               'logmountain',
               'ethnic_fractionalization',
               'religion_fractionalization',
               'language_fractionalization',
               'leg_british',
               'decade',
               'opec']

# %%
def fit_and_run_model(df, outcome:str, treatment:str, confounders:list, make_g_model,
                      make_Q_model, n_splits=5, output_type='binary', ate=True):
    '''
    Function that creates a g, q, and aiptw model based on the 
    given inputs
    
    Inputs: df (pandas df) - the dataframe the variables are contained in
            outcome (str) - the outcome variable
            treatment (str) - the treatment variable
            confounders (lst) - a list of the confounding variables
            make_g_model - the make_g_model function
            make_Q_model - the make_Q_model function
            n_splits (int) - number of splits for the model
            output_type (str) - the desired output type, either binary or continous
            ate (bool) - whether to use ate or alternative att
    
    Returns: tau_hat - the tau hat estimator for the average treatment effect
             std of tau_hat - the standard deviation for the tau_hat estimator
    '''
    df = df.replace({outcome: .00001}, 0)
    df = df[[outcome] + confounders + [treatment]]
    df = df.dropna().reset_index()
    print('Running models for treatment {} and outcome {} on {} samples'.format(treatment, outcome, len(df)))
    n = len(df)
    outcome = df[outcome]
    confounders = df[confounders]
    treatment = df[treatment]
    treatment = treatment.replace({0.0: 0, 1.0: 1})
    outcome = outcome.replace({0.0: 0, 1.0: 1})
    g = treatment_k_fold_fit_and_predict(make_g_model, X=confounders, A=treatment, n_splits=n_splits)
    drop=False
    if min(g) < .01:
        print('\nWARNING:\n Some propensity scores are very small,\n which could '
              'lead to an inflated AIPTW.\n Minimum score = ', min(g))
    if max(g) > .99:
        print('\nWARNING:\n Some propensity scores are very large,\n which could '
              'lead to an inflated AIPTW.\n Maximum score = ', max(g))
        drop = True
    print('G Model has been fit')

    Q0_ml, Q1_ml = outcome_k_fold_fit_and_predict(make_Q_model, X=confounders, y=outcome, A=treatment, \
                                                  n_splits=n_splits, output_type=output_type)
    
    print('Q model has been fit')
    data_and_nuisance_estimates_ml = pd.DataFrame({'g': g, 'Q0': Q0_ml, 'Q1': Q1_ml, 'A': treatment, 'Y': outcome})
    
    if drop:
        data_and_nuisance_estimates_ml = data_and_nuisance_estimates_ml[data_and_nuisance_estimates_ml['g'] > .01]
        data_and_nuisance_estimates_ml = data_and_nuisance_estimates_ml[data_and_nuisance_estimates_ml['g'] < .99]
        print('Dropped {} observations due to overlap condition'.format(len(df) - len(data_and_nuisance_estimates_ml)))
    # ate aiptw
    if ate:
        tau_hat, std_hat = ate_aiptw(**data_and_nuisance_estimates_ml)
    else: 
        tau_hat, std_hat = att_aiptw(**data_and_nuisance_estimates_ml)
    test_stat = tau_hat / std_hat
    p_value = stats.t.sf(abs(test_stat), df=(n-1))
    print('AIPTW model has been fit. Returning \u03C4 hat and its standard deviation')
    print('\u03C4 hat = {}, std = {}, test statistic = {}, p-value = {}\n'.format(round(tau_hat, 5), round(std_hat, 5), round(test_stat, 5), round(p_value, 5)))
    return tau_hat, std_hat, test_stat, p_value

# %%
treatment_lst = ['valoilres_binarize', # value of oil reserves
               'valoilres_public_binarize', # value of oil reserves from public data
               'oilpop_binarize', # oil reserves per capita in million barrels per 1000 persons
               'valoilres_impute_binarize', # value of oilpop_impute (multiply by crude oil price)
               'oilpop_impute_binarize']

outcome_lst = ['onset2COWCS',
               'onsetUCS',
               'coup',
               'periregular',
               'milexp_pergdpSIPRI_diff']

# %%
oil_df = oil_df.T.drop_duplicates().T

# %%
from xgboost import XGBClassifier
from xgboost import XGBRegressor

# %%
def make_xgboost_g_model():
    return XGBClassifier(n_estimators=50, max_depth=3)

def make_xgboost_Q_model(output_type:str):
    if output_type == 'binary':
        return XGBClassifier(random_state=RANDOM_SEED, n_estimators=500, max_depth=None)
    return XGBRegressor(random_state=RANDOM_SEED, n_estimators=500, max_depth=None)

# %%
oil_df[confounders] = oil_df[confounders].astype(float)

# %%
df_dict = {'model': [], 'treatment': [], 'outcome': [], 'tau_hat': [], 'tau_std': [], 'test_stat': [], 'p_value': []}
for treat in treatment_lst:
    for out in outcome_lst:
        for model_type in ['rf', 'xgb']:
            if len(oil_df[out].value_counts()) == 2:
                output = 'binary'
            else:
                output = 'continuous'
            if model_type == 'rf':
                tau_hat, tau_std, test_stat, p_value = fit_and_run_model(oil_df, out, treat, confounders, make_g_model, make_Q_model, output_type=output, ate=False)
            else:
                tau_hat, tau_std, test_stat, p_value = fit_and_run_model(oil_df, out, treat, confounders, make_xgboost_g_model, make_xgboost_Q_model, output_type=output, ate=False)
            df_dict['model'].append(model_type)
            df_dict['treatment'].append(treat)
            df_dict['outcome'].append(out)
            df_dict['tau_hat'].append(tau_hat)
            df_dict['tau_std'].append(tau_std)
            df_dict['test_stat'].append(test_stat)
            df_dict['p_value'].append(p_value)

att_results_df = pd.DataFrame(data=df_dict)
# Out:
# Running models for treatment valoilres_binarize and outcome onset2COWCS on 2624 samples
# G Model has been fit
# Q model has been fit
# AIPTW model has been fit. Returning τ hat and its standard deviation
# τ hat = 0.00205, std = 0.00854, test statistic = 0.23985, p-value = 0.40523
#
# Running models for treatment valoilres_binarize and outcome onset2COWCS on 2624 samples
#
# WARNING:
#  Some propensity scores are very small,
#  which could lead to an inflated AIPTW.
#  Minimum score =  0.00022125114628579468
#
# WARNING:
#  Some propensity scores are very large,
#  which could lead to an inflated AIPTW.
#  Maximum score =  0.9980530738830566
# G Model has been fit
# Q model has been fit
# Dropped 773 observations due to overlap condition
# AIPTW model has been fit. Returning τ hat and its standard deviation
# τ hat = -0.03947, std = 0.05198, test statistic = -0.75934, p-value = 0.22386
#
# Running models for treatment valoilres_binarize and outcome onsetUCS on 2330 samples
# G Model has been fit
# Q model has been fit
# AIPTW model has been fit. Returning τ hat and its standard deviation
# τ hat = -0.00704, std = 0.01216, test statistic = -0.57846, p-value = 0.28151
#
# Running models for treatment valoilres_binarize and outcome onsetUCS on 2330 samples
#
# WARNING:
#  Some propensity scores are very small,
#  which could lead to an inflated AIPTW.
#  Minimum score =  0.00026828990667127073
#
# WARNING:
#  Some propensity scores are very large,
#  which could lead to an inflated AIPTW.
#  Maximum score =  0.9993000030517578
# G Model has been fit
# Q model has been fit
# Dropped 780 observations due to overlap condition
# AIPTW model has been fit. Returning τ hat and its standard deviation
# τ hat = -0.00426, std = 0.05388, test statistic = -0.07907, p-value = 0.46849
#
# Running models for treatment valoilres_binarize and outcome coup on 2653 samples
# G Model has been fit
# Q model has been fit
# AIPTW model has been fit. Returning τ hat and its standard deviation
# τ hat = -0.02297, std = 0.02324, test statistic = -0.98853, p-value = 0.16149
#
# Running models for treatment valoilres_binarize and outcome coup on 2653 samples
#
# WARNING:
#  Some propensity scores are very small,
#  which could lead to an inflated AIPTW.
#  Minimum score =  0.00013827953080181032
#
# WARNING:
#  Some propensity scores are very large,
#  which could lead to an inflated AIPTW.
#  Maximum score =  0.9987321496009827
# G Model has been fit
# Q model has been fit
# Dropped 903 observations due to overlap condition
# AIPTW model has been fit. Returning τ hat and its standard deviation
# τ hat = 0.04491, std = 0.05252, test statistic = 0.85502, p-value = 0.19631
#
# Running models for treatment valoilres_binarize and outcome periregular on 1884 samples
# G Model has been fit
# Q model has been fit
# AIPTW model has been fit. Returning τ hat and its standard deviation
# τ hat = -0.00968, std = 0.00998, test statistic = -0.97054, p-value = 0.16595
#
# Running models for treatment valoilres_binarize and outcome periregular on 1884 samples
#
# WARNING:
#  Some propensity scores are very small,
#  which could lead to an inflated AIPTW.
#  Minimum score =  0.0004603218985721469
#
# WARNING:
#  Some propensity scores are very large,
#  which could lead to an inflated AIPTW.
#  Maximum score =  0.9951505661010742
# G Model has been fit
# Q model has been fit
# Dropped 562 observations due to overlap condition
# AIPTW model has been fit. Returning τ hat and its standard deviation
# τ hat = 0.0159, std = 0.03479, test statistic = 0.45712, p-value = 0.32382
#
# Running models for treatment valoilres_binarize and outcome milexp_pergdpSIPRI_diff on 479 samples
#
# WARNING:
#  Some propensity scores are very small,
#  which could lead to an inflated AIPTW.
#  Minimum score =  0.005043461043120232
# G Model has been fit
# Q model has been fit
# AIPTW model has been fit. Returning τ hat and its standard deviation
# τ hat = 1.19834, std = 1.12199, test statistic = 1.06805, p-value = 0.14302
#
# Running models for treatment valoilres_binarize and outcome milexp_pergdpSIPRI_diff on 479 samples
#
# WARNING:
#  Some propensity scores are very small,
#  which could lead to an inflated AIPTW.
#  Minimum score =  0.0001477060141041875
#
# WARNING:
#  Some propensity scores are very large,
#  which could lead to an inflated AIPTW.
#  Maximum score =  0.9981048107147217
# G Model has been fit
# Q model has been fit
# Dropped 286 observations due to overlap condition
# AIPTW model has been fit. Returning τ hat and its standard deviation
# τ hat = 1.18103, std = 1.61606, test statistic = 0.73081, p-value = 0.23263
#
# Running models for treatment valoilres_public_binarize and outcome onset2COWCS on 2091 samples
# G Model has been fit
# Q model has been fit
# AIPTW model has been fit. Returning τ hat and its standard deviation
# τ hat = 0.00598, std = 0.00867, test statistic = 0.68966, p-value = 0.24524
#
# Running models for treatment valoilres_public_binarize and outcome onset2COWCS on 2091 samples
#
# WARNING:
#  Some propensity scores are very small,
#  which could lead to an inflated AIPTW.
#  Minimum score =  0.00035216688411310315
#
# WARNING:
#  Some propensity scores are very large,
#  which could lead to an inflated AIPTW.
#  Maximum score =  0.9931394457817078
# G Model has been fit
# Q model has been fit
# Dropped 493 observations due to overlap condition
# AIPTW model has been fit. Returning τ hat and its standard deviation
# τ hat = 0.01341, std = 0.0088, test statistic = 1.52319, p-value = 0.06393
#
# Running models for treatment valoilres_public_binarize and outcome onsetUCS on 2007 samples
# G Model has been fit
# Q model has been fit
# AIPTW model has been fit. Returning τ hat and its standard deviation
# τ hat = 0.01748, std = 0.01461, test statistic = 1.19677, p-value = 0.11577
#
# Running models for treatment valoilres_public_binarize and outcome onsetUCS on 2007 samples
#
# WARNING:
#  Some propensity scores are very small,
#  which could lead to an inflated AIPTW.
#  Minimum score =  0.00018502608872950077
#
# WARNING:
#  Some propensity scores are very large,
#  which could lead to an inflated AIPTW.
#  Maximum score =  0.9963217973709106
# G Model has been fit
# Q model has been fit
# Dropped 492 observations due to overlap condition
# AIPTW model has been fit. Returning τ hat and its standard deviation
# τ hat = 0.01318, std = 0.03477, test statistic = 0.37917, p-value = 0.3523
#
# Running models for treatment valoilres_public_binarize and outcome coup on 2290 samples
# G Model has been fit
# Q model has been fit
# AIPTW model has been fit. Returning τ hat and its standard deviation
# τ hat = 0.00437, std = 0.02535, test statistic = 0.17254, p-value = 0.43152
#
# Running models for treatment valoilres_public_binarize and outcome coup on 2290 samples
#
# WARNING:
#  Some propensity scores are very small,
#  which could lead to an inflated AIPTW.
#  Minimum score =  0.00034383061574772
# G Model has been fit
# Q model has been fit
# AIPTW model has been fit. Returning τ hat and its standard deviation
# τ hat = -0.00181, std = 0.06503, test statistic = -0.02788, p-value = 0.48888
#
# Running models for treatment valoilres_public_binarize and outcome periregular on 1354 samples
# G Model has been fit
# Q model has been fit
# AIPTW model has been fit. Returning τ hat and its standard deviation
# τ hat = 0.00812, std = 0.01345, test statistic = 0.60336, p-value = 0.27318
#
# Running models for treatment valoilres_public_binarize and outcome periregular on 1354 samples
#
# WARNING:
#  Some propensity scores are very small,
#  which could lead to an inflated AIPTW.
#  Minimum score =  0.0009373892098665237
#
# WARNING:
#  Some propensity scores are very large,
#  which could lead to an inflated AIPTW.
#  Maximum score =  0.9981400966644287
# G Model has been fit
# Q model has been fit
# Dropped 282 observations due to overlap condition
# AIPTW model has been fit. Returning τ hat and its standard deviation
# τ hat = 0.00917, std = 0.01807, test statistic = 0.50745, p-value = 0.30596
#
# Running models for treatment valoilres_public_binarize and outcome milexp_pergdpSIPRI_diff on 467 samples
#
# WARNING:
#  Some propensity scores are very small,
#  which could lead to an inflated AIPTW.
#  Minimum score =  0.006484918501669759
# G Model has been fit
# Q model has been fit
# AIPTW model has been fit. Returning τ hat and its standard deviation
# τ hat = 1.10364, std = 0.98249, test statistic = 1.12331, p-value = 0.13094
#
# Running models for treatment valoilres_public_binarize and outcome milexp_pergdpSIPRI_diff on 467 samples
#
# WARNING:
#  Some propensity scores are very small,
#  which could lead to an inflated AIPTW.
#  Minimum score =  5.121601861901581e-05
#
# WARNING:
#  Some propensity scores are very large,
#  which could lead to an inflated AIPTW.
#  Maximum score =  0.9980764389038086
# G Model has been fit
# Q model has been fit
# Dropped 252 observations due to overlap condition
# AIPTW model has been fit. Returning τ hat and its standard deviation
# τ hat = 0.9063, std = 1.25511, test statistic = 0.72209, p-value = 0.2353
#
# Running models for treatment oilpop_binarize and outcome onset2COWCS on 2624 samples
#
# WARNING:
#  Some propensity scores are very small,
#  which could lead to an inflated AIPTW.
#  Minimum score =  0.00539502799219342
# G Model has been fit
# Q model has been fit
# AIPTW model has been fit. Returning τ hat and its standard deviation
# τ hat = 0.00722, std = 0.01495, test statistic = 0.48277, p-value = 0.31465
#
# Running models for treatment oilpop_binarize and outcome onset2COWCS on 2624 samples
#
# WARNING:
#  Some propensity scores are very small,
#  which could lead to an inflated AIPTW.
#  Minimum score =  0.0002243256603833288
# G Model has been fit
# Q model has been fit
# AIPTW model has been fit. Returning τ hat and its standard deviation
# τ hat = 0.00881, std = 0.01789, test statistic = 0.49225, p-value = 0.31129
#
# Running models for treatment oilpop_binarize and outcome onsetUCS on 2330 samples
#
# WARNING:
#  Some propensity scores are very small,
#  which could lead to an inflated AIPTW.
#  Minimum score =  0.00506264047682009
# G Model has been fit
# Q model has been fit
# AIPTW model has been fit. Returning τ hat and its standard deviation
# τ hat = -0.01174, std = 0.01751, test statistic = -0.67067, p-value = 0.25125
#
# Running models for treatment oilpop_binarize and outcome onsetUCS on 2330 samples
#
# WARNING:
#  Some propensity scores are very small,
#  which could lead to an inflated AIPTW.
#  Minimum score =  0.00015294470358639956
# G Model has been fit
# Q model has been fit
# AIPTW model has been fit. Returning τ hat and its standard deviation
# τ hat = 0.00387, std = 0.02078, test statistic = 0.18639, p-value = 0.42608
#
# Running models for treatment oilpop_binarize and outcome coup on 2653 samples
#
# WARNING:
#  Some propensity scores are very small,
#  which could lead to an inflated AIPTW.
#  Minimum score =  0.004546346108272048
# G Model has been fit
# Q model has been fit
# AIPTW model has been fit. Returning τ hat and its standard deviation
# τ hat = -0.0389, std = 0.04246, test statistic = -0.9163, p-value = 0.1798
#
# Running models for treatment oilpop_binarize and outcome coup on 2653 samples
#
# WARNING:
#  Some propensity scores are very small,
#  which could lead to an inflated AIPTW.
#  Minimum score =  0.00016494649753440171
# G Model has been fit
# Q model has been fit
# AIPTW model has been fit. Returning τ hat and its standard deviation
# τ hat = -0.12311, std = 0.069, test statistic = -1.78415, p-value = 0.03726
#
# Running models for treatment oilpop_binarize and outcome periregular on 1884 samples
#
# WARNING:
#  Some propensity scores are very small,
#  which could lead to an inflated AIPTW.
#  Minimum score =  0.00426845678185631
# G Model has been fit
# Q model has been fit
# AIPTW model has been fit. Returning τ hat and its standard deviation
# τ hat = 0.00587, std = 0.01278, test statistic = 0.45972, p-value = 0.32288
#
# Running models for treatment oilpop_binarize and outcome periregular on 1884 samples
#
# WARNING:
#  Some propensity scores are very small,
#  which could lead to an inflated AIPTW.
#  Minimum score =  0.00019850760872941464
# G Model has been fit
# Q model has been fit
# AIPTW model has been fit. Returning τ hat and its standard deviation
# τ hat = -0.015, std = 0.01611, test statistic = -0.93112, p-value = 0.17596
#
# Running models for treatment oilpop_binarize and outcome milexp_pergdpSIPRI_diff on 479 samples
#
# WARNING:
#  Some propensity scores are very small,
#  which could lead to an inflated AIPTW.
#  Minimum score =  0.0
# G Model has been fit
# Q model has been fit
# AIPTW model has been fit. Returning τ hat and its standard deviation
# τ hat = 6.9167, std = 6.49269, test statistic = 1.06531, p-value = 0.14364
#
# Running models for treatment oilpop_binarize and outcome milexp_pergdpSIPRI_diff on 479 samples
#
# WARNING:
#  Some propensity scores are very small,
#  which could lead to an inflated AIPTW.
#  Minimum score =  0.00016334799875039607
# G Model has been fit
# Q model has been fit
# AIPTW model has been fit. Returning τ hat and its standard deviation
# τ hat = 5.79283, std = 6.99041, test statistic = 0.82868, p-value = 0.20385
#
# Running models for treatment valoilres_impute_binarize and outcome onset2COWCS on 2624 samples
# G Model has been fit
# Q model has been fit
# AIPTW model has been fit. Returning τ hat and its standard deviation
# τ hat = -1e-05, std = 0.00795, test statistic = -0.00187, p-value = 0.49925
#
# Running models for treatment valoilres_impute_binarize and outcome onset2COWCS on 2624 samples
#
# WARNING:
#  Some propensity scores are very small,
#  which could lead to an inflated AIPTW.
#  Minimum score =  0.00012710652663372457
#
# WARNING:
#  Some propensity scores are very large,
#  which could lead to an inflated AIPTW.
#  Maximum score =  0.9977735877037048
# G Model has been fit
# Q model has been fit
# Dropped 855 observations due to overlap condition
# AIPTW model has been fit. Returning τ hat and its standard deviation
# τ hat = -0.00383, std = 0.01633, test statistic = -0.23443, p-value = 0.40733
#
# Running models for treatment valoilres_impute_binarize and outcome onsetUCS on 2330 samples
# G Model has been fit
# Q model has been fit
# AIPTW model has been fit. Returning τ hat and its standard deviation
# τ hat = 0.00467, std = 0.01249, test statistic = 0.3739, p-value = 0.35426
#
# Running models for treatment valoilres_impute_binarize and outcome onsetUCS on 2330 samples
#
# WARNING:
#  Some propensity scores are very small,
#  which could lead to an inflated AIPTW.
#  Minimum score =  0.00022800177976023406
#
# WARNING:
#  Some propensity scores are very large,
#  which could lead to an inflated AIPTW.
#  Maximum score =  0.9984629154205322
# G Model has been fit
# Q model has been fit
# Dropped 845 observations due to overlap condition
# AIPTW model has been fit. Returning τ hat and its standard deviation
# τ hat = 0.03852, std = 0.08917, test statistic = 0.43204, p-value = 0.33288
#
# Running models for treatment valoilres_impute_binarize and outcome coup on 2653 samples
# G Model has been fit
# Q model has been fit
# AIPTW model has been fit. Returning τ hat and its standard deviation
# τ hat = -0.01722, std = 0.02175, test statistic = -0.79163, p-value = 0.21432
#
# Running models for treatment valoilres_impute_binarize and outcome coup on 2653 samples
#
# WARNING:
#  Some propensity scores are very small,
#  which could lead to an inflated AIPTW.
#  Minimum score =  3.47105014952831e-05
#
# WARNING:
#  Some propensity scores are very large,
#  which could lead to an inflated AIPTW.
#  Maximum score =  0.9990490078926086
# G Model has been fit
# Q model has been fit
# Dropped 936 observations due to overlap condition
# AIPTW model has been fit. Returning τ hat and its standard deviation
# τ hat = 0.03591, std = 0.05093, test statistic = 0.70495, p-value = 0.24045
#
# Running models for treatment valoilres_impute_binarize and outcome periregular on 1884 samples
# G Model has been fit
# Q model has been fit
# AIPTW model has been fit. Returning τ hat and its standard deviation
# τ hat = -0.00989, std = 0.00997, test statistic = -0.99157, p-value = 0.16077
#
# Running models for treatment valoilres_impute_binarize and outcome periregular on 1884 samples
#
# WARNING:
#  Some propensity scores are very small,
#  which could lead to an inflated AIPTW.
#  Minimum score =  0.0004603218985721469
#
# WARNING:
#  Some propensity scores are very large,
#  which could lead to an inflated AIPTW.
#  Maximum score =  0.9951505661010742
# G Model has been fit
# Q model has been fit
# Dropped 562 observations due to overlap condition
# AIPTW model has been fit. Returning τ hat and its standard deviation
# τ hat = 0.0159, std = 0.03479, test statistic = 0.45712, p-value = 0.32382
#
# Running models for treatment valoilres_impute_binarize and outcome milexp_pergdpSIPRI_diff on 479 samples
#
# WARNING:
#  Some propensity scores are very small,
#  which could lead to an inflated AIPTW.
#  Minimum score =  0.008410354291321566
# G Model has been fit
# Q model has been fit
# AIPTW model has been fit. Returning τ hat and its standard deviation
# τ hat = 1.16922, std = 1.11738, test statistic = 1.04639, p-value = 0.14795
#
# Running models for treatment valoilres_impute_binarize and outcome milexp_pergdpSIPRI_diff on 479 samples
#
# WARNING:
#  Some propensity scores are very small,
#  which could lead to an inflated AIPTW.
#  Minimum score =  0.0001477060141041875
#
# WARNING:
#  Some propensity scores are very large,
#  which could lead to an inflated AIPTW.
#  Maximum score =  0.9981048107147217
# G Model has been fit
# Q model has been fit
# Dropped 286 observations due to overlap condition
# AIPTW model has been fit. Returning τ hat and its standard deviation
# τ hat = 1.18103, std = 1.61606, test statistic = 0.73081, p-value = 0.23263
#
# Running models for treatment oilpop_impute_binarize and outcome onset2COWCS on 2624 samples
#
# WARNING:
#  Some propensity scores are very small,
#  which could lead to an inflated AIPTW.
#  Minimum score =  0.004356504033464665
# G Model has been fit
# Q model has been fit
# AIPTW model has been fit. Returning τ hat and its standard deviation
# τ hat = 0.00272, std = 0.01497, test statistic = 0.18198, p-value = 0.42781
#
# Running models for treatment oilpop_impute_binarize and outcome onset2COWCS on 2624 samples
#
# WARNING:
#  Some propensity scores are very small,
#  which could lead to an inflated AIPTW.
#  Minimum score =  0.0002429477754049003
# G Model has been fit
# Q model has been fit
# AIPTW model has been fit. Returning τ hat and its standard deviation
# τ hat = 2e-05, std = 0.01757, test statistic = 0.00139, p-value = 0.49945
#
# Running models for treatment oilpop_impute_binarize and outcome onsetUCS on 2330 samples
#
# WARNING:
#  Some propensity scores are very small,
#  which could lead to an inflated AIPTW.
#  Minimum score =  0.004323262250138059
# G Model has been fit
# Q model has been fit
# AIPTW model has been fit. Returning τ hat and its standard deviation
# τ hat = -0.01909, std = 0.01772, test statistic = -1.07728, p-value = 0.14073
#
# Running models for treatment oilpop_impute_binarize and outcome onsetUCS on 2330 samples
#
# WARNING:
#  Some propensity scores are very small,
#  which could lead to an inflated AIPTW.
#  Minimum score =  0.00018681497022043914
# G Model has been fit
# Q model has been fit
# AIPTW model has been fit. Returning τ hat and its standard deviation
# τ hat = 0.01572, std = 0.02818, test statistic = 0.55791, p-value = 0.28848
#
# Running models for treatment oilpop_impute_binarize and outcome coup on 2653 samples
#
# WARNING:
#  Some propensity scores are very small,
#  which could lead to an inflated AIPTW.
#  Minimum score =  0.005665646715983038
# G Model has been fit

# %%
att_results_df
# Out:
#    model                  treatment                  outcome   tau_hat  \
# 0     rf         valoilres_binarize              onset2COWCS -0.000093
# 1    xgb         valoilres_binarize              onset2COWCS -0.008819
# 2     rf         valoilres_binarize                 onsetUCS -0.001373
# 3    xgb         valoilres_binarize                 onsetUCS -0.038175
# 4     rf         valoilres_binarize                     coup -0.024780
# 5    xgb         valoilres_binarize                     coup  0.139695
# 6     rf         valoilres_binarize              periregular -0.013310
# 7    xgb         valoilres_binarize              periregular -0.005801
# 8     rf         valoilres_binarize  milexp_pergdpSIPRI_diff  0.532218
# 9    xgb         valoilres_binarize  milexp_pergdpSIPRI_diff  0.094764
# 10    rf  valoilres_public_binarize              onset2COWCS  0.003337
# 11   xgb  valoilres_public_binarize              onset2COWCS  0.010381
# 12    rf  valoilres_public_binarize                 onsetUCS  0.014194
# 13   xgb  valoilres_public_binarize                 onsetUCS  0.009038
# 14    rf  valoilres_public_binarize                     coup -0.007927
# 15   xgb  valoilres_public_binarize                     coup -0.058904
# 16    rf  valoilres_public_binarize              periregular -0.003546
# 17   xgb  valoilres_public_binarize              periregular  0.008626
# 18    rf  valoilres_public_binarize  milexp_pergdpSIPRI_diff  0.493834
# 19   xgb  valoilres_public_binarize  milexp_pergdpSIPRI_diff  0.554497
# 20    rf            oilpop_binarize              onset2COWCS -0.001811
# 21   xgb            oilpop_binarize              onset2COWCS -0.001714
# 22    rf            oilpop_binarize                 onsetUCS  0.002310
# 23   xgb            oilpop_binarize                 onsetUCS  0.009566
# 24    rf            oilpop_binarize                     coup -0.022034
# 25   xgb            oilpop_binarize                     coup -0.048128
# 26    rf            oilpop_binarize              periregular -0.003430
# 27   xgb            oilpop_binarize              periregular -0.003504
# 28    rf            oilpop_binarize  milexp_pergdpSIPRI_diff  3.326232
# 29   xgb            oilpop_binarize  milexp_pergdpSIPRI_diff  3.740208
# 30    rf  valoilres_impute_binarize              onset2COWCS  0.000938
# 31   xgb  valoilres_impute_binarize              onset2COWCS  0.005646
# 32    rf  valoilres_impute_binarize                 onsetUCS  0.008852
# 33   xgb  valoilres_impute_binarize                 onsetUCS  0.018814
# 34    rf  valoilres_impute_binarize                     coup -0.015064
# 35   xgb  valoilres_impute_binarize                     coup  0.023343
# 36    rf  valoilres_impute_binarize              periregular -0.012925
# 37   xgb  valoilres_impute_binarize              periregular -0.005801
# 38    rf  valoilres_impute_binarize  milexp_pergdpSIPRI_diff  0.535934
# 39   xgb  valoilres_impute_binarize  milexp_pergdpSIPRI_diff  0.094764
# 40    rf     oilpop_impute_binarize              onset2COWCS -0.002056
# 41   xgb     oilpop_impute_binarize              onset2COWCS -0.001724
# 42    rf     oilpop_impute_binarize                 onsetUCS -0.004849
# 43   xgb     oilpop_impute_binarize                 onsetUCS  0.003523
# 44    rf     oilpop_impute_binarize                     coup -0.025363
# 45   xgb     oilpop_impute_binarize                     coup -0.043192
# 46    rf     oilpop_impute_binarize              periregular -0.003442
# 47   xgb     oilpop_impute_binarize              periregular -0.003504
# 48    rf     oilpop_impute_binarize  milexp_pergdpSIPRI_diff  3.288689
# 49   xgb     oilpop_impute_binarize  milexp_pergdpSIPRI_diff  3.740208
#
#      tau_std  test_stat   p_value
# 0   0.004841  -0.019169  0.492354
# 1   0.016666  -0.529206  0.298343
# 2   0.008469  -0.162126  0.435607
# 3   0.080767  -0.472653  0.318242
# 4   0.012849  -1.928501  0.026924
# 5   0.107302   1.301880  0.096508
# 6   0.005828  -2.283614  0.011229
# 7   0.012502  -0.463972  0.321349
# 8   0.411386   1.293718  0.097996
# 9   0.126958   0.746423  0.227773
# 10  0.004735   0.704871  0.240465
# 11  0.005081   2.043252  0.020545
# 12  0.008519   1.666199  0.047876
# 13  0.022647   0.399076  0.344929
# 14  0.012932  -0.612991  0.269957
# 15  0.057089  -1.031805  0.151110
# 16  0.007494  -0.473144  0.318078
# 17  0.014520   0.594084  0.276257
# 18  0.368400   1.340482  0.090163
# 19  0.366180   1.514273  0.065102
# 20  0.006821  -0.265501  0.395317
# 21  0.007948  -0.215610  0.414650
# 22  0.012673   0.182269  0.427690
# 23  0.014491   0.660098  0.254612
# 24  0.021585  -1.020779  0.153704
# 25  0.027503  -1.749916  0.040097
# 26  0.006842  -0.501310  0.308093
# 27  0.010732  -0.326511  0.372029
# 28  2.931039   1.134830  0.128328
# 29  2.976707   1.256492  0.104582
# 30  0.004504   0.208254  0.417519
# 31  0.005395   1.046495  0.147691
# 32  0.008401   1.053728  0.146032
# 33  0.026931   0.698598  0.242420
# 34  0.011832  -1.273144  0.101513
# 35  0.039202   0.595467  0.275779
# 36  0.005818  -2.221473  0.013193
# 37  0.012502  -0.463972  0.321349
# 38  0.411760   1.301567  0.096647
# 39  0.126958   0.746423  0.227773
# 40  0.006645  -0.309429  0.378504
# 41  0.007934  -0.217287  0.413996
# 42  0.012466  -0.388985  0.348653
# 43  0.014490   0.243156  0.403948
# 44  0.021042  -1.205382  0.114056
# 45  0.027206  -1.587569  0.056223
# 46  0.006851  -0.502420  0.307703
# 47  0.010732  -0.326511  0.372029
# 48  2.931767   1.121743  0.131089
# 49  2.976707   1.256492  0.104582

# %%
att_results_df.loc[[0, 1, 4, 5, 6, 7, 12, 13, 26, 27, 30, 31], :].sort_values(by=['outcome', 'treatment', 'model']).reset_index(drop=True)
# Out:
#    model                  treatment      outcome   tau_hat   tau_std  \
# 0     rf         valoilres_binarize         coup -0.024780  0.012849
# 1    xgb         valoilres_binarize         coup  0.139695  0.107302
# 2     rf         valoilres_binarize  onset2COWCS -0.000093  0.004841
# 3    xgb         valoilres_binarize  onset2COWCS -0.008819  0.016666
# 4     rf  valoilres_impute_binarize  onset2COWCS  0.000938  0.004504
# 5    xgb  valoilres_impute_binarize  onset2COWCS  0.005646  0.005395
# 6     rf  valoilres_public_binarize     onsetUCS  0.014194  0.008519
# 7    xgb  valoilres_public_binarize     onsetUCS  0.009038  0.022647
# 8     rf            oilpop_binarize  periregular -0.003430  0.006842
# 9    xgb            oilpop_binarize  periregular -0.003504  0.010732
# 10    rf         valoilres_binarize  periregular -0.013310  0.005828
# 11   xgb         valoilres_binarize  periregular -0.005801  0.012502
#
#     test_stat   p_value
# 0   -1.928501  0.026924
# 1    1.301880  0.096508
# 2   -0.019169  0.492354
# 3   -0.529206  0.298343
# 4    0.208254  0.417519
# 5    1.046495  0.147691
# 6    1.666199  0.047876
# 7    0.399076  0.344929
# 8   -0.501310  0.308093
# 9   -0.326511  0.372029
# 10  -2.283614  0.011229
# 11  -0.463972  0.321349

# %%
att_temp = att_results_df[(att_results_df['treatment'] == 'valoilres_binarize') | (att_results_df['treatment'] == 'oilpop_binarize')].reset_index(drop=True)

# %%
att_temp[att_temp['outcome'].isin(['onset2COWCS', 'coup', 'periregular', 'milexp_pergdpSIPRI_diff'])].sort_values(by=['outcome', 'treatment', 'model']).reset_index(drop=True)
# Out:
#    model           treatment                  outcome   tau_hat   tau_std  \
# 0     rf     oilpop_binarize                     coup -0.022034  0.021585
# 1    xgb     oilpop_binarize                     coup -0.048128  0.027503
# 2     rf  valoilres_binarize                     coup -0.024780  0.012849
# 3    xgb  valoilres_binarize                     coup  0.139695  0.107302
# 4     rf     oilpop_binarize  milexp_pergdpSIPRI_diff  3.326232  2.931039
# 5    xgb     oilpop_binarize  milexp_pergdpSIPRI_diff  3.740208  2.976707
# 6     rf  valoilres_binarize  milexp_pergdpSIPRI_diff  0.532218  0.411386
# 7    xgb  valoilres_binarize  milexp_pergdpSIPRI_diff  0.094764  0.126958
# 8     rf     oilpop_binarize              onset2COWCS -0.001811  0.006821
# 9    xgb     oilpop_binarize              onset2COWCS -0.001714  0.007948
# 10    rf  valoilres_binarize              onset2COWCS -0.000093  0.004841
# 11   xgb  valoilres_binarize              onset2COWCS -0.008819  0.016666
# 12    rf     oilpop_binarize              periregular -0.003430  0.006842
# 13   xgb     oilpop_binarize              periregular -0.003504  0.010732
# 14    rf  valoilres_binarize              periregular -0.013310  0.005828
# 15   xgb  valoilres_binarize              periregular -0.005801  0.012502
#
#     test_stat   p_value
# 0   -1.020779  0.153704
# 1   -1.749916  0.040097
# 2   -1.928501  0.026924
# 3    1.301880  0.096508
# 4    1.134830  0.128328
# 5    1.256492  0.104582
# 6    1.293718  0.097996
# 7    0.746423  0.227773
# 8   -0.265501  0.395317
# 9   -0.215610  0.414650
# 10  -0.019169  0.492354
# 11  -0.529206  0.298343
# 12  -0.501310  0.308093
# 13  -0.326511  0.372029
# 14  -2.283614  0.011229
# 15  -0.463972  0.321349

# %%
att_results_df[att_results_df['p_value'] < .05]
# Out:
#    model                  treatment      outcome   tau_hat   tau_std  \
# 4     rf         valoilres_binarize         coup -0.024780  0.012849
# 6     rf         valoilres_binarize  periregular -0.013310  0.005828
# 11   xgb  valoilres_public_binarize  onset2COWCS  0.010381  0.005081
# 12    rf  valoilres_public_binarize     onsetUCS  0.014194  0.008519
# 25   xgb            oilpop_binarize         coup -0.048128  0.027503
# 36    rf  valoilres_impute_binarize  periregular -0.012925  0.005818
#
#     test_stat   p_value
# 4   -1.928501  0.026924
# 6   -2.283614  0.011229
# 11   2.043252  0.020545
# 12   1.666199  0.047876
# 25  -1.749916  0.040097
# 36  -2.221473  0.013193

# %%
treatment_lst = ['newdiscovery_aspo_binarize']
outcome_lst = ['d2incidenceU',
               'd3_6incidenceU',
               'onset2COWCS',
               'onsetUCS',
               'coup',
               'periregular',
               'milexp_pergdpSIPRI_diff']
confoundes = ['crude1990P_diff',
               'wildcat_diff',
               'out_regdisaster_diff',
               'ecgrowth',
               'pop_maddison_diff',
               'popdens_diff',
               'democracy_diff',
               'logmountain',
               'ethnic_fractionalization',
               'religion_fractionalization',
               'language_fractionalization',
               'leg_british',
               'decade',
               'opec']

# %%
df_dict = {'model': [], 'treatment': [], 'outcome': [], 'tau_hat': [], 'tau_std': [], 'test_stat': [], 'p_value': []}
for treat in treatment_lst:
    for out in outcome_lst:
        for model_type in ['rf', 'xgb']:
            if len(oil_df[out].value_counts()) == 2:
                output = 'binary'
            else:
                output = 'continuous'
            if model_type == 'rf':
                tau_hat, tau_std, test_stat, p_value = fit_and_run_model(oil_df, out, treat, confounders, make_g_model, make_Q_model, output_type=output, ate=False)
            else:
                tau_hat, tau_std, test_stat, p_value = fit_and_run_model(oil_df, out, treat, confounders, make_xgboost_g_model, make_xgboost_Q_model, output_type=output, ate=False)
            df_dict['model'].append(model_type)
            df_dict['treatment'].append(treat)
            df_dict['outcome'].append(out)
            df_dict['tau_hat'].append(tau_hat)
            df_dict['tau_std'].append(tau_std)
            df_dict['test_stat'].append(test_stat)
            df_dict['p_value'].append(p_value)

att_discovery_results_df = pd.DataFrame(data=df_dict)
# Out:
# Running models for treatment newdiscovery_aspo_binarize and outcome d2incidenceU on 2561 samples
# G Model has been fit
# Q model has been fit
# AIPTW model has been fit. Returning τ hat and its standard deviation
# τ hat = 0.00204, std = 0.01281, test statistic = 0.15951, p-value = 0.43664
#
# Running models for treatment newdiscovery_aspo_binarize and outcome d2incidenceU on 2561 samples
#
# WARNING:
#  Some propensity scores are very small,
#  which could lead to an inflated AIPTW.
#  Minimum score =  0.004560614470392466
#
# WARNING:
#  Some propensity scores are very large,
#  which could lead to an inflated AIPTW.
#  Maximum score =  0.9953548908233643
# G Model has been fit
# Q model has been fit
# Dropped 18 observations due to overlap condition
# AIPTW model has been fit. Returning τ hat and its standard deviation
# τ hat = -0.01818, std = 0.02404, test statistic = -0.75605, p-value = 0.22484
#
# Running models for treatment newdiscovery_aspo_binarize and outcome d3_6incidenceU on 2509 samples
# G Model has been fit
# Q model has been fit
# AIPTW model has been fit. Returning τ hat and its standard deviation
# τ hat = -0.00718, std = 0.01556, test statistic = -0.46128, p-value = 0.32232
#
# Running models for treatment newdiscovery_aspo_binarize and outcome d3_6incidenceU on 2509 samples
#
# WARNING:
#  Some propensity scores are very small,
#  which could lead to an inflated AIPTW.
#  Minimum score =  0.005469282623380423
#
# WARNING:
#  Some propensity scores are very large,
#  which could lead to an inflated AIPTW.
#  Maximum score =  0.9963449835777283
# G Model has been fit
# Q model has been fit
# Dropped 23 observations due to overlap condition
# AIPTW model has been fit. Returning τ hat and its standard deviation
# τ hat = 0.00098, std = 0.03709, test statistic = 0.02629, p-value = 0.48951
#
# Running models for treatment newdiscovery_aspo_binarize and outcome onset2COWCS on 4977 samples
# G Model has been fit
# Q model has been fit
# AIPTW model has been fit. Returning τ hat and its standard deviation
# τ hat = 0.00478, std = 0.00363, test statistic = 1.31672, p-value = 0.094
#
# Running models for treatment newdiscovery_aspo_binarize and outcome onset2COWCS on 4977 samples
#
# WARNING:
#  Some propensity scores are very small,
#  which could lead to an inflated AIPTW.
#  Minimum score =  0.0018777363002300262
#
# WARNING:
#  Some propensity scores are very large,
#  which could lead to an inflated AIPTW.
#  Maximum score =  0.991011381149292
# G Model has been fit
# Q model has been fit
# Dropped 339 observations due to overlap condition
# AIPTW model has been fit. Returning τ hat and its standard deviation
# τ hat = 0.00475, std = 0.00641, test statistic = 0.74053, p-value = 0.22951
#
# Running models for treatment newdiscovery_aspo_binarize and outcome onsetUCS on 4307 samples
# G Model has been fit
# Q model has been fit
# AIPTW model has been fit. Returning τ hat and its standard deviation
# τ hat = 0.00741, std = 0.0063, test statistic = 1.17642, p-value = 0.11975
#
# Running models for treatment newdiscovery_aspo_binarize and outcome onsetUCS on 4307 samples
#
# WARNING:
#  Some propensity scores are very small,
#  which could lead to an inflated AIPTW.
#  Minimum score =  0.00203303131274879
#
# WARNING:
#  Some propensity scores are very large,
#  which could lead to an inflated AIPTW.
#  Maximum score =  0.9958327412605286
# G Model has been fit
# Q model has been fit
# Dropped 324 observations due to overlap condition
# AIPTW model has been fit. Returning τ hat and its standard deviation
# τ hat = 0.00784, std = 0.01453, test statistic = 0.53933, p-value = 0.29484
#
# Running models for treatment newdiscovery_aspo_binarize and outcome coup on 4849 samples
# G Model has been fit
# Q model has been fit
# AIPTW model has been fit. Returning τ hat and its standard deviation
# τ hat = -0.03699, std = 0.00998, test statistic = -3.70479, p-value = 0.00011
#
# Running models for treatment newdiscovery_aspo_binarize and outcome coup on 4849 samples
#
# WARNING:
#  Some propensity scores are very small,
#  which could lead to an inflated AIPTW.
#  Minimum score =  0.0021128894295543432
#
# WARNING:
#  Some propensity scores are very large,
#  which could lead to an inflated AIPTW.
#  Maximum score =  0.9949800372123718
# G Model has been fit
# Q model has been fit
# Dropped 271 observations due to overlap condition
# AIPTW model has been fit. Returning τ hat and its standard deviation
# τ hat = -0.01015, std = 0.02398, test statistic = -0.42355, p-value = 0.33596
#
# Running models for treatment newdiscovery_aspo_binarize and outcome periregular on 3312 samples
# G Model has been fit
# Q model has been fit
# AIPTW model has been fit. Returning τ hat and its standard deviation
# τ hat = -0.01594, std = 0.00498, test statistic = -3.19894, p-value = 0.0007
#
# Running models for treatment newdiscovery_aspo_binarize and outcome periregular on 3312 samples
#
# WARNING:
#  Some propensity scores are very small,
#  which could lead to an inflated AIPTW.
#  Minimum score =  0.001165153575129807
#
# WARNING:
#  Some propensity scores are very large,
#  which could lead to an inflated AIPTW.
#  Maximum score =  0.9976063966751099
# G Model has been fit
# Q model has been fit
# Dropped 270 observations due to overlap condition
# AIPTW model has been fit. Returning τ hat and its standard deviation
# τ hat = -0.01757, std = 0.01049, test statistic = -1.67425, p-value = 0.04709
#
# Running models for treatment newdiscovery_aspo_binarize and outcome milexp_pergdpSIPRI_diff on 1302 samples
# G Model has been fit
# Q model has been fit
# AIPTW model has been fit. Returning τ hat and its standard deviation
# τ hat = 0.00369, std = 0.14012, test statistic = 0.02634, p-value = 0.48949
#
# Running models for treatment newdiscovery_aspo_binarize and outcome milexp_pergdpSIPRI_diff on 1302 samples
#
# WARNING:
#  Some propensity scores are very small,
#  which could lead to an inflated AIPTW.
#  Minimum score =  0.0010452225105836987
#
# WARNING:
#  Some propensity scores are very large,
#  which could lead to an inflated AIPTW.
#  Maximum score =  0.9980888962745667
# G Model has been fit
# Q model has been fit
# Dropped 176 observations due to overlap condition
# AIPTW model has been fit. Returning τ hat and its standard deviation
# τ hat = 0.03495, std = 0.10933, test statistic = 0.3197, p-value = 0.37462

# %%
att_discovery_results_df.loc[0:3, :]
# Out:
#   model                   treatment         outcome   tau_hat   tau_std  \
# 0    rf  newdiscovery_aspo_binarize    d2incidenceU  0.002043  0.012810
# 1   xgb  newdiscovery_aspo_binarize    d2incidenceU -0.018176  0.024041
# 2    rf  newdiscovery_aspo_binarize  d3_6incidenceU -0.007179  0.015563
# 3   xgb  newdiscovery_aspo_binarize  d3_6incidenceU  0.000975  0.037087
#
#    test_stat   p_value
# 0   0.159511  0.436639
# 1  -0.756049  0.224845
# 2  -0.461279  0.322319
# 3   0.026291  0.489514

# %%
g_df = oil_df[confounders + [treatment]].dropna().reset_index()
g_df[treatment] = g_df[treatment].replace({0.0: 0, 1.0: 1})
rf_propensity = treatment_k_fold_fit_and_predict(make_g_model, g_df[confounders], g_df[treatment], n_splits=5)
xgb_propensity = treatment_k_fold_fit_and_predict(make_xgboost_g_model, g_df[confounders], g_df[treatment], n_splits=5)

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(7, 5))
hist(rf_propensity)
plt.title('Propensity Scores for Random Forest Model', fontsize=16)
plt.xlabel('Propensity Scores', fontsize=15)
plt.ylabel('Frequency', fontsize=15)
# Out:
# Text(0, 0.5, 'Frequency')

# %%
plt.figure(figsize=(7, 5))
hist(xgb_propensity)
plt.title('Propensity Scores for XGBoost Model', fontsize=16)
plt.xlabel('Propensity Scores', fontsize=15)
plt.ylabel('Frequency', fontsize=15)
# Out:
# Text(0, 0.5, 'Frequency')
